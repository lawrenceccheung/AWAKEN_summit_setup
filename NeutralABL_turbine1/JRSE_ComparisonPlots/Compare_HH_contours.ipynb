# %% [markdown]
# # Compare hub-height velocities

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd

from matplotlib.lines import Line2D

# %%
def loadpickle(picklefile):
    pfile          = open(picklefile, 'rb')
    ds             = pickle.load(pfile)
    pfile.close()
    return ds

# %%
rotorD = 127
zHH    = 90

# %%
# Put the list of all cases in here
cases = [
    # AMR-Wind data defs
    {'label':'AMRWIND',
     'datadir':'../AMR.5kmX5km_turbine1/post_processing/pklfiles/',
     'prefix':'AMRWIND',
     'fname_avg':'{prefix}_HH_avgVEL.pkl',
     'fname_inst':'{prefix}_HH_instVEL.pkl',
     'x0':2000,'y0':2560,
    },
    
    # Nalu data defs
    {'label':'NALUWIND',
     'datadir':'../NALU.5kmX5km_turbine1/postprocessing/pklfiles',
     'prefix':'NALUWIND',
     'fname_avg':'{prefix}_HH_avgVEL.pkl',
     'fname_inst':'{prefix}_HH_instVEL.pkl',
     'x0':2000,'y0':2560,
    },

    # Nalu data defs
    {'label':'WRFLES',
     'datadir':'../WRFLES.5kmX5km_turbine1/post_processing/pklfiles',
     'prefix':'WRFLES',
     'fname_avg':'averageHHmaps_{prefix}_D2_wt.pkl',
     'linestyle':{'linestyle':'--', 'lw':2},
     'x0':500,'y0':1000,
    },

]

# %%
for icase, case in enumerate(cases):
    label   = case['label']
    prefix  = case['prefix']
    datadir = case['datadir']
    fname   = case['fname_avg']
    x0, y0   = case['x0'], case['y0']
    ds      = loadpickle(datadir+'/'+fname.format(prefix=prefix))
    
    fig, ax = plt.subplots(1,1,figsize=(10,3), dpi=125)
    clevels=np.linspace(0, 10,101)
    Uh=np.sqrt(ds['U']**2 + ds['V']**2)
    c=plt.contourf((ds['X']-x0)/rotorD, (ds['Y']-y0)/rotorD, Uh, levels=clevels, cmap='coolwarm')
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="3%", pad=0.05)
    cbar=fig.colorbar(c, ax=ax, cax=cax)
    cbar.ax.tick_params(labelsize=8)

    ax.set_xlim([-4, 20])
    ax.set_ylim([-4, 4])

    #ax.set_xlim([-500, 2500])
    #ax.set_ylim([-400, 400])
    ax.set_title(label)
    ax.set_ylabel('y/D')
ax.set_xlabel('x/D')
# Out:
# Text(0.5, 0, 'x/D')

# %%
for icase, case in enumerate(cases):
    label   = case['label']
    prefix  = case['prefix']
    datadir = case['datadir']
    x0, y0   = case['x0'], case['y0']
    if 'fname_inst' in case:
        fname   = case['fname_inst']
        ds      = loadpickle(datadir+'/'+fname.format(prefix=prefix))
    
        fig, ax = plt.subplots(1,1,figsize=(10,3), dpi=125)
        clevels=np.linspace(0, 10,101)
        Uh=np.sqrt(ds['U']**2 + ds['V']**2)
        c=plt.contourf((ds['X']-x0)/rotorD, (ds['Y']-y0)/rotorD, Uh, levels=clevels, cmap='coolwarm')
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="3%", pad=0.05)
        cbar=fig.colorbar(c, ax=ax, cax=cax)
        cbar.ax.tick_params(labelsize=8)

        ax.set_xlim([-4, 20])
        ax.set_ylim([-4, 4])

        ax.set_title(label)
        ax.set_ylabel('y/D')
ax.set_xlabel('x/D')
# Out:
# Text(0.5, 0, 'x/D')
