# %% [markdown]
# # Summit AWAKEN Layout

# %%
# Load the amrwind-frontend module
amrwindfedir = '/projects/wind_uq/lcheung/amrwind-frontend'  # Location of amrwind-frontend 

import sys, os
sys.path.insert(1, amrwindfedir)

# Load the libraries
import amrwind_frontend  as amrwind
import matplotlib.pyplot as plt
import numpy             as np
import math

# Also ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Make all plots inline 
# %matplotlib inline
# Out:
# /projects/wind_uq/lcheung/naluhelperscripts/venv/lib/python2.7/site-packages/subprocess32.py:149: RuntimeWarning: The _posixsubprocess module is not being used. Child process reliability may suffer if your program uses threads.
#   "program uses threads.", RuntimeWarning)

# %%
# Add this to load local packages
import sys
sys.path.insert(1, '/ascldap/users/lcheung/.local/lib/python2.7/site-packages')
import utm
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the data from the database of all turbines
df = pd.read_csv('../../ThunderRanchCoords/uswtdb_v3_3_20210114.csv',low_memory=False)

# %%
turbines=[]
addKingPlains     = True
addArmadilloFlats = True
addThunderRanch   = False
addBreckinridge   = True
addChisholmView   = False

# %% [markdown]
# ### King Plains turbines

# %%
KPturbs1=df[df['p_name']=="unknown Noble County"]
KPturbs2=df[df['p_name']=="unknown Garfield County"]

KPcount = 0

if addKingPlains:
    ge2p8='GE2.8-127'
    turblist = []
    # Turbines from Noble County
    for index, row in KPturbs1.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        datarow = {'faa_asn':row['faa_asn'].replace('OE','KP'), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':ge2p8}
        turbines.append(datarow)
        KPcount += 1
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    
    # Turbines from Garfield County
    for index, row in KPturbs2.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        datarow = {'faa_asn':row['faa_asn'].replace('OE','KP'), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':ge2p8}
        if utmxy[1]>4020000:  # Remove the ones from Armadillo Ranch
            turbines.append(datarow)    
            KPcount += 1
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
        
    print("King Plains: %i turbines"%(KPcount))
    print('Turbine types: '+repr(turblist))
# Out:
# King Plains: 88 turbines
# Turbine types: ['GE2.8-127']

# %% [markdown]
# ### Armadillo flats turbines

# %%
AFturbs=df[df['p_name']=="Armadillo Flats"]

# %%
if addArmadilloFlats:
    turblist = []
    # Turbines from Armadillo Flats
    for index, row in AFturbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','AF').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    
    print("Armadillo Flats: %i turbines"%(len(AFturbs)))
    print('Turbine types: '+repr(turblist))
# Out:
# Armadillo Flats: 109 turbines
# Turbine types: ['GE1.79-100', 'GE1.715-103', 'GE2.3-116']

# %% [markdown]
# ## Thunder Ranch turbines

# %%
TRturbs=df[df['p_name']=="Thunder Ranch"]

# %%
if addThunderRanch:
    turblist = []
    for index, row in TRturbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','TR').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    print("Thunder Ranch: %i turbines"%(len(TRturbs)))
    print('Turbine types: '+repr(turblist))

# %% [markdown]
# ## Breckenridge turbines

# %%
BRturbs=df[df['p_name']=="Breckinridge"]

# %%
if addBreckinridge:
    turblist = []
    for index, row in BRturbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','BR').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    print("Breckinridge: %i turbines"%(len(BRturbs)))
    print('Turbine types: '+repr(turblist))
# Out:
# Breckinridge: 57 turbines
# Turbine types: ['GE1.7-103']

# %% [markdown]
# ## Add Chisholm View

# %%
CV1turbs=df[df['p_name']=="Chisholm View"]
CV2turbs=df[df['p_name']=="Chisholm View II"]

# %%
CVcount = 0

if addChisholmView:
    turblist = []
    for index, row in CV1turbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','CV').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)   
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
        CVcount += 1
    for index, row in CV2turbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','CV').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)   
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
        CVcount += 1
    print("Chisholm View: %i turbines"%(CVcount))
    print('Turbine types: '+repr(turblist))

# %%
print("Total turbines: %i"%(len(turbines)))
# Out:
# Total turbines: 254

# %% [markdown]
# ### Write the CSV file

# %%
summitcsv = 'SummitLayout_Stable1.csv'

verbose=True

# CSV file should have columns with
# name, x, y, type, yaw, hubheight, options
header="""# name, x, y, type, yaw, hubheight, options"""
with open(summitcsv, 'w') as f:
    f.write(header+'\n')
    if verbose: print(header)
    for x in turbines: 
        #line='%s, %f, %f, %s, , ,'%(x['faa_asn'], x['lat'], x['long'], 'Summit_'+x['t_model'])
        line='%s, %f, %f, %s, , ,'%(x['faa_asn'], x['utm'][0], x['utm'][1], 'Summit_'+x['t_model'])
        f.write(line+'\n')
        if verbose: print(line)
# Out:
# # name, x, y, type, yaw, hubheight, options
# 2019-WTW-4713-KP, 644600.601753, 4027108.285963, Summit_GE2.8-127, , ,
# 2019-WTW-4655-KP, 642097.122368, 4030694.510509, Summit_GE2.8-127, , ,
# 2019-WTW-4651-KP, 640524.009474, 4030645.516444, Summit_GE2.8-127, , ,
# 2019-WTW-4726-KP, 647045.619630, 4026325.291169, Summit_GE2.8-127, , ,
# 2019-WTW-4671-KP, 643717.500753, 4029868.723641, Summit_GE2.8-127, , ,
# 2019-WTW-4715-KP, 641404.515835, 4025585.036081, Summit_GE2.8-127, , ,
# 2019-WTW-4691-KP, 640525.539569, 4027810.309735, Summit_GE2.8-127, , ,
# 2019-WTW-7913-KP, 638938.794021, 4027387.685619, Summit_GE2.8-127, , ,
# 2019-WTW-4657-KP, 642927.453405, 4030718.728327, Summit_GE2.8-127, , ,
# 2019-WTW-4694-KP, 641659.228636, 4028640.259465, Summit_GE2.8-127, , ,
# 2019-WTW-4718-KP, 642621.397465, 4025659.569623, Summit_GE2.8-127, , ,
# 2019-WTW-4690-KP, 640175.944241, 4027374.995134, Summit_GE2.8-127, , ,
# 2019-WTW-4656-KP, 642480.917060, 4030612.715718, Summit_GE2.8-127, , ,
# 2019-WTW-4697-KP, 642940.656099, 4028713.362363, Summit_GE2.8-127, , ,
# 2019-WTW-4698-KP, 643348.753181, 4028746.408167, Summit_GE2.8-127, , ,
# 2019-WTW-4701-KP, 644923.445904, 4028068.654069, Summit_GE2.8-127, , ,
# 2019-WTW-4723-KP, 644814.999895, 4025506.305084, Summit_GE2.8-127, , ,
# 2019-WTW-4673-KP, 638413.264818, 4028657.223273, Summit_GE2.8-127, , ,
# 2019-WTW-4716-KP, 641814.750726, 4025661.091204, Summit_GE2.8-127, , ,
# 2014-WTW-8370-BR, 616523.313051, 4035548.675567, Summit_GE1.7-103, , ,

# %% [markdown]
# ## AWAKEN Wind farm layout for Summit

# %% [markdown]
# **Note**: to make sure that the correct turbines are in place for setting up this layout file, make sure something like this file is in place:

# %%
with open(amrwindfedir+"/turbines/summitlayoutturbs.yaml")as f: print(f.read())
# Out:
# turbines:
#   Summit_GE1.68-82.5:
#     turbinetype_name:    "Summit_GE1.68-82.5"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      82.5
#     Actuator_hub_height:          80
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE1.715-103:
#     turbinetype_name:    "Summit_GE1.715-103"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      103
#     Actuator_hub_height:          80
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE1.715-103:
#     turbinetype_name:    "Summit_GE1.715-103"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      103
#     Actuator_hub_height:          80
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE1.79-100:
#     turbinetype_name:    "Summit_GE1.79-100"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      100
#     Actuator_hub_height:          80
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE1.7-103:
#     turbinetype_name:    "Summit_GE1.7-103"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      103
#     Actuator_hub_height:          80
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE2.3-116:
#     turbinetype_name:    "Summit_GE2.3-116"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      116
#     Actuator_hub_height:          80
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE2.4-107:
#     turbinetype_name:    "Summit_GE2.4-107"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      107
#     Actuator_hub_height:          80
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE2.5-116:
#     turbinetype_name:    "Summit_GE2.5-116"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      116
#     Actuator_hub_height:          90
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]
#   Summit_GE2.8-127:
#     turbinetype_name:    "Summit_GE2.8-127"
#     turbinetype_comment: "Dummy layout"
#     Actuator_type:       UniformCtDisk
#     Actuator_rotor_diameter:      127
#     Actuator_hub_height:          90
#     Actuator_thrust_coeff:        0.6
#     Actuator_epsilon:             [5.0]

# %%
# Start the AMR-Wind case
case = amrwind.MyApp.init_nogui()

# %%
WS     = 10.5            # Wind speed, m/s
WDir   = 175           # Wind direction, degrees
farm_domainsize = [42000, 35000, 900]
farm_center     = [630500, 4023000]   # In utm
#print(utm.from_latlon(36.587395, -97.756294))
#farm_center          = utm.to_latlon(640000, 4030000, 14, 'S')
print("Farm center = "+repr(farm_center)) # in lat/long
farm_background_mesh = 10 #20
# Out:
# Farm center = [630500, 4023000]

# %%
case.setAMRWindInput('useWSDir', True)
case.setAMRWindInput('ABL_windspeed', WS, forcechange=True)
case.setAMRWindInput('ABL_winddir',   WDir, forcechange=True)
case.ABL_calculateWindVector()

# %%
# Some random stuff
case.setAMRWindInput('incflo.physics', ['FreeStream', 'Actuator'])
case.setAMRWindInput('time.fixed_dt', 0.1)

# %%
case.loadTurbineCSVFile(summitcsv)

# %%
case.setAMRWindInput('turbines_coordsys', 'utm')

# Set up the domain 
case.setAMRWindInput('turbines_domainsize',         farm_domainsize)
case.setAMRWindInput('turbines_backgroundmeshsize', farm_background_mesh)
case.setAMRWindInput('turbines_autocalccenter',     False)
case.setAMRWindInput('turbines_farmcenter',         [farm_center[0], farm_center[1]])
case.setAMRWindInput('turbines_deleteprev', True)

# %%
# Preview the turbine layout
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=125)
case.setAMRWindInput('turbines_plotnames', False)
case.turbines_previewAllTurbines(ax=ax)

# %%
case.getAMRWindInput('turbines_farmcenter')
# Out:
# [630500.0, 4023000.0]

# %%
case.turbines_createAllTurbines()

# Print out existing list of turbines, just to confirm that the turbines got made
#print(case.listboxpopupwindict['listboxactuator'].getitemlist())
# Out:
# CANNOT update: ABLMeanBoussinesq use forcechange=True in setval()

# %% [markdown]
# ## Add refinements

# %%
refinementcsv="""
# CSV file should have columns with
# level, upstream, downstream, lateral, below, above, options
level, upstream, downstream, lateral, below, above, options
0,     13800,    15000,      18500,  100,  700,      center:farm units:meter
#1,     20000,    25000,      30000,  100,  500,   center:farm units:meter
1,   6500,    4500,    9000,  100,  400, center:specified units:meter centerx:639000 centery:4030000 centerz:100 name:KP
1,  8800,    9000,    9000,  100,  400, center:specified units:meter centerx:627000 centery:4018000 centerz:100 name:AF
1,   3700,    1900,     6500,  100,  400, center:specified units:meter centerx:618500 centery:4035000 centerz:100 name:BR
#1,  10000,    5000,    14000,  100,  400, center:specified units:meter centerx:618000 centery:4050000 centerz:100 name:CV
#1,  10000,    7500,    20000,  100,  400, center:specified units:meter centerx:653000 centery:4050000 centerz:100 name:TR
#2,     0.5,  0.5, 0.5, 0.525, 0.525, #take out if L1 is 2.5 m -units D
"""
case.setAMRWindInput('refine_csvtextbox', refinementcsv)
case.setAMRWindInput('refine_deleteprev', True)

# %%
case.refine_createAllZones()

# %%
# Plot the domain (total domain)
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=150)
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
case.plotDomain(ax=ax)
ax.axis('scaled')
# Out:
# Plotting turbines
# (607400.0, 653600.0, 4003750.0, 4042250.0)

# %%
# Plot the domain (total domain)
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=150)
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = True
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XZ'
case.plotDomain(ax=ax)
ax.axis('auto')
# Out:
# Plotting turbines
# (607400.0, 653600.0, -62.36220472440946, 945.8267716535433)

# %%
# Estimate mesh size
case.estimateMeshSize(verbose=False)
# Out:
# ESTIMATED MESH SIZE
#    Level       Ncells                      Cell Size
#        0   1323000000             10.0 x 10.0 x 10.0
#        1   6819840000                5.0 x 5.0 x 5.0
#        2  18918400000                2.5 x 2.5 x 2.5
#   TOTAL:  27061240000

# %%
## Write the input file
print(case.writeAMRWindInput(''))
# Out:
# # --- Simulation time control parameters ---
# time.stop_time                           = 100.0               # Max (simulated) time to evolve [s]
# time.max_step                            = -1
# time.fixed_dt                            = 0.1                 # Fixed timestep size (in seconds). If negative, then time.cfl is used
# incflo.physics                           = FreeStream Actuator # List of physics models to include in simulation.
# incflo.verbose                           = 0
# io.check_file                            = chk
# incflo.use_godunov                       = true
# incflo.godunov_type                      = weno_z
# incflo.gravity                           = 0.0 0.0 -9.81       # Gravitational acceleration vector (x,y,z) [m/s^2]
# incflo.density                           = 1.0                 # Fluid density [kg/m^3]
# transport.viscosity                      = 1.872e-05           # Fluid dynamic viscosity [kg/m-s]
# transport.laminar_prandtl                = 0.7                 # Laminar prandtl number
# transport.turbulent_prandtl              = 0.3333              # Turbulent prandtl number
#
# # --- Geometry and Mesh ---
# geometry.prob_lo                         = 609500.0 4005500.0 0.0
# geometry.prob_hi                         = 651500.0 4040500.0 900.0
# amr.n_cell                               = 4200 3500 90        # Number of cells in x, y, and z directions
# amr.max_level                            = 2
# geometry.is_periodic                     = 1 1 0
# zlo.type                                 = no_slip_wall
# zhi.type                                 = no_slip_wall
#
# # --- ABL parameters ---
# ICNS.source_terms                        =    ActuatorForcing
# incflo.velocity                          = -0.91513529885 10.46004433 0.0
# ABLForcing.abl_forcing_height            = 0.0
# time.plot_interval                       = 1000
# io.plot_file                             = plt
# io.KE_int                                = -1
#
# #---- tagging defs ----
# tagging.labels                           = Farm_level_0_zone KP AF BR
# tagging.Farm_level_0_zone.type           = GeometryRefinement
# tagging.Farm_level_0_zone.shapes         = Farm_level_0_zone
# tagging.Farm_level_0_zone.level          = 0
# tagging.Farm_level_0_zone.Farm_level_0_zone.type = box
# tagging.Farm_level_0_zone.Farm_level_0_zone.origin = 650132.351165 4010864.89441 -16.5354330709
# tagging.Farm_level_0_zone.Farm_level_0_zone.xaxis = -2510.08539113 28690.407305 0.0
# tagging.Farm_level_0_zone.Farm_level_0_zone.yaxis = -36859.2038294 -3224.76248166 0.0
# tagging.Farm_level_0_zone.Farm_level_0_zone.zaxis = 0.0 0.0 800.0
# tagging.KP.type                          = GeometryRefinement
# tagging.KP.shapes                        = KP
# tagging.KP.level                         = 1
# tagging.KP.KP.type                       = box
# tagging.KP.KP.origin                     = 648532.264611 4024309.13615 0.0
# tagging.KP.KP.xaxis                      = -958.713170224 10958.141679 0.0
# tagging.KP.KP.yaxis                      = -17931.5045657 -1568.80336946 0.0
# tagging.KP.KP.zaxis                      = 0.0 0.0 500.0
# tagging.AF.type                          = GeometryRefinement
# tagging.AF.shapes                        = AF
# tagging.AF.level                         = 1
# tagging.AF.AF.type                       = box
# tagging.AF.AF.origin                     = 636732.722819 4010017.88834 0.0
# tagging.AF.AF.xaxis                      = -1551.37222091 17732.265626 0.0
# tagging.AF.AF.yaxis                      = -17931.5045657 -1568.80336946 0.0
# tagging.AF.AF.zaxis                      = 0.0 0.0 500.0
# tagging.BR.type                          = GeometryRefinement
# tagging.BR.shapes                        = BR
# tagging.BR.level                         = 1
# tagging.BR.BR.type                       = box
# tagging.BR.BR.origin                     = 625297.741786 4031880.59194 0.0
# tagging.BR.BR.xaxis                      = -488.072159387 5578.69030931 0.0
# tagging.BR.BR.yaxis                      = -12950.5310752 -1133.02465572 0.0
# tagging.BR.BR.zaxis                      = 0.0 0.0 500.0
#
# #---- actuator defs ----
# Actuator.labels                          = 2019-WTW-4713-KP 2019-WTW-4655-KP 2019-WTW-4651-KP 2019-WTW-4726-KP 2019-WTW-4671-KP 2019-WTW-4715-KP 2019-WTW-4691-KP 2019-WTW-7913-KP 2019-WTW-4657-KP 2019-WTW-4694-KP 2019-WTW-4718-KP 2019-WTW-4690-KP 2019-WTW-4656-KP 2019-WTW-4697-KP 2019-WTW-4698-KP 2019-WTW-4701-KP 2019-WTW-4723-KP 2019-WTW-4673-KP 2019-WTW-4716-KP 2019-WTW-4693
KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4655-KP.hub_height     = 90.0
# Actuator.2019-WTW-4655-KP.epsilon        = 5.0
# Actuator.2019-WTW-4655-KP.fllc           = false
# Actuator.2019-WTW-4655-KP.yaw            = 175.0
# Actuator.2019-WTW-4655-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4655-KP.num_blades     = 3
# Actuator.2019-WTW-4655-KP.use_tip_correction = true
# Actuator.2019-WTW-4655-KP.use_root_correction = true
# Actuator.2019-WTW-4651-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4651-KP.base_position  = 640524.009474 4030645.51644 0.0
# Actuator.2019-WTW-4651-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4651-KP.hub_height     = 90.0
# Actuator.2019-WTW-4651-KP.epsilon        = 5.0
# Actuator.2019-WTW-4651-KP.fllc           = false
# Actuator.2019-WTW-4651-KP.yaw            = 175.0
# Actuator.2019-WTW-4651-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4651-KP.num_blades     = 3
# Actuator.2019-WTW-4651-KP.use_tip_correction = true
# Actuator.2019-WTW-4651-KP.use_root_correction = true
# Actuator.2019-WTW-4726-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4726-KP.base_position  = 647045.61963 4026325.29117 0.0
# Actuator.2019-WTW-4726-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4726-KP.hub_height     = 90.0
# Actuator.2019-WTW-4726-KP.epsilon        = 5.0
# Actuator.2019-WTW-4726-KP.fllc           = false
# Actuator.2019-WTW-4726-KP.yaw            = 175.0
# Actuator.2019-WTW-4726-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4726-KP.num_blades     = 3
# Actuator.2019-WTW-4726-KP.use_tip_correction = true
# Actuator.2019-WTW-4726-KP.use_root_correction = true
# Actuator.2019-WTW-4671-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4671-KP.base_position  = 643717.500753 4029868.72364 0.0
# Actuator.2019-WTW-4671-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4671-KP.hub_height     = 90.0
# Actuator.2019-WTW-4671-KP.epsilon        = 5.0
# Actuator.2019-WTW-4671-KP.fllc           = false
# Actuator.2019-WTW-4671-KP.yaw            = 175.0
# Actuator.2019-WTW-4671-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4671-KP.num_blades     = 3
# Actuator.2019-WTW-4671-KP.use_tip_correction = true
# Actuator.2019-WTW-4671-KP.use_root_correction = true
# Actuator.2019-WTW-4715-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4715-KP.base_position  = 641404.515835 4025585.03608 0.0
# Actuator.2019-WTW-4715-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4715-KP.hub_height     = 90.0
# Actuator.2019-WTW-4715-KP.epsilon        = 5.0
# Actuator.2019-WTW-4715-KP.fllc           = false
# Actuator.2019-WTW-4715-KP.yaw            = 175.0
# Actuator.2019-WTW-4715-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4715-KP.num_blades     = 3
# Actuator.2019-WTW-4715-KP.use_tip_correction = true
# Actuator.2019-WTW-4715-KP.use_root_correction = true
# Actuator.2019-WTW-4691-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4691-KP.base_position  = 640525.539569 4027810.30973 0.0
# Actuator.2019-WTW-4691-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4691-KP.hub_height     = 90.0
# Actuator.2019-WTW-4691-KP.epsilon        = 5.0
# Actuator.2019-WTW-4691-KP.fllc           = false
# Actuator.2019-WTW-4691-KP.yaw            = 175.0
# Actuator.2019-WTW-4691-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4691-KP.num_blades     = 3
# Actuator.2019-WTW-4691-KP.use_tip_correction = true
# Actuator.2019-WTW-4691-KP.use_root_correction = true
# Actuator.2019-WTW-7913-KP.type           = UniformCtDisk
# Actuator.2019-WTW-7913-KP.base_position  = 638938.794021 4027387.68562 0.0
# Actuator.2019-WTW-7913-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-7913-KP.hub_height     = 90.0
# Actuator.2019-WTW-7913-KP.epsilon        = 5.0
# Actuator.2019-WTW-7913-KP.fllc           = false
# Actuator.2019-WTW-7913-KP.yaw            = 175.0
# Actuator.2019-WTW-7913-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-7913-KP.num_blades     = 3
# Actuator.2019-WTW-7913-KP.use_tip_correction = true
# Actuator.2019-WTW-7913-KP.use_root_correction = true
# Actuator.2019-WTW-4657-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4657-KP.base_position  = 642927.453405 4030718.72833 0.0
# Actuator.2019-WTW-4657-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4657-KP.hub_height     = 90.0
# Actuator.2019-WTW-4657-KP.epsilon        = 5.0
# Actuator.2019-WTW-4657-KP.fllc           = false
# Actuator.2019-WTW-4657-KP.yaw            = 175.0
# Actuator.2019-WTW-4657-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4657-KP.num_blades     = 3
# Actuator.2019-WTW-4657-KP.use_tip_correction = true
# Actuator.2019-WTW-4657-KP.use_root_correction = true
# Actuator.2019-WTW-4694-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4694-KP.base_position  = 641659.228636 4028640.25947 0.0
# Actuator.2019-WTW-4694-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4694-KP.hub_height     = 90.0
# Actuator.2019-WTW-4694-KP.epsilon        = 5.0
# Actuator.2019-WTW-4694-KP.fllc           = false
# Actuator.2019-WTW-4694-KP.yaw            = 175.0
# Actuator.2019-WTW-4694-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4694-KP.num_blades     = 3
# Actuator.2019-WTW-4694-KP.use_tip_correction = true
# Actuator.2019-WTW-4694-KP.use_root_correction = true
# Actuator.2019-WTW-4718-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4718-KP.base_position  = 642621.397465 4025659.56962 0.0
# Actuator.2019-WTW-4718-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4718-KP.hub_height     = 90.0
# Actuator.2019-WTW-4718-KP.epsilon        = 5.0
# Actuator.2019-WTW-4718-KP.fllc           = false
# Actuator.2019-WTW-4718-KP.yaw            = 175.0
# Actuator.2019-WTW-4718-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4718-KP.num_blades     = 3
# Actuator.2019-WTW-4718-KP.use_tip_correction = true
# Actuator.2019-WTW-4718-KP.use_root_correction = true
# Actuator.2019-WTW-4690-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4690-KP.base_position  = 640175.944241 4027374.99513 0.0
# Actuator.2019-WTW-4690-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4690-KP.hub_height     = 90.0
# Actuator.2019-WTW-4690-KP.epsilon        = 5.0
# Actuator.2019-WTW-4690-KP.fllc           = false
# Actuator.2019-WTW-4690-KP.yaw            = 175.0
# Actuator.2019-WTW-4690-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4690-KP.num_blades     = 3
# Actuator.2019-WTW-4690-KP.use_tip_correction = true
# Actuator.2019-WTW-4690-KP.use_root_correction = true
# Actuator.2019-WTW-4656-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4656-KP.base_position  = 642480.91706 4030612.71572 0.0
# Actuator.2019-WTW-4656-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4656-KP.hub_height     = 90.0
# Actuator.2019-WTW-4656-KP.epsilon        = 5.0
# Actuator.2019-WTW-4656-KP.fllc           = false
# Actuator.2019-WTW-4656-KP.yaw            = 175.0
# Actuator.2019-WTW-4656-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4656-KP.num_blades     = 3
# Actuator.2019-WTW-4656-KP.use_tip_correction = true
# Actuator.2019-WTW-4656-KP.use_root_correction = true
# Actuator.2019-WTW-4697-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4697-KP.base_position  = 642940.656099 4028713.36236 0.0
# Actuator.2019-WTW-4697-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4697-KP.hub_height     = 90.0
# Actuator.2019-WTW-4697-KP.epsilon        = 5.0
# Actuator.2019-WTW-4697-KP.fllc           = false
# Actuator.2019-WTW-4697-KP.yaw            = 175.0
# Actuator.2019-WTW-4697-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4697-KP.num_blades     = 3
# Actuator.2019-WTW-4697-KP.use_tip_correction = true
# Actuator.2019-WTW-4697-KP.use_root_correction = true
# Actuator.2019-WTW-4698-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4698-KP.base_position  = 643348.753181 4028746.40817 0.0
# Actuator.2019-WTW-4698-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4698-KP.hub_height     = 90.0
# Actuator.2019-WTW-4698-KP.epsilon        = 5.0
# Actuator.2019-WTW-4698-KP.fllc           = false
# Actuator.2019-WTW-4698-KP.yaw            = 175.0
# Actuator.2019-WTW-4698-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4698-KP.num_blades     = 3
# Actuator.2019-WTW-4698-KP.use_tip_correction = true
# Actuator.2019-WTW-4698-KP.use_root_correction = true
# Actuator.2019-WTW-4701-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4701-KP.base_position  = 644923.445904 4028068.65407 0.0
# Actuator.2019-WTW-4701-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4701-KP.hub_height     = 90.0
# Actuator.2019-WTW-4701-KP.epsilon        = 5.0
# Actuator.2019-WTW-4701-KP.fllc           = false
# Actuator.2019-WTW-4701-KP.yaw            = 175.0
# Actuator.2019-WTW-4701-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4701-KP.num_blades     = 3
# Actuator.2019-WTW-4701-KP.use_tip_correction = true
# Actuator.2019-WTW-4701-KP.use_root_correction = true
# Actuator.2019-WTW-4723-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4723-KP.base_position  = 644814.999895 4025506.30508 0.0
# Actuator.2019-WTW-4723-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4723-KP.hub_height     = 90.0
# Actuator.2019-WTW-4723-KP.epsilon        = 5.0
# Actuator.2019-WTW-4723-KP.fllc           = false
# Actuator.2019-WTW-4723-KP.yaw            = 175.0
# Actuator.2019-WTW-4723-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4723-KP.num_blades     = 3
# Actuator.2019-WTW-4723-KP.use_tip_correction = true
# Actuator.2019-WTW-4723-KP.use_root_correction = true
# Actuator.2019-WTW-4673-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4673-KP.base_position  = 638413.264818 4028657.22327 0.0
# Actuator.2019-WTW-4673-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4673-KP.hub_height     = 90.0
# Actuator.2019-WTW-4673-KP.epsilon        = 5.0
# Actuator.2019-WTW-4673-KP.fllc           = false
# Actuator.2019-WTW-4673-KP.yaw            = 175.0
# Actuator.2019-WTW-4673-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4673-KP.num_blades     = 3
# Actuator.2019-WTW-4673-KP.use_tip_correction = true
# Actuator.2019-WTW-4673-KP.use_root_correction = true
# Actuator.2019-WTW-4716-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4716-KP.base_position  = 641814.750726 4025661.0912 0.0
# Actuator.2019-WTW-4716-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4716-KP.hub_height     = 90.0
# Actuator.2019-WTW-4716-KP.epsilon        = 5.0
# Actuator.2019-WTW-4716-KP.fllc           = false
# Actuator.2019-WTW-4716-KP.yaw            = 175.0
# Actuator.2019-WTW-4716-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4716-KP.num_blades     = 3
# Actuator.2019-WTW-4716-KP.use_tip_correction = true
# Actuator.2019-WTW-4716-KP.use_root_correction = true
# Actuator.2019-WTW-4693-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4693-KP.base_position  = 641344.229254 4028146.64813 0.0
# Actuator.2019-WTW-4693-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4693-KP.hub_height     = 90.0
# Actuator.2019-WTW-4693-KP.epsilon        = 5.0
# Actuator.2019-WTW-4693-KP.fllc           = false
# Actuator.2019-WTW-4693-KP.yaw            = 175.0
# Actuator.2019-WTW-4693-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4693-KP.num_blades     = 3
# Actuator.2019-WTW-4693-KP.use_tip_correction = true
# Actuator.2019-WTW-4693-KP.use_root_correction = true
# Actuator.2019-WTW-4725-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4725-KP.base_position  = 646632.028126 4026329.26812 0.0
# Actuator.2019-WTW-4725-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4725-KP.hub_height     = 90.0
# Actuator.2019-WTW-4725-KP.epsilon        = 5.0
# Actuator.2019-WTW-4725-KP.fllc           = false
# Actuator.2019-WTW-4725-KP.yaw            = 175.0
# Actuator.2019-WTW-4725-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4725-KP.num_blades     = 3
# Actuator.2019-WTW-4725-KP.use_tip_correction = true
# Actuator.2019-WTW-4725-KP.use_root_correction = true
# Actuator.2019-WTW-7915-KP.type           = UniformCtDisk
# Actuator.2019-WTW-7915-KP.base_position  = 643050.58826 4025581.53324 0.0
# Actuator.2019-WTW-7915-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-7915-KP.hub_height     = 90.0
# Actuator.2019-WTW-7915-KP.epsilon        = 5.0
# Actuator.2019-WTW-7915-KP.fllc           = false
# Actuator.2019-WTW-7915-KP.yaw            = 175.0
# Actuator.2019-WTW-7915-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-7915-KP.num_blades     = 3
# Actuator.2019-WTW-7915-KP.use_tip_correction = true
# Actuator.2019-WTW-7915-KP.use_root_correction = true
# Actuator.2019-WTW-4674-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4674-KP.base_position  = 638814.19917 4028667.41476 0.0
# Actuator.2019-WTW-4674-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4674-KP.hub_height     = 90.0
# Actuator.2019-WTW-4674-KP.epsilon        = 5.0
# Actuator.2019-WTW-4674-KP.fllc           = false
# Actuator.2019-WTW-4674-KP.yaw            = 175.0
# Actuator.2019-WTW-4674-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4674-KP.num_blades     = 3
# Actuator.2019-WTW-4674-KP.use_tip_correction = true
# Actuator.2019-WTW-4674-KP.use_root_correction = true
# Actuator.2019-WTW-4689-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4689-KP.base_position  = 639255.563856 4026972.00264 0.0
# Actuator.2019-WTW-4689-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4689-KP.hub_height     = 90.0
# Actuator.2019-WTW-4689-KP.epsilon        = 5.0
# Actuator.2019-WTW-4689-KP.fllc           = false
# Actuator.2019-WTW-4689-KP.yaw            = 175.0
# Actuator.2019-WTW-4689-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4689-KP.num_blades     = 3
# Actuator.2019-WTW-4689-KP.use_tip_correction = true
# Actuator.2019-WTW-4689-KP.use_root_correction = true
# Actuator.2019-WTW-7921-KP.type           = UniformCtDisk
# Actuator.2019-WTW-7921-KP.base_position  = 639314.463247 4030543.40061 0.0
# Actuator.2019-WTW-7921-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-7921-KP.hub_height     = 90.0
# Actuator.2019-WTW-7921-KP.epsilon        = 5.0
# Actuator.2019-WTW-7921-KP.fllc           = false
# Actuator.2019-WTW-7921-KP.yaw            = 175.0
# Actuator.2019-WTW-7921-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-7921-KP.num_blades     = 3
# Actuator.2019-WTW-7921-KP.use_tip_correction = true
# Actuator.2019-WTW-7921-KP.use_root_correction = true
# Actuator.2019-WTW-4710-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4710-KP.base_position  = 643380.072473 4027477.81862 0.0
# Actuator.2019-WTW-4710-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4710-KP.hub_height     = 90.0
# Actuator.2019-WTW-4710-KP.epsilon        = 5.0
# Actuator.2019-WTW-4710-KP.fllc           = false
# Actuator.2019-WTW-4710-KP.yaw            = 175.0
# Actuator.2019-WTW-4710-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4710-KP.num_blades     = 3
# Actuator.2019-WTW-4710-KP.use_tip_correction = true
# Actuator.2019-WTW-4710-KP.use_root_correction = true
# Actuator.2019-WTW-4648-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4648-KP.base_position  = 638913.48724 4030881.93782 0.0
# Actuator.2019-WTW-4648-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4648-KP.hub_height     = 90.0
# Actuator.2019-WTW-4648-KP.epsilon        = 5.0
# Actuator.2019-WTW-4648-KP.fllc           = false
# Actuator.2019-WTW-4648-KP.yaw            = 175.0
# Actuator.2019-WTW-4648-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4648-KP.num_blades     = 3
# Actuator.2019-WTW-4648-KP.use_tip_correction = true
# Actuator.2019-WTW-4648-KP.use_root_correction = true
# Actuator.2019-WTW-4721-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4721-KP.base_position  = 643798.350971 4025700.54468 0.0
# Actuator.2019-WTW-4721-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4721-KP.hub_height     = 90.0
# Actuator.2019-WTW-4721-KP.epsilon        = 5.0
# Actuator.2019-WTW-4721-KP.fllc           = false
# Actuator.2019-WTW-4721-KP.yaw            = 175.0
# Actuator.2019-WTW-4721-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4721-KP.num_blades     = 3
# Actuator.2019-WTW-4721-KP.use_tip_correction = true
# Actuator.2019-WTW-4721-KP.use_root_correction = true
# Actuator.2019-WTW-4652-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4652-KP.base_position  = 640910.306246 4030667.88858 0.0
# Actuator.2019-WTW-4652-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4652-KP.hub_height     = 90.0
# Actuator.2019-WTW-4652-KP.epsilon        = 5.0
# Actuator.2019-WTW-4652-KP.fllc           = false
# Actuator.2019-WTW-4652-KP.yaw            = 175.0
# Actuator.2019-WTW-4652-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4652-KP.num_blades     = 3
# Actuator.2019-WTW-4652-KP.use_tip_correction = true
# Actuator.2019-WTW-4652-KP.use_root_correction = true
# Actuator.2019-WTW-4658-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4658-KP.base_position  = 643350.893237 4030724.0689 0.0
# Actuator.2019-WTW-4658-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4658-KP.hub_height     = 90.0
# Actuator.2019-WTW-4658-KP.epsilon        = 5.0
# Actuator.2019-WTW-4658-KP.fllc           = false
# Actuator.2019-WTW-4658-KP.yaw            = 175.0
# Actuator.2019-WTW-4658-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4658-KP.num_blades     = 3
# Actuator.2019-WTW-4658-KP.use_tip_correction = true
# Actuator.2019-WTW-4658-KP.use_root_correction = true
# Actuator.2019-WTW-4692-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4692-KP.base_position  = 640933.981632 4028117.10328 0.0
# Actuator.2019-WTW-4692-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4692-KP.hub_height     = 90.0
# Actuator.2019-WTW-4692-KP.epsilon        = 5.0
# Actuator.2019-WTW-4692-KP.fllc           = false
# Actuator.2019-WTW-4692-KP.yaw            = 175.0
# Actuator.2019-WTW-4692-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4692-KP.num_blades     = 3
# Actuator.2019-WTW-4692-KP.use_tip_correction = true
# Actuator.2019-WTW-4692-KP.use_root_correction = true
# Actuator.2019-WTW-4695-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4695-KP.base_position  = 642076.518358 4028698.36238 0.0
# Actuator.2019-WTW-4695-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4695-KP.hub_height     = 90.0
# Actuator.2019-WTW-4695-KP.epsilon        = 5.0
# Actuator.2019-WTW-4695-KP.fllc           = false
# Actuator.2019-WTW-4695-KP.yaw            = 175.0
# Actuator.2019-WTW-4695-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4695-KP.num_blades     = 3
# Actuator.2019-WTW-4695-KP.use_tip_correction = true
# Actuator.2019-WTW-4695-KP.use_root_correction = true
# Actuator.2019-WTW-7914-KP.type           = UniformCtDisk
# Actuator.2019-WTW-7914-KP.base_position  = 642457.921904 4027436.41542 0.0
# Actuator.2019-WTW-7914-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-7914-KP.hub_height     = 90.0
# Actuator.2019-WTW-7914-KP.epsilon        = 5.0
# Actuator.2019-WTW-7914-KP.fllc           = false
# Actuator.2019-WTW-7914-KP.yaw            = 175.0
# Actuator.2019-WTW-7914-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-7914-KP.num_blades     = 3
# Actuator.2019-WTW-7914-KP.use_tip_correction = true
# Actuator.2019-WTW-7914-KP.use_root_correction = true
# Actuator.2019-WTW-4675-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4675-KP.base_position  = 639300.397636 4028608.31291 0.0
# Actuator.2019-WTW-4675-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4675-KP.hub_height     = 90.0
# Actuator.2019-WTW-4675-KP.epsilon        = 5.0
# Actuator.2019-WTW-4675-KP.fllc           = false
# Actuator.2019-WTW-4675-KP.yaw            = 175.0
# Actuator.2019-WTW-4675-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4675-KP.num_blades     = 3
# Actuator.2019-WTW-4675-KP.use_tip_correction = true
# Actuator.2019-WTW-4675-KP.use_root_correction = true
# Actuator.2019-WTW-4702-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4702-KP.base_position  = 645358.125553 4028064.50971 0.0
# Actuator.2019-WTW-4702-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4702-KP.hub_height     = 90.0
# Actuator.2019-WTW-4702-KP.epsilon        = 5.0
# Actuator.2019-WTW-4702-KP.fllc           = false
# Actuator.2019-WTW-4702-KP.yaw            = 175.0
# Actuator.2019-WTW-4702-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4702-KP.num_blades     = 3
# Actuator.2019-WTW-4702-KP.use_tip_correction = true
# Actuator.2019-WTW-4702-KP.use_root_correction = true
# Actuator.2019-WTW-4704-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4704-KP.base_position  = 646974.461559 4027853.43292 0.0
# Actuator.2019-WTW-4704-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4704-KP.hub_height     = 90.0
# Actuator.2019-WTW-4704-KP.epsilon        = 5.0
# Actuator.2019-WTW-4704-KP.fllc           = false
# Actuator.2019-WTW-4704-KP.yaw            = 175.0
# Actuator.2019-WTW-4704-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4704-KP.num_blades     = 3
# Actuator.2019-WTW-4704-KP.use_tip_correction = true
# Actuator.2019-WTW-4704-KP.use_root_correction = true
# Actuator.2019-WTW-4712-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4712-KP.base_position  = 644188.833666 4027458.28737 0.0
# Actuator.2019-WTW-4712-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4712-KP.hub_height     = 90.0
# Actuator.2019-WTW-4712-KP.epsilon        = 5.0
# Actuator.2019-WTW-4712-KP.fllc           = false
# Actuator.2019-WTW-4712-KP.yaw            = 175.0
# Actuator.2019-WTW-4712-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4712-KP.num_blades     = 3
# Actuator.2019-WTW-4712-KP.use_tip_correction = true
# Actuator.2019-WTW-4712-KP.use_root_correction = true
# Actuator.2019-WTW-7916-KP.type           = UniformCtDisk
# Actuator.2019-WTW-7916-KP.base_position  = 643397.166173 4025740.05886 0.0
# Actuator.2019-WTW-7916-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-7916-KP.hub_height     = 90.0
# Actuator.2019-WTW-7916-KP.epsilon        = 5.0
# Actuator.2019-WTW-7916-KP.fllc           = false
# Actuator.2019-WTW-7916-KP.yaw            = 175.0
# Actuator.2019-WTW-7916-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-7916-KP.num_blades     = 3
# Actuator.2019-WTW-7916-KP.use_tip_correction = true
# Actuator.2019-WTW-7916-KP.use_root_correction = true
# Actuator.2019-WTW-4711-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4711-KP.base_position  = 643783.390821 4027510.3592 0.0
# Actuator.2019-WTW-4711-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4711-KP.hub_height     = 90.0
# Actuator.2019-WTW-4711-KP.epsilon        = 5.0
# Actuator.2019-WTW-4711-KP.fllc           = false
# Actuator.2019-WTW-4711-KP.yaw            = 175.0
# Actuator.2019-WTW-4711-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4711-KP.num_blades     = 3
# Actuator.2019-WTW-4711-KP.use_tip_correction = true
# Actuator.2019-WTW-4711-KP.use_root_correction = true
# Actuator.2019-WTW-7912-KP.type           = UniformCtDisk
# Actuator.2019-WTW-7912-KP.base_position  = 638530.555187 4030610.81902 0.0
# Actuator.2019-WTW-7912-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-7912-KP.hub_height     = 90.0
# Actuator.2019-WTW-7912-KP.epsilon        = 5.0
# Actuator.2019-WTW-7912-KP.fllc           = false
# Actuator.2019-WTW-7912-KP.yaw            = 175.0
# Actuator.2019-WTW-7912-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-7912-KP.num_blades     = 3
# Actuator.2019-WTW-7912-KP.use_tip_correction = true
# Actuator.2019-WTW-7912-KP.use_root_correction = true
# Actuator.2019-WTW-4654-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4654-KP.base_position  = 641724.24211 4030603.28502 0.0
# Actuator.2019-WTW-4654-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4654-KP.hub_height     = 90.0
# Actuator.2019-WTW-4654-KP.epsilon        = 5.0
# Actuator.2019-WTW-4654-KP.fllc           = false
# Actuator.2019-WTW-4654-KP.yaw            = 175.0
# Actuator.2019-WTW-4654-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4654-KP.num_blades     = 3
# Actuator.2019-WTW-4654-KP.use_tip_correction = true
# Actuator.2019-WTW-4654-KP.use_root_correction = true
# Actuator.2019-WTW-4650-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4650-KP.base_position  = 639794.706255 4030635.81113 0.0
# Actuator.2019-WTW-4650-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4650-KP.hub_height     = 90.0
# Actuator.2019-WTW-4650-KP.epsilon        = 5.0
# Actuator.2019-WTW-4650-KP.fllc           = false
# Actuator.2019-WTW-4650-KP.yaw            = 175.0
# Actuator.2019-WTW-4650-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4650-KP.num_blades     = 3
# Actuator.2019-WTW-4650-KP.use_tip_correction = true
# Actuator.2019-WTW-4650-KP.use_root_correction = true
# Actuator.2019-WTW-4653-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4653-KP.base_position  = 641314.488418 4030638.52785 0.0
# Actuator.2019-WTW-4653-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4653-KP.hub_height     = 90.0
# Actuator.2019-WTW-4653-KP.epsilon        = 5.0
# Actuator.2019-WTW-4653-KP.fllc           = false
# Actuator.2019-WTW-4653-KP.yaw            = 175.0
# Actuator.2019-WTW-4653-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4653-KP.num_blades     = 3
# Actuator.2019-WTW-4653-KP.use_tip_correction = true
# Actuator.2019-WTW-4653-KP.use_root_correction = true
# Actuator.2019-WTW-4722-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4722-KP.base_position  = 644226.975274 4025657.28879 0.0
# Actuator.2019-WTW-4722-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4722-KP.hub_height     = 90.0
# Actuator.2019-WTW-4722-KP.epsilon        = 5.0
# Actuator.2019-WTW-4722-KP.fllc           = false
# Actuator.2019-WTW-4722-KP.yaw            = 175.0
# Actuator.2019-WTW-4722-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4722-KP.num_blades     = 3
# Actuator.2019-WTW-4722-KP.use_tip_correction = true
# Actuator.2019-WTW-4722-KP.use_root_correction = true
# Actuator.2019-WTW-4717-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4717-KP.base_position  = 642230.912822 4025670.90686 0.0
# Actuator.2019-WTW-4717-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4717-KP.hub_height     = 90.0
# Actuator.2019-WTW-4717-KP.epsilon        = 5.0
# Actuator.2019-WTW-4717-KP.fllc           = false
# Actuator.2019-WTW-4717-KP.yaw            = 175.0
# Actuator.2019-WTW-4717-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4717-KP.num_blades     = 3
# Actuator.2019-WTW-4717-KP.use_tip_correction = true
# Actuator.2019-WTW-4717-KP.use_root_correction = true
# Actuator.2019-WTW-4703-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4703-KP.base_position  = 645793.907141 4028042.98392 0.0
# Actuator.2019-WTW-4703-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4703-KP.hub_height     = 90.0
# Actuator.2019-WTW-4703-KP.epsilon        = 5.0
# Actuator.2019-WTW-4703-KP.fllc           = false
# Actuator.2019-WTW-4703-KP.yaw            = 175.0
# Actuator.2019-WTW-4703-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4703-KP.num_blades     = 3
# Actuator.2019-WTW-4703-KP.use_tip_correction = true
# Actuator.2019-WTW-4703-KP.use_root_correction = true
# Actuator.2019-WTW-4709-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4709-KP.base_position  = 642965.369043 4027428.24238 0.0
# Actuator.2019-WTW-4709-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4709-KP.hub_height     = 90.0
# Actuator.2019-WTW-4709-KP.epsilon        = 5.0
# Actuator.2019-WTW-4709-KP.fllc           = false
# Actuator.2019-WTW-4709-KP.yaw            = 175.0
# Actuator.2019-WTW-4709-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4709-KP.num_blades     = 3
# Actuator.2019-WTW-4709-KP.use_tip_correction = true
# Actuator.2019-WTW-4709-KP.use_root_correction = true
# Actuator.2019-WTW-4672-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4672-KP.base_position  = 644154.802531 4029911.50534 0.0
# Actuator.2019-WTW-4672-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4672-KP.hub_height     = 90.0
# Actuator.2019-WTW-4672-KP.epsilon        = 5.0
# Actuator.2019-WTW-4672-KP.fllc           = false
# Actuator.2019-WTW-4672-KP.yaw            = 175.0
# Actuator.2019-WTW-4672-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4672-KP.num_blades     = 3
# Actuator.2019-WTW-4672-KP.use_tip_correction = true
# Actuator.2019-WTW-4672-KP.use_root_correction = true
# Actuator.2019-WTW-4696-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4696-KP.base_position  = 642514.984532 4028712.33736 0.0
# Actuator.2019-WTW-4696-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4696-KP.hub_height     = 90.0
# Actuator.2019-WTW-4696-KP.epsilon        = 5.0
# Actuator.2019-WTW-4696-KP.fllc           = false
# Actuator.2019-WTW-4696-KP.yaw            = 175.0
# Actuator.2019-WTW-4696-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4696-KP.num_blades     = 3
# Actuator.2019-WTW-4696-KP.use_tip_correction = true
# Actuator.2019-WTW-4696-KP.use_root_correction = true
# Actuator.2019-WTW-4724-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4724-KP.base_position  = 646247.346919 4026321.87924 0.0
# Actuator.2019-WTW-4724-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4724-KP.hub_height     = 90.0
# Actuator.2019-WTW-4724-KP.epsilon        = 5.0
# Actuator.2019-WTW-4724-KP.fllc           = false
# Actuator.2019-WTW-4724-KP.yaw            = 175.0
# Actuator.2019-WTW-4724-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4724-KP.num_blades     = 3
# Actuator.2019-WTW-4724-KP.use_tip_correction = true
# Actuator.2019-WTW-4724-KP.use_root_correction = true
# Actuator.2019-WTW-7910-KP.type           = UniformCtDisk
# Actuator.2019-WTW-7910-KP.base_position  = 637401.036692 4031331.03992 0.0
# Actuator.2019-WTW-7910-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-7910-KP.hub_height     = 90.0
# Actuator.2019-WTW-7910-KP.epsilon        = 5.0
# Actuator.2019-WTW-7910-KP.fllc           = false
# Actuator.2019-WTW-7910-KP.yaw            = 175.0
# Actuator.2019-WTW-7910-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-7910-KP.num_blades     = 3
# Actuator.2019-WTW-7910-KP.use_tip_correction = true
# Actuator.2019-WTW-7910-KP.use_root_correction = true
# Actuator.2019-WTW-4683-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4683-KP.base_position  = 636235.526112 4027734.99562 0.0
# Actuator.2019-WTW-4683-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4683-KP.hub_height     = 90.0
# Actuator.2019-WTW-4683-KP.epsilon        = 5.0
# Actuator.2019-WTW-4683-KP.fllc           = false
# Actuator.2019-WTW-4683-KP.yaw            = 175.0
# Actuator.2019-WTW-4683-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4683-KP.num_blades     = 3
# Actuator.2019-WTW-4683-KP.use_tip_correction = true
# Actuator.2019-WTW-4683-KP.use_root_correction = true
# Actuator.2019-WTW-4737-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4737-KP.base_position  = 633734.559459 4030915.51295 0.0
# Actuator.2019-WTW-4737-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4737-KP.hub_height     = 90.0
# Actuator.2019-WTW-4737-KP.epsilon        = 5.0
# Actuator.2019-WTW-4737-KP.fllc           = false
# Actuator.2019-WTW-4737-KP.yaw            = 175.0
# Actuator.2019-WTW-4737-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4737-KP.num_blades     = 3
# Actuator.2019-WTW-4737-KP.use_tip_correction = true
# Actuator.2019-WTW-4737-KP.use_root_correction = true
# Actuator.2019-WTW-4732-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4732-KP.base_position  = 632834.785566 4032606.99043 0.0
# Actuator.2019-WTW-4732-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4732-KP.hub_height     = 90.0
# Actuator.2019-WTW-4732-KP.epsilon        = 5.0
# Actuator.2019-WTW-4732-KP.fllc           = false
# Actuator.2019-WTW-4732-KP.yaw            = 175.0
# Actuator.2019-WTW-4732-KP.thrust_coeff   = 0.6
# Actuator.2019-WTW-4732-KP.num_blades     = 3
# Actuator.2019-WTW-4732-KP.use_tip_correction = true
# Actuator.2019-WTW-4732-KP.use_root_correction = true
# Actuator.2019-WTW-4668-KP.type           = UniformCtDisk
# Actuator.2019-WTW-4668-KP.base_position  = 635372.783244 4029680.47605 0.0
# Actuator.2019-WTW-4668-KP.rotor_diameter = 127.0
# Actuator.2019-WTW-4668-KP.hub_height     = 90.0
# Actuator.2019-WTW-4668-KP.epsilon        = 5.0
# Actuator.2019-WTW-4668-KP.fllc           = false
# ...
# Actuator.2014-WTW-8363-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8363-BR.base_position  = 613265.356367 4035628.49747 0.0
# Actuator.2014-WTW-8363-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8363-BR.hub_height     = 80.0
# Actuator.2014-WTW-8363-BR.epsilon        = 5.0
# Actuator.2014-WTW-8363-BR.fllc           = false
# Actuator.2014-WTW-8363-BR.yaw            = 175.0
# Actuator.2014-WTW-8363-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8363-BR.num_blades     = 3
# Actuator.2014-WTW-8363-BR.use_tip_correction = true
# Actuator.2014-WTW-8363-BR.use_root_correction = true
# Actuator.2014-WTW-8394-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8394-BR.base_position  = 617259.133806 4034129.79243 0.0
# Actuator.2014-WTW-8394-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8394-BR.hub_height     = 80.0
# Actuator.2014-WTW-8394-BR.epsilon        = 5.0
# Actuator.2014-WTW-8394-BR.fllc           = false
# Actuator.2014-WTW-8394-BR.yaw            = 175.0
# Actuator.2014-WTW-8394-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8394-BR.num_blades     = 3
# Actuator.2014-WTW-8394-BR.use_tip_correction = true
# Actuator.2014-WTW-8394-BR.use_root_correction = true
# Actuator.2014-WTW-8393-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8393-BR.base_position  = 616926.277819 4033912.36629 0.0
# Actuator.2014-WTW-8393-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8393-BR.hub_height     = 80.0
# Actuator.2014-WTW-8393-BR.epsilon        = 5.0
# Actuator.2014-WTW-8393-BR.fllc           = false
# Actuator.2014-WTW-8393-BR.yaw            = 175.0
# Actuator.2014-WTW-8393-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8393-BR.num_blades     = 3
# Actuator.2014-WTW-8393-BR.use_tip_correction = true
# Actuator.2014-WTW-8393-BR.use_root_correction = true
# Actuator.2014-WTW-8389-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8389-BR.base_position  = 614846.296064 4033358.34948 0.0
# Actuator.2014-WTW-8389-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8389-BR.hub_height     = 80.0
# Actuator.2014-WTW-8389-BR.epsilon        = 5.0
# Actuator.2014-WTW-8389-BR.fllc           = false
# Actuator.2014-WTW-8389-BR.yaw            = 175.0
# Actuator.2014-WTW-8389-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8389-BR.num_blades     = 3
# Actuator.2014-WTW-8389-BR.use_tip_correction = true
# Actuator.2014-WTW-8389-BR.use_root_correction = true
# Actuator.2014-WTW-8369-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8369-BR.base_position  = 616207.926349 4035661.25907 0.0
# Actuator.2014-WTW-8369-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8369-BR.hub_height     = 80.0
# Actuator.2014-WTW-8369-BR.epsilon        = 5.0
# Actuator.2014-WTW-8369-BR.fllc           = false
# Actuator.2014-WTW-8369-BR.yaw            = 175.0
# Actuator.2014-WTW-8369-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8369-BR.num_blades     = 3
# Actuator.2014-WTW-8369-BR.use_tip_correction = true
# Actuator.2014-WTW-8369-BR.use_root_correction = true
# Actuator.2014-WTW-8400-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8400-BR.base_position  = 619283.538332 4033784.58428 0.0
# Actuator.2014-WTW-8400-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8400-BR.hub_height     = 80.0
# Actuator.2014-WTW-8400-BR.epsilon        = 5.0
# Actuator.2014-WTW-8400-BR.fllc           = false
# Actuator.2014-WTW-8400-BR.yaw            = 175.0
# Actuator.2014-WTW-8400-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8400-BR.num_blades     = 3
# Actuator.2014-WTW-8400-BR.use_tip_correction = true
# Actuator.2014-WTW-8400-BR.use_root_correction = true
# Actuator.2014-WTW-8392-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8392-BR.base_position  = 616565.258794 4033907.48974 0.0
# Actuator.2014-WTW-8392-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8392-BR.hub_height     = 80.0
# Actuator.2014-WTW-8392-BR.epsilon        = 5.0
# Actuator.2014-WTW-8392-BR.fllc           = false
# Actuator.2014-WTW-8392-BR.yaw            = 175.0
# Actuator.2014-WTW-8392-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8392-BR.num_blades     = 3
# Actuator.2014-WTW-8392-BR.use_tip_correction = true
# Actuator.2014-WTW-8392-BR.use_root_correction = true
# Actuator.2014-WTW-8406-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8406-BR.base_position  = 622517.852658 4034807.5572 0.0
# Actuator.2014-WTW-8406-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8406-BR.hub_height     = 80.0
# Actuator.2014-WTW-8406-BR.epsilon        = 5.0
# Actuator.2014-WTW-8406-BR.fllc           = false
# Actuator.2014-WTW-8406-BR.yaw            = 175.0
# Actuator.2014-WTW-8406-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8406-BR.num_blades     = 3
# Actuator.2014-WTW-8406-BR.use_tip_correction = true
# Actuator.2014-WTW-8406-BR.use_root_correction = true
# Actuator.2014-WTW-8366-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8366-BR.base_position  = 614874.300322 4035061.92653 0.0
# Actuator.2014-WTW-8366-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8366-BR.hub_height     = 80.0
# Actuator.2014-WTW-8366-BR.epsilon        = 5.0
# Actuator.2014-WTW-8366-BR.fllc           = false
# Actuator.2014-WTW-8366-BR.yaw            = 175.0
# Actuator.2014-WTW-8366-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8366-BR.num_blades     = 3
# Actuator.2014-WTW-8366-BR.use_tip_correction = true
# Actuator.2014-WTW-8366-BR.use_root_correction = true
# Actuator.2015-WTW-3018-BR.type           = UniformCtDisk
# Actuator.2015-WTW-3018-BR.base_position  = 618054.767477 4034912.63082 0.0
# Actuator.2015-WTW-3018-BR.rotor_diameter = 103.0
# Actuator.2015-WTW-3018-BR.hub_height     = 80.0
# Actuator.2015-WTW-3018-BR.epsilon        = 5.0
# Actuator.2015-WTW-3018-BR.fllc           = false
# Actuator.2015-WTW-3018-BR.yaw            = 175.0
# Actuator.2015-WTW-3018-BR.thrust_coeff   = 0.6
# Actuator.2015-WTW-3018-BR.num_blades     = 3
# Actuator.2015-WTW-3018-BR.use_tip_correction = true
# Actuator.2015-WTW-3018-BR.use_root_correction = true
# Actuator.2015-WTW-3017-BR.type           = UniformCtDisk
# Actuator.2015-WTW-3017-BR.base_position  = 615662.101374 4034804.93379 0.0
# Actuator.2015-WTW-3017-BR.rotor_diameter = 103.0
# Actuator.2015-WTW-3017-BR.hub_height     = 80.0
# Actuator.2015-WTW-3017-BR.epsilon        = 5.0
# Actuator.2015-WTW-3017-BR.fllc           = false
# Actuator.2015-WTW-3017-BR.yaw            = 175.0
# Actuator.2015-WTW-3017-BR.thrust_coeff   = 0.6
# Actuator.2015-WTW-3017-BR.num_blades     = 3
# Actuator.2015-WTW-3017-BR.use_tip_correction = true
# Actuator.2015-WTW-3017-BR.use_root_correction = true
# Actuator.2015-WTW-3026-BR.type           = UniformCtDisk
# Actuator.2015-WTW-3026-BR.base_position  = 622150.465206 4034088.36396 0.0
# Actuator.2015-WTW-3026-BR.rotor_diameter = 103.0
# Actuator.2015-WTW-3026-BR.hub_height     = 80.0
# Actuator.2015-WTW-3026-BR.epsilon        = 5.0
# Actuator.2015-WTW-3026-BR.fllc           = false
# Actuator.2015-WTW-3026-BR.yaw            = 175.0
# Actuator.2015-WTW-3026-BR.thrust_coeff   = 0.6
# Actuator.2015-WTW-3026-BR.num_blades     = 3
# Actuator.2015-WTW-3026-BR.use_tip_correction = true
# Actuator.2015-WTW-3026-BR.use_root_correction = true
# Actuator.2015-WTW-3023-BR.type           = UniformCtDisk
# Actuator.2015-WTW-3023-BR.base_position  = 615921.996164 4034039.74616 0.0
# Actuator.2015-WTW-3023-BR.rotor_diameter = 103.0
# Actuator.2015-WTW-3023-BR.hub_height     = 80.0
# Actuator.2015-WTW-3023-BR.epsilon        = 5.0
# Actuator.2015-WTW-3023-BR.fllc           = false
# Actuator.2015-WTW-3023-BR.yaw            = 175.0
# Actuator.2015-WTW-3023-BR.thrust_coeff   = 0.6
# Actuator.2015-WTW-3023-BR.num_blades     = 3
# Actuator.2015-WTW-3023-BR.use_tip_correction = true
# Actuator.2015-WTW-3023-BR.use_root_correction = true
# Actuator.2014-WTW-8385-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8385-BR.base_position  = 612589.150245 4033419.74629 0.0
# Actuator.2014-WTW-8385-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8385-BR.hub_height     = 80.0
# Actuator.2014-WTW-8385-BR.epsilon        = 5.0
# Actuator.2014-WTW-8385-BR.fllc           = false
# Actuator.2014-WTW-8385-BR.yaw            = 175.0
# Actuator.2014-WTW-8385-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8385-BR.num_blades     = 3
# Actuator.2014-WTW-8385-BR.use_tip_correction = true
# Actuator.2014-WTW-8385-BR.use_root_correction = true
# Actuator.2014-WTW-8408-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8408-BR.base_position  = 623655.287803 4034317.58277 0.0
# Actuator.2014-WTW-8408-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8408-BR.hub_height     = 80.0
# Actuator.2014-WTW-8408-BR.epsilon        = 5.0
# Actuator.2014-WTW-8408-BR.fllc           = false
# Actuator.2014-WTW-8408-BR.yaw            = 175.0
# Actuator.2014-WTW-8408-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8408-BR.num_blades     = 3
# Actuator.2014-WTW-8408-BR.use_tip_correction = true
# Actuator.2014-WTW-8408-BR.use_root_correction = true
# Actuator.2014-WTW-8421-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8421-BR.base_position  = 621582.671981 4035558.71118 0.0
# Actuator.2014-WTW-8421-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8421-BR.hub_height     = 80.0
# Actuator.2014-WTW-8421-BR.epsilon        = 5.0
# Actuator.2014-WTW-8421-BR.fllc           = false
# Actuator.2014-WTW-8421-BR.yaw            = 175.0
# Actuator.2014-WTW-8421-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8421-BR.num_blades     = 3
# Actuator.2014-WTW-8421-BR.use_tip_correction = true
# Actuator.2014-WTW-8421-BR.use_root_correction = true
# Actuator.2014-WTW-8367-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8367-BR.base_position  = 615271.862721 4034937.29806 0.0
# Actuator.2014-WTW-8367-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8367-BR.hub_height     = 80.0
# Actuator.2014-WTW-8367-BR.epsilon        = 5.0
# Actuator.2014-WTW-8367-BR.fllc           = false
# Actuator.2014-WTW-8367-BR.yaw            = 175.0
# Actuator.2014-WTW-8367-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8367-BR.num_blades     = 3
# Actuator.2014-WTW-8367-BR.use_tip_correction = true
# Actuator.2014-WTW-8367-BR.use_root_correction = true
# Actuator.2014-WTW-8412-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8412-BR.base_position  = 622836.819948 4033341.71421 0.0
# Actuator.2014-WTW-8412-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8412-BR.hub_height     = 80.0
# Actuator.2014-WTW-8412-BR.epsilon        = 5.0
# Actuator.2014-WTW-8412-BR.fllc           = false
# Actuator.2014-WTW-8412-BR.yaw            = 175.0
# Actuator.2014-WTW-8412-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8412-BR.num_blades     = 3
# Actuator.2014-WTW-8412-BR.use_tip_correction = true
# Actuator.2014-WTW-8412-BR.use_root_correction = true
# Actuator.2014-WTW-8399-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8399-BR.base_position  = 618897.651527 4033592.64506 0.0
# Actuator.2014-WTW-8399-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8399-BR.hub_height     = 80.0
# Actuator.2014-WTW-8399-BR.epsilon        = 5.0
# Actuator.2014-WTW-8399-BR.fllc           = false
# Actuator.2014-WTW-8399-BR.yaw            = 175.0
# Actuator.2014-WTW-8399-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8399-BR.num_blades     = 3
# Actuator.2014-WTW-8399-BR.use_tip_correction = true
# Actuator.2014-WTW-8399-BR.use_root_correction = true
# Actuator.2014-WTW-8402-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8402-BR.base_position  = 620962.836196 4033865.50794 0.0
# Actuator.2014-WTW-8402-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8402-BR.hub_height     = 80.0
# Actuator.2014-WTW-8402-BR.epsilon        = 5.0
# Actuator.2014-WTW-8402-BR.fllc           = false
# Actuator.2014-WTW-8402-BR.yaw            = 175.0
# Actuator.2014-WTW-8402-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8402-BR.num_blades     = 3
# Actuator.2014-WTW-8402-BR.use_tip_correction = true
# Actuator.2014-WTW-8402-BR.use_root_correction = true
# Actuator.2014-WTW-8415-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8415-BR.base_position  = 624069.535136 4033330.47022 0.0
# Actuator.2014-WTW-8415-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8415-BR.hub_height     = 80.0
# Actuator.2014-WTW-8415-BR.epsilon        = 5.0
# Actuator.2014-WTW-8415-BR.fllc           = false
# Actuator.2014-WTW-8415-BR.yaw            = 175.0
# Actuator.2014-WTW-8415-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8415-BR.num_blades     = 3
# Actuator.2014-WTW-8415-BR.use_tip_correction = true
# Actuator.2014-WTW-8415-BR.use_root_correction = true
# Actuator.2014-WTW-8370-BR.type           = UniformCtDisk
# Actuator.2014-WTW-8370-BR.base_position  = 616523.313051 4035548.67557 0.0
# Actuator.2014-WTW-8370-BR.rotor_diameter = 103.0
# Actuator.2014-WTW-8370-BR.hub_height     = 80.0
# Actuator.2014-WTW-8370-BR.epsilon        = 5.0
# Actuator.2014-WTW-8370-BR.fllc           = false
# Actuator.2014-WTW-8370-BR.yaw            = 175.0
# Actuator.2014-WTW-8370-BR.thrust_coeff   = 0.6
# Actuator.2014-WTW-8370-BR.num_blades     = 3
# Actuator.2014-WTW-8370-BR.use_tip_correction = true
# Actuator.2014-WTW-8370-BR.use_root_correction = true
#
# #---- extra params ----
# #== END AMR-WIND INPUT ==
