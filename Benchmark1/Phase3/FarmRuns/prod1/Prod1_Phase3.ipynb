# %% [markdown]
# # Production Run 1 (new BC)

# %%
# Load the modules

# Add any possible locations of amr-wind-frontend here
amrwindfedirs = ['/projects/wind_uq/lcheung/amrwind-frontend/',
                 '/ccs/proj/cfd162/lcheung/amrwind-frontend/']
import sys, os, shutil
for x in amrwindfedirs: sys.path.insert(1, x)
import MMCutil as writeMMC
import postproamrwindsample_xarray as ppsamplexr

# Load the libraries
import numpy as np
import pandas as pd
import re
import utm
import amrwind_frontend as amrwind
import matplotlib.pyplot    as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import CubicSpline

# Also ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Make all plots inline 
# %matplotlib inline
# Out:
# /ascldap/users/lcheung/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /ascldap/users/lcheung/.local/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %% [markdown]
# ## Set up measurement coordinates

# %%
def dms2dec(lat):
    deg, minutes, seconds, direction =  re.split('[°\'"]', lat.strip())
    return (float(deg) + float(minutes)/60 + float(seconds)/(60*60)) * (-1 if direction in ['W', 'S'] else 1)

# %%
# Get the UTM coordinates of all measurement locations
mdict = {
    'siteA1':{'lat':dms2dec("""36°21'43.6"N"""), 'long':dms2dec("""97°24'16.4"W""")},
    #'siteA2':{'lat':dms2dec("""36°19'05.5"N"""), 'long':dms2dec("""97°24'32.7"W""")},  # outside of domain
    'siteA5':{'lat':dms2dec("""36°21'42.5"N"""), 'long':dms2dec("""97°22'53.8"W""")},
    #'siteB':  {'lat':dms2dec("""36°13'54.4"N"""), 'long':dms2dec("""97°33'31.2"W""")},
    #'siteE36':{'lat':dms2dec("""36°07'01.0"N"""), 'long':dms2dec("""97°30'39.2"W""")},
    'siteC1a': {'lat':dms2dec("""36°21'41.8"N"""), 'long':dms2dec("""97°30'36.1"W""")},
    'siteG':{'lat':dms2dec("""36°23'58.1"N"""), 'long':dms2dec("""97°24'28.9"W""")},
    'siteGC':{'lat':dms2dec("""36°22'47.09"N"""), 'long':dms2dec("""97°31'24.51"W""")},
    'siteH':{'lat':dms2dec("""36°26'12.7"N"""), 'long':dms2dec("""97°24'27.9"W""")},
    'turbE06':{'lat':dms2dec("""36°24'39.708"N"""), 'long':dms2dec("""97°24'21.24"W""")},
}

# Convert to UTM coordinates
for k,g in mdict.items():
    g['utm']  = utm.from_latlon(g['lat'], g['long'])
    g['utmx'] = g['utm'][0]
    g['utmy'] = g['utm'][1]

# %%
inputfile = 'FarmRun3_01.inp'
runOnSummit = False
rundir = 'BM3_FarmRunProd1_runA'

# Go to the run directory

# Delete any existing directory
if os.path.exists(rundir):
    shutil.rmtree(rundir)

# create a new version
os.makedirs(rundir)

cwd = os.getcwd()
os.chdir(rundir)

# %%
# Start the AMR-Wind case
case = amrwind.MyApp.init_nogui()

# %%
# Location of precursor run with boundary data
#summitprecursordir = '/gpfs/alpine2/cli187/world-shared/lcheung/AWAKEN/Benchmark1/Phase1/MMC_BM1_BigPrecursor.prod/'

#precursordir  = '/gpfs/lcheung/AWAKEN/Benchmark1/Phase2/MMC/MMC_BM2_BigPrecursor/'
precursordir  = '/tscratch/lcheung/AWAKEN/Benchmark1/Phase3/MMC/MMC_BM3_BigPrecursor'
precursorsetup= precursordir+'/abl_HPP_MMC.inp'

# Load the starting point
case.loadAMRWindInput(precursorsetup)
# Out:
# CANNOT update: ABLMeanBoussinesq use forcechange=True in setval()
# OrderedDict()

# %%
#case.setAMRWindInput('time_control', ['const dt'])
case.setAMRWindInput('time.fixed_dt',  0.10)
case.setAMRWindInput('time.checkpoint_interval', 900)
case.setAMRWindInput('time.stop_time', 7200+5400.0)
case.setAMRWindInput('ABL.stats_output_frequency', 10)

# %%
# Set the restart point
chkiter = '/chk14400/'
chkdir = precursordir+chkiter
case.setAMRWindInput('restart_file', os.path.realpath(chkdir))

# %%
# Set the boundary input file parameters
ablstatfile = precursordir+'/post_processing/abl_statistics00000.nc'
forcingdict = {'ablstatfile':ablstatfile, 'tendencyforcing_file':'./tendencyforcing.nc'}
inflowplanes= ['xlo', 'ylo', 'xhi','yhi' ] #['ylo', 'xhi']
bndryfiles  = precursordir+'/bndry_file/'

# %%
case.boundaryplane_restart(bndryfiles=bndryfiles, 
                           forcingdict=forcingdict, 
                           inflowplanes=inflowplanes, 
                           checkpointdir=chkdir,
                           autoset_BodyForcing=False,
                           autoset_MMCForcing=False,
                           autoset_MMCTendencyForcing=True,
                           autooutflow=False,
                           massinflowBC='mass_inflow_outflow',
                           verbose=True)
# Out:
# SET ABL_bndry_io_mode = '1'
# SET ABL_bndry_file = '/tscratch/lcheung/AWAKEN/Benchmark1/Phase3/MMC/MMC_BM3_BigPrecursor/bndry_file/'
# SET ABL_bndry_planes = ['xlo', 'ylo', 'xhi', 'yhi']
# SET is_periodicx = False
# SET is_periodicy = False
# SET xlo_type = 'mass_inflow_outflow'
# SET xlo_density = 1.103707
# SET xlo_temperature = 0.0
# SET xlo_tke = 0.0
# SET ylo_type = 'mass_inflow_outflow'
# SET ylo_density = 1.103707
# SET ylo_temperature = 0.0
# SET ylo_tke = 0.0
# SET xhi_type = 'mass_inflow_outflow'
# SET xhi_density = 1.103707
# SET xhi_temperature = 0.0
# SET xhi_tke = 0.0
# SET yhi_type = 'mass_inflow_outflow'
# SET yhi_density = 1.103707
# SET yhi_temperature = 0.0
# SET yhi_tke = 0.0
# SET ABLForcing = False
# Wrote ./tendencyforcing.nc
# SET ABL_tendency_forcing = True
# SET ABL_mesoscale_forcing = './tendencyforcing.nc'
# SET ABLMesoForcingMom = True
# SET ABL_initial_condition_input_file = 'None'
# SET ABLMeanBoussinesq = True
# SET wall_shear_stress_type = 'local'
# SET checkpoint_start = 14400

# %% [markdown]
# ## Add Turbines

# %%
WS     = 10.05         # Wind speed, m/s
WDir   = 180           # Wind direction, degrees
farm_domainsize = [2.4*10000.0, 1.76*10000.0, 800]
farm_center     = [637500, 4.030E6]   # In utm
#print(utm.from_latlon(36.587395, -97.756294))
#farm_center          = utm.to_latlon(640000, 4030000, 14, 'S')
print("Farm center = "+repr(farm_center)) # in lat/long
farm_background_mesh = 10
# Out:
# Farm center = [637500, 4030000.0]

# %%
summitcsv = precursordir+'/turbines.csv'
outputcsv = 'turbines_farmrun.csv'

inityaw = 155.25
initAFyaw = 155.25 #221.3  # See MMC_BM2_bigprecursor_ABLStats.ipynb
YawNeut = 270.0-inityaw
typereplace = {'Summit_GE2.8-127':'NREL 2.8-127 ADM AWAKEN',
               'Summit_GE1.79-100':'NREL GE1.79-100 Joukowski Jul2024',
               'Summit_GE2.3-116':'NREL GE2.3-116v2 Joukowski Jul2024',
               'Summit_GE1.7-103':'NREL GE1.72-103 Joukowski Jul2024',
}

OFoptions = (
    "EDparam_YawDOF:False "
    "AMRparam_Actuator_openfast_stop_time:5400.0 "
    "FSTparam_DT_Out:0.5 "   #"FSTparam_DT_Out:1 "
    "FSTparam_TStart:0.0 "
    "ADparam_AirDens:Default "
    "EDparam_BlPitch(1):0.0 "
    "EDparam_BlPitch(2):0.0 "
    "EDparam_BlPitch(3):0.0 "
)

YAWoptions = (
    "EDparam_YawDOF:True "
    "SDparam_YawNeut:{YawNeut} "
    "SDparam_YCMode:5 "
    "SDparam_TYCOn:0.0 "
    "DISCONparam_Y_ControlMode:1 "
    "DISCONparam_Y_ErrThresh:'4.0 4.0' "
    "DISCONparam_WE_RhoAir:1.103707 "
)

OFoptions += YAWoptions.format(YawNeut=YawNeut)

if runOnSummit:
    OFoptions += "SDparam_DLL_FileName:/gpfs/alpine2/cli187/world-shared/lcheung/summit.spackbuilds/ew-mananger.20241017/ROSCO_2.9/rosco/controller/build/libdiscon.so "

JDiskoptions = (
    "AMRparam_Actuator_epsilon:[5;5;5] "
    "AMRparam_Actuator_output_frequency:1 "
)

# %%
# Process the csv file
df = pd.read_csv(summitcsv)

# Fix the turbine types of the turbines
for index, row in df.iterrows():
    
    turbtype = df.loc[index, ' type']
    df.loc[index, ' type'] = typereplace[turbtype.strip()]
    if turbtype.strip() == "Summit_GE2.8-127":
        df.loc[index, ' options'] = OFoptions
        df.loc[index, ' yaw']=inityaw
    else:
        df.loc[index, ' options'] = JDiskoptions
        df.loc[index, ' yaw']=initAFyaw
    
df.to_csv(outputcsv, index=False)
#print(df)
#    if row['turbine_qc_id'].startswith('WIT_USKPL_SS001'):
#        df.loc[index, 'Unnamed: 0']='King Plains'
#    if row['turbine_qc_id'].startswith('WAF1'):
#        df.loc[index, 'Unnamed: 0']='Armadillo Flats'

# %%
print('Total turbines: %i'%len(df))
# Out:
# Total turbines: 85

# %%
case.loadTurbineCSVFile(outputcsv)

# %%
case.setAMRWindInput('turbines_coordsys', 'utm')

## Set up the domain 
case.setAMRWindInput('turbines_domainsize',         farm_domainsize)
case.setAMRWindInput('turbines_backgroundmeshsize', farm_background_mesh)
case.setAMRWindInput('turbines_autocalccenter',     False)
case.setAMRWindInput('turbines_farmcenter',         [farm_center[0], farm_center[1]])
case.setAMRWindInput('turbines_deleteprev', True)

# %%
# Preview the turbine layout
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=125)
case.setAMRWindInput('turbines_plotnames', False)
#case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
case.turbines_previewAllTurbines(ax=ax)

#rect = patches.Rectangle((turb_inside_box[0][0], turb_inside_box[1][0]), 
#                         turb_inside_box[0][1]-turb_inside_box[0][0], 
#                         turb_inside_box[1][1]-turb_inside_box[1][0], linewidth=1, edgecolor='k', linestyle='--', facecolor='none')
#ax.add_patch(rect)

# Plot measurement sites
for k, g in mdict.items():
    ax.plot(g['utmx'], g['utmy'], 'r^')

# %% [markdown]
# ### Add turbines

# %%
case.turbines_createAllTurbines()

# Print out existing list of turbines, just to confirm that the turbines got made
print(len(case.listboxpopupwindict['listboxactuator'].getitemlist()))
# Out:
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT001_OpenFAST_NREL2p8-127_AWAKEN
# WIT_USKPL_SS001_WT001_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT001_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT002_OpenFAST_NREL2p8-127_AWAKEN
# WIT_USKPL_SS001_WT002_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT002_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT003_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT003_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT003_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT004_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT004_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT004_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT005_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT005_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT005_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT006_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT006_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT006_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT007_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT007_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT007_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT008_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT008_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT008_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT009_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT009_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT009_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT010_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT010_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT010_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT012_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT012_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT012_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT013_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT013_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT013_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT014_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT014_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT014_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT015_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT015_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT015_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT016_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT016_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT016_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT017_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT017_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT017_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT018_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT018_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT018_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT019_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT019_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT019_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT020_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT020_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT020_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT021_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT021_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT021_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT022_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT022_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT022_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT023_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT023_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT023_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT024_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
# ...
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT082_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT082_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT083_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT083_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT083_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT084_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT084_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT084_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT085_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT085_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT085_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT086_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT086_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT086_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT087_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT087_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT087_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# docopy = True from /projects/wind_uq/lcheung/amrwind-frontend/turbines/OpenFAST_NREL2p8-127_AWAKEN to WIT_USKPL_SS001_WT088_OpenFAST_NREL2p8-127_AWAKEN
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]
# WIT_USKPL_SS001_WT088_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst
# Fixing yaw in /projects/AWAKEN/lcheung/awaken.github/SummitRuns/AWAKEN_summit_setup/Benchmark1/Phase3/FarmRuns/prod1/BM3_FarmRunProd1_runA/WIT_USKPL_SS001_WT088_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_ElastoDyn.dat
# MISMATCH between incflo.density = 1.103707 and OpenFAST density = 1.225000
# USING incflo value
# Setting Actuator_openfast_stop_time to 5400.0
# OrderedDict([('DT_Out', 0.5), ('TStart', 0.0)])
# OrderedDict([('AirDens', 'Default')])
# OrderedDict([('YawNeut', 114.75), ('YCMode', 5), ('TYCOn', 0.0)])
# OrderedDict([('YawDOF', 'True'), ('BlPitch(1)', 0.0), ('BlPitch(2)', 0.0), ('BlPitch(3)', 0.0)])
# OrderedDict([('Y_ControlMode', 1), ('Y_ErrThresh', '4.0 4.0'), ('WE_RhoAir', 1.103707)])
# 85
#     114.75 NacYaw - Initial or fixed nacelle-yaw angle (degrees) [EDITED]
#   1.103707 AirDens - Air density (kg/m^3) [EDITED]
#        0.5 DT_Out - Time step for tabular output (s) (or "default") [EDITED]
#        0.0 TStart - Time to begin tabular output (s) [EDITED]
#    Default AirDens - Air density (kg/m^3) [EDITED]
#          5 YCMode - Yaw control mode {0: none 3: user-defined from routine UserYawCont 4: user-defined from Simulink/Labview 5: user-defined from Bladed-style DLL} (switch) [EDITED]
#        0.0 TYCOn - Time to enable active yaw control (s) [unused when YCMode=0] [EDITED]
#     114.75 YawNeut - Neutral yaw position--yaw spring force is zero at this yaw (degrees) [EDITED]
#       True YawDOF - Yaw DOF (flag) [EDITED]
#        0.0 BlPitch(1) - Blade 1 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(2) - Blade 2 initial pitch (degrees) [EDITED]
#        0.0 BlPitch(3) - Blade 3 initial pitch (degrees) [unused for 2 blades] [EDITED]
# 1 ! Y_ControlMode   - Yaw control mode {0: no yaw control, 1: yaw rate control, 2: yaw-by-IPC} [EDITED]
# 1.103707 ! WE_RhoAir			- Air density, [kg m^-3] [EDITED]
# 4.0 4.0 ! Y_ErrThresh    - Yaw error threshold/deadbands. Turbine begins to yaw when it passes this. If Y_uSwitch is zero, only the second value is used. [deg]. [EDITED]

# %% [markdown]
# ## Add refinements

# %%
refinementcsv="""
# CSV file should have columns with
# level, upstream, downstream, lateral, below, above, options
level, upstream, downstream, lateral, below, above, options
#0,     13800,    15000,      18500,  100,  250,      center:farm units:meter
# KP
#0,     4250,    4200,      9500,  100,  75, center:specified units:meter centerx:638500 centery:4029000 centerz:100
0,     4250,    3500,      4750,  100,  75, center:specified units:meter centerx:643000 centery:4029000 centerz:100 orientation:180
0,     2700,    4200,      4750,  100,  75, center:specified units:meter centerx:634000 centery:4029000 centerz:100 orientation:180

# AF
#0,     4000,    6000,      5000,  100,  350, center:specified units:meter centerx:632000 centery:4018000 centerz:100   
#0,     4000,    3000,      7000,  100,  350, center:specified units:meter centerx:618000 centery:4035000 centerz:100

# Turbine refinement
#1,     2.0,    2.0,     2.0,    0.525, 0.525, orientation:nacdir
1,     0.6,    0.6,     0.6,    0.525, 0.525, orientation:nacdir
"""
case.setAMRWindInput('refine_csvtextbox', refinementcsv)
case.setAMRWindInput('refine_deleteprev', True)

# %%
case.refine_createAllZones()

# %%
# Plot the domain (total domain)
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=150)
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
case.plotDomain(ax=ax)
ax.axis('scaled')
# Out:
# (624300.0, 650700.0, 4020320.0, 4039680.0)

# %%
# Plot the domain (total domain)
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=150)
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = True
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XZ'
case.plotDomain(ax=ax)
ax.axis('auto')
# Out:
# (624300.0, 650700.0, -40.0, 840.0)

# %%
# Estimate mesh size
case.estimateMeshSize(verbose=False)
# Out:
# ESTIMATED MESH SIZE
#    Level       Ncells                      Cell Size
#        0    337920000             10.0 x 10.0 x 10.0
#        1    194845000                5.0 x 5.0 x 5.0
#        2     16848445                2.5 x 2.5 x 2.5
#   TOTAL:    549613445

# %% [markdown]
# ### Add metmast/lidar sampling

# %%
# Set up averaging

## Surface measurements
metmastpprosetup = case.get_default_postprosetupdict()
metmastpprosetup['postprocessing_setup_name'] = 'surf_'
metmastpprosetup['postprocessing_setup_type'] = 'Sampling'
metmastpprosetup['postprocessing_setup_output_frequency'] =  1
metmastpprosetup['postprocessing_setup_fields']           =  ['velocity', 'temperature', 'tke']
case.add_postprosetup(metmastpprosetup, verbose=True)

## Lidar measurements
metmastpprosetup = case.get_default_postprosetupdict()
metmastpprosetup['postprocessing_setup_name'] = 'lidar_'
metmastpprosetup['postprocessing_setup_type'] = 'Sampling'
metmastpprosetup['postprocessing_setup_output_frequency'] =  1
metmastpprosetup['postprocessing_setup_fields']           =  ['velocity', 'temperature', 'tke']
case.add_postprosetup(metmastpprosetup, verbose=True)

### Lidar measurements
#metmastpprosetup = case.get_default_postprosetupdict()
#metmastpprosetup['postprocessing_setup_name'] = 'tprof_'
#metmastpprosetup['postprocessing_setup_type'] = 'Sampling'
#metmastpprosetup['postprocessing_setup_output_frequency'] =  1
#metmastpprosetup['postprocessing_setup_fields']           =  ['velocity', 'temperature', 'tke']
#case.add_postprosetup(metmastpprosetup, verbose=True)
# Out:
# postprocessing_setup_name: 'surf_'
# postprocessing_setup_type: 'Sampling'
# postprocessing_setup_output_frequency: 1
# postprocessing_setup_fields: ['velocity', 'temperature', 'tke']
# postprocessing_setup_derived_fields: None
# postprocessing_setup_averaging_window: None
# postprocessing_setup_averaging_start_time: None
# postprocessing_setup_averaging_stop_time: None
# postprocessing_setup_name: 'lidar_'
# postprocessing_setup_type: 'Sampling'
# postprocessing_setup_output_frequency: 1
# postprocessing_setup_fields: ['velocity', 'temperature', 'tke']
# postprocessing_setup_derived_fields: None
# postprocessing_setup_averaging_window: None
# postprocessing_setup_averaging_start_time: None
# postprocessing_setup_averaging_stop_time: None

# %%
print(case.listboxpopupwindict['listboxsampling'].getitemlist())
print(case.listboxpopupwindict['listboxpostprosetup'].getitemlist())
# Out:
# ['Farm_sw1', 'Farm_hh']
# ['sw_', 'hubheight_', 'surf_', 'lidar_']

# %%
# Add surface measurement outputs
for name in ['siteA1', 'siteA5']:
    sampledict = case.get_default_samplingdict()
    sampledict['sampling_name']     = 'surface_'+name
    sampledict['sampling_outputto'] = 'surf_'
    sampledict['sampling_type']     = 'LineSampler'
    sampledict['sampling_l_num_points'] = 2
    sampledict['sampling_l_start']      = [mdict[name]['utmx'], mdict[name]['utmy'], 4.0]
    sampledict['sampling_l_end']        = [mdict[name]['utmx'], mdict[name]['utmy'], 10.0]
    case.add_sampling(sampledict, verbose=False)
    
for name in ['siteA1',  'siteC1a', 'siteH', 'siteG', 'siteGC']:  # Not available: 'siteB', 'siteE36',
    sampledict = case.get_default_samplingdict()
    sampledict['sampling_name']     = 'lidar_'+name
    sampledict['sampling_outputto'] = 'lidar_'
    sampledict['sampling_type']     = 'LineSampler'
    sampledict['sampling_l_num_points'] = 79
    sampledict['sampling_l_start']      = [mdict[name]['utmx'], mdict[name]['utmy'], 10.0]
    sampledict['sampling_l_end']        = [mdict[name]['utmx'], mdict[name]['utmy'], 790.0]
    case.add_sampling(sampledict, verbose=False)
    
# Add surface wake measurements
for name in ['siteC1a', 'siteG', 'siteH']:
    sampledict = case.get_default_samplingdict()
    sampledict['sampling_name']     = 'surface_'+name
    sampledict['sampling_outputto'] = 'surf_'
    sampledict['sampling_type']     = 'LineSampler'
    sampledict['sampling_l_num_points'] = 2
    sampledict['sampling_l_start']      = [mdict[name]['utmx'], mdict[name]['utmy'], 4.0]
    sampledict['sampling_l_end']        = [mdict[name]['utmx'], mdict[name]['utmy'], 10.0]
    case.add_sampling(sampledict, verbose=False)

# %%
outputoptions="outputvars:velocity;tke;temperature outputfreq:10"

#centerx, centery = 637500, 4025000.0
centerx, centery = 639000, 4029000
AFcenterx, AFcentery = 632000, 4018000
## Add E06 Wake sampling
samplingcsv = """
# CSV file should have columns withturbinescsv=
# name, type, upstream, downstream, lateral, below, above, n1, n2, options
name, type, upstream, downstream, lateral, below, above, n1, n2, options
E06wake27,  hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:27   orientation:y outputto:E06wake_z27_ {outputoptions} 
E06wake59,  hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:59   orientation:y outputto:E06wake_z59_ {outputoptions} 
E06wake90,  hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:90.5 orientation:y outputto:E06wake_z90_ {outputoptions} 
E06wake122, hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:122  orientation:y outputto:E06wake_z122_ {outputoptions} 
E06wake154, hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:154  orientation:y outputto:E06wake_z154_ {outputoptions} 
E06wake217, hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:217.5  orientation:y outputto:E06wake_z217_ {outputoptions} 
E06wake281, hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:281  orientation:y outputto:E06wake_z281_ {outputoptions} 
E06wake344, hubheight, 0, 4000.5, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:344.5  orientation:y outputto:E06wake_z344_ {outputoptions} 
""".format(outputoptions=outputoptions, dx=12.7, centerx=mdict['turbE06']['utmx'], centery=mdict['turbE06']['utmy'])
#print(samplingcsv)

samplingcsv += """
# CSV file should have columns withturbinescsv=
# name, type, upstream, downstream, lateral, below, above, n1, n2, options
allhh,  hubheight, {up}, {down}, {lateral}, 0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:90 orientation:y  wholedomain:1 outputto:all_z90_ {outputoptions} 
hh90,  hubheight, {up}, {down}, {lateral}, 0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:90 orientation:y   outputto:farm_z90_ {outputoptions} 
hh153,  hubheight, {up}, {down}, {lateral}, 0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:153 orientation:y outputto:farm_z153_ {outputoptions} 
""".format(centerx=centerx, centery=centery, up=6000, down=6000, lateral=9300, dx=200, outputoptions=outputoptions)

samplingcsv += """
# King plains inflow/outflow
KP500, hubheight,  6000,  7000, 10000,  0, none, 0, 0,              usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:500 outputto:KP_z500hh_  orientation:180.0 {outputoptions}
KP153, hubheight,  6000,  7000, 10000,  0, none, 0, 0,              usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:153 outputto:KP_z153hh_  orientation:180.0 {outputoptions}
KP090, hubheight,  6000,  7000, 10000,  0, none, 0, 0,              usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:90 outputto:KP_z090hh_   orientation:180.0 {outputoptions}
KP026, hubheight,  6000,  7000, 10000,  0, none, 0, 0,              usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:26 outputto:KP_z026hh_   orientation:180.0 {outputoptions}

#KP_sideplane1, streamwise, 6000, 7000,  10000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:KP_sideplane1_ noffsets:2 orientation:180.0 {outputoptions}
#KP_sideplane2, streamwise, 6000, 7000, -10000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:KP_sideplane2_ noffsets:2 orientation:180.0 {outputoptions}
#KP_ioflow1,  rotorplane,   6000, 7000,  10000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:KP_inflow1_    noffsets:4 orientation:180.0 {outputoptions}

KP_sideplane1o, streamwise, 5000, 7000,  7000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:KP_sideplane1o_ noffsets:2 orientation:{inityaw} {outputoptions}
KP_sideplane2o, streamwise, 5000, 7000, -7000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:KP_sideplane2o_ noffsets:2 orientation:{inityaw} {outputoptions}
KP_ioflow1o,  rotorplane,   5000, 7000,  7000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:KP_inflow1o_    noffsets:4 orientation:{inityaw} {outputoptions}
""".format(centerx=centerx, centery=centery,outputoptions=outputoptions, inityaw=inityaw)

#samplingcsv += """
## Armadillo flats inflow/outflow
#AF090,      hubheight,  4000,   8000, 5000,  0, none, 0, 0,      usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:90 outputto:AF_z090hh_   orientation:180.0 {outputoptions}
#AF_ioflow1, rotorplane, 4000,   8000, 5000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:AF_inflow1_    noffsets:4 orientation:180.0 {outputoptions}
#AF_sideplane1, streamwise, 4000, 8000,  5000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:AF_sideplane1_ noffsets:2 orientation:180.0 {outputoptions}
#AF_sideplane2, streamwise, 4000, 8000, -5000,  100, 400, 0, 0,     usedx:20 units:meter center:specified centerx:{centerx} centery:{centery} centerz:100.1 outputto:AF_sideplane2_ noffsets:2 orientation:180.0 {outputoptions}
#""".format(centerx=AFcenterx, centery=AFcentery,outputoptions=outputoptions, inityaw=inityaw)

samplingcsv += """
# CSV file should have columns withturbinescsv=
# name, type, upstream, downstream, lateral, below, above, n1, n2, options
KPturbhh,  hubheight, 1020, 1020,       760,     0,     0,     11, 11, usedx:10 units:meter outputto:KPturbhh_ orientation:nacdir outputvars:velocity   applyto:WIT_USKPL_* {outputoptions}
KPsw,     streamwise, 1020, 1020,       0,       80,    380,   11, 11, usedx:10 units:meter outputto:KPsw_     orientation:nacdir outputvars:velocity    applyto:WIT_USKPL_* {outputoptions}
KProtor,  rotorplane, 1020, 1020,       760,     ,      380,   11, 11, usedx:10 units:meter outputto:KProtor_  orientation:nacdir outputvars:velocity noffsets:8   applyto:WIT_USKPL_* {outputoptions}
""".format(outputoptions=outputoptions)

# %%
# heights at 
print(127/4.0*np.array([-2, -1.5, -1, -0.5, 0,0.5,1,1.5,2,2.5,3,3.5,4])+90.5)
# Out:
# [ 27.     42.875  58.75   74.625  90.5   106.375 122.25  138.125 154.
#  169.875 185.75  201.625 217.5  ]

# %%
# Add H05 scanning lidars (optional)
H05centerx, H05centery = 643049.78, 4025582.41
#samplingcsv += """
XXXsamplingcsvXXXX = """
# CSV file should have columns withturbinescsv=
# name, type, upstream, downstream, lateral, below, above, n1, n2, options
H05wake27,  hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:27    orientation:y outputto:H05wake_z27_ {outputoptions} 
H05wake43,  hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:42.875 orientation:y outputto:H05wake_z43_ {outputoptions} 
H05wake59,  hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:59    orientation:y outputto:H05wake_z59_ {outputoptions} 
H05wake75,  hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:74.625 orientation:y outputto:H05wake_z75_ {outputoptions} 
H05wake90,  hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:90.5  orientation:y outputto:H05wake_z90_ {outputoptions} 
H05wake106, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:106.375 orientation:y outputto:H05wake_z106_ {outputoptions} 
H05wake122, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:122       orientation:y outputto:H05wake_z122_ {outputoptions} 
H05wake138, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:138.125   orientation:y outputto:H05wake_z138_ {outputoptions} 
H05wake154, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:154       orientation:y outputto:H05wake_z154_ {outputoptions} 
H05wake170, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:169.875   orientation:y outputto:H05wake_z170_ {outputoptions} 
H05wake186,  hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:185.75   orientation:y outputto:H05wake_z186_ {outputoptions} 
H05wake202,  hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:201.625  orientation:y outputto:H05wake_z202_ {outputoptions} 
H05wake217, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:217.5 orientation:y outputto:H05wake_z217_ {outputoptions} 
H05wake281, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:281   orientation:y outputto:H05wake_z281_ {outputoptions} 
H05wake344, hubheight, 2000.25, 2000.25, 2540,    0,  none,  11, 11, usedx:{dx} units:meter center:specified centerx:{centerx} centery:{centery} centerz:344.5 orientation:y outputto:H05wake_z344_ {outputoptions} 
""".format(outputoptions=outputoptions, dx=12.7, centerx=H05centerx, centery=H05centery)
#print(samplingcsv)

# %%
case.setAMRWindInput('sampling_csvtextbox', samplingcsv)
case.setAMRWindInput('sampling_deleteprev', False)

case.sampling_createAllProbes(verbose=False)

# %%
KPturbhh = [x for x in case.listboxpopupwindict['listboxsampling'].getitemlist() if x.endswith('_KPturbhh') ]
KPsw     = [x for x in case.listboxpopupwindict['listboxsampling'].getitemlist() if x.endswith('_KPsw') ]
KProtor  = [x for x in case.listboxpopupwindict['listboxsampling'].getitemlist() if x.endswith('_KProtor') ]
lidarsam = [x for x in case.listboxpopupwindict['listboxsampling'].getitemlist() if x.startswith('lidar') ]
KPIO     = [x for x in case.listboxpopupwindict['listboxsampling'].getitemlist() if x.startswith('Farm_KP') ]
E06wake  = [x for x in case.listboxpopupwindict['listboxsampling'].getitemlist() if x.startswith('Farm_E06') ]
H05wake  = [x for x in case.listboxpopupwindict['listboxsampling'].getitemlist() if x.startswith('Farm_H05') ]

# %%
print(E06wake)
print(H05wake)
# Out:
# ['Farm_E06wake27', 'Farm_E06wake59', 'Farm_E06wake90', 'Farm_E06wake122', 'Farm_E06wake154', 'Farm_E06wake217', 'Farm_E06wake281', 'Farm_E06wake344']
# []

# %%
# Plot the domain
fig, ax = plt.subplots(figsize=(7,7), facecolor='w', dpi=125)

# Set any additional items to plot
#case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':0.1, 'marker':'.', 'linestyle':'None', }"
#case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{'title':'Sampling probes', 'fontsize':6, 'loc':'upper right', 'markerscale':6}"


case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{'title':'Sampling probes', 'fontsize':6, 'loc':'upper right', 'markerscale':2}"
#case.popup_storteddata['plotdomain']['plot_sampleprobes']    = KPturbhh[-10:] + KPsw[-10:] + KProtor[-10:] 
#case.popup_storteddata['plotdomain']['plot_sampleprobes']    = E06wake
case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':5, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = lidarsam #case.listboxpopupwindict['listboxsampling'].getitemlist() 

#case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':0.5, 'marker':'.', 'linestyle':'None', }"
#case.popup_storteddata['plotdomain']['plot_sampleprobes']    = KPIO #lidarsam #case.listboxpopupwindict['listboxsampling'].getitemlist() 
#case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{}"

case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
case.popup_storteddata['plotdomain']['plot_refineboxes']     = [] 
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False
case.plotDomain(ax=ax, verbose=False)

ax.set_aspect('equal')
#ax.set_xlim([ 640000,  650000])
#ax.set_ylim([4025000, 4035000])

# %%
# Plot the domain
fig, axs = plt.subplots(1,2, figsize=(14,7), facecolor='w', dpi=125)
case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':0.01, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = KPsw[::5]+KProtor[::5]+KPturbhh[::5] 
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{}"
case.plotDomain(ax=axs[0], verbose=False)

case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':0.01, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes']        = E06wake #lidarsam #case.listboxpopupwindict['listboxsampling'].getitemlist() 
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{}"
case.plotDomain(ax=axs[1], verbose=False)


axs[0].set_xlim([640000, 644000])
axs[0].set_ylim([4.025E6, 4.029E6])

axs[0].set_aspect('equal')
axs[1].set_aspect('equal')

# %%
# Plot the domain
fig, axs = plt.subplots(1,2, figsize=(14,7), facecolor='w', dpi=125)
case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':0.01, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = ['Farm_KP090', 'Farm_KP_sideplane1o', 'Farm_KP_sideplane2o', 'Farm_KP_ioflow1o',]
                                                                #'Farm_AF090', 'Farm_AF_ioflow1', 'Farm_AF_sideplane1', 'Farm_AF_sideplane2',]
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{}"
case.plotDomain(ax=axs[0], verbose=False)

case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':0.01, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = H05wake #lidarsam #case.listboxpopupwindict['listboxsampling'].getitemlist() 
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{}"
case.plotDomain(ax=axs[1], verbose=False)

axs[1].set_xlim([640000, 647000])
axs[1].set_ylim([4.021E6, 4.028E6])

axs[0].set_aspect('equal')
axs[1].set_aspect('equal')

# %%
v=case.validate();
# Out:
# -- Checking inputs --
# [ PASS] max_level:           max_level = 2 >= 0
# [ PASS] dt & CFL:            DT and CFL OK
# [ PASS] restart dir:         Restart directory /tscratch/lcheung/AWAKEN/Benchmark1/Phase3/MMC/MMC_BM3_BigPrecursor/chk14400 exists
# [ PASS] boundary plane dir:  Restart directory /tscratch/lcheung/AWAKEN/Benchmark1/Phase3/MMC/MMC_BM3_BigPrecursor/bndry_file/ exists
# [ PASS] Actuator physics:    incflo.physics and ICNS.source_terms OK for Actuators
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT001 [WIT_USKPL_SS001_WT001_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT001 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT001 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT001 [WIT_USKPL_SS001_WT001_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT001 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT001 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT001 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT002 [WIT_USKPL_SS001_WT002_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT002 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT002 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT002 [WIT_USKPL_SS001_WT002_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT002 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT002 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT002 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT003 [WIT_USKPL_SS001_WT003_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT003 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT003 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT003 [WIT_USKPL_SS001_WT003_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT003 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT003 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT003 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT004 [WIT_USKPL_SS001_WT004_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT004 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT004 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT004 [WIT_USKPL_SS001_WT004_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT004 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT004 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT004 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT005 [WIT_USKPL_SS001_WT005_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT005 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT005 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT005 [WIT_USKPL_SS001_WT005_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT005 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT005 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT005 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT006 [WIT_USKPL_SS001_WT006_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT006 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT006 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT006 [WIT_USKPL_SS001_WT006_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT006 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT006 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT006 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT007 [WIT_USKPL_SS001_WT007_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT007 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT007 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT007 [WIT_USKPL_SS001_WT007_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT007 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT007 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT007 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT008 [WIT_USKPL_SS001_WT008_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT008 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT008 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT008 [WIT_USKPL_SS001_WT008_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT008 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT008 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT008 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT009 [WIT_USKPL_SS001_WT009_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT009 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT009 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT009 [WIT_USKPL_SS001_WT009_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT009 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT009 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT009 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT010 [WIT_USKPL_SS001_WT010_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT010 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT010 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT010 [WIT_USKPL_SS001_WT010_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT010 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT010 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT010 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT012 [WIT_USKPL_SS001_WT012_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT012 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT012 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT012 [WIT_USKPL_SS001_WT012_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT012 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT012 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT012 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT013 [WIT_USKPL_SS001_WT013_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT013 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT013 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT013 [WIT_USKPL_SS001_WT013_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT013 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT013 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT013 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT014 [WIT_USKPL_SS001_WT014_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT014 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT014 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT014 [WIT_USKPL_SS001_WT014_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT014 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT014 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT014 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT015 [WIT_USKPL_SS001_WT015_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT015 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT015 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT015 [WIT_USKPL_SS001_WT015_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT015 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT015 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT015 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT016 [WIT_USKPL_SS001_WT016_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT016 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT016 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT016 [WIT_USKPL_SS001_WT016_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT016 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT016 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT016 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT017 [WIT_USKPL_SS001_WT017_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT017 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT017 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT017 [WIT_USKPL_SS001_WT017_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT017 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT017 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT017 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT018 [WIT_USKPL_SS001_WT018_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT018 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT018 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT018 [WIT_USKPL_SS001_WT018_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT018 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT018 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT018 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT019 [WIT_USKPL_SS001_WT019_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT019 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT019 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT019 [WIT_USKPL_SS001_WT019_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT019 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT019 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT019 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT020 [WIT_USKPL_SS001_WT020_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT020 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT020 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT020 [WIT_USKPL_SS001_WT020_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT020 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT020 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT020 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT021 [WIT_USKPL_SS001_WT021_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT021 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT021 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT021 [WIT_USKPL_SS001_WT021_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT021 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT021 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT021 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT022 [WIT_USKPL_SS001_WT022_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT022 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT022 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT022 [WIT_USKPL_SS001_WT022_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT022 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT022 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT022 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT023 [WIT_USKPL_SS001_WT023_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT023 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT023 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT023 [WIT_USKPL_SS001_WT023_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT023 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT023 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT023 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT024 [WIT_USKPL_SS001_WT024_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT024 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT024 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT024 [WIT_USKPL_SS001_WT024_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT024 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT024 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT024 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT025 [WIT_USKPL_SS001_WT025_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT025 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT025 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT025 [WIT_USKPL_SS001_WT025_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT025 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT025 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT025 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT026 [WIT_USKPL_SS001_WT026_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT026 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT026 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT026 [WIT_USKPL_SS001_WT026_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT026 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT026 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT026 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT027 [WIT_USKPL_SS001_WT027_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT027 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT027 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT027 [WIT_USKPL_SS001_WT027_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT027 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT027 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT027 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT028 [WIT_USKPL_SS001_WT028_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT028 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT028 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT028 [WIT_USKPL_SS001_WT028_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT028 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT028 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT028 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT030 [WIT_USKPL_SS001_WT030_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT030 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT030 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT030 [WIT_USKPL_SS001_WT030_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT030 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT030 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT030 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT031 [WIT_USKPL_SS001_WT031_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT031 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT031 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT031 [WIT_USKPL_SS001_WT031_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT031 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT031 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT031 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT032 [WIT_USKPL_SS001_WT032_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT032 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT032 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT032 [WIT_USKPL_SS001_WT032_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT032 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT032 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT032 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT033 [WIT_USKPL_SS001_WT033_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT033 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT033 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT033 [WIT_USKPL_SS001_WT033_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT033 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT033 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT033 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT034 [WIT_USKPL_SS001_WT034_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT034 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT034 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT034 [WIT_USKPL_SS001_WT034_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT034 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT034 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT034 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT035 [WIT_USKPL_SS001_WT035_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT035 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT035 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT035 [WIT_USKPL_SS001_WT035_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT035 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT035 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT035 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT036 [WIT_USKPL_SS001_WT036_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT036 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT036 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT036 [WIT_USKPL_SS001_WT036_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT036 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT036 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT036 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT037 [WIT_USKPL_SS001_WT037_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT037 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT037 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT037 [WIT_USKPL_SS001_WT037_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT037 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT037 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT037 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT038 [WIT_USKPL_SS001_WT038_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT038 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT038 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT038 [WIT_USKPL_SS001_WT038_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT038 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT038 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT038 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT039 [WIT_USKPL_SS001_WT039_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT039 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT039 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT039 [WIT_USKPL_SS001_WT039_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT039 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT039 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT039 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT040 [WIT_USKPL_SS001_WT040_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT040 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT040 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT040 [WIT_USKPL_SS001_WT040_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT040 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT040 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT040 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT041 [WIT_USKPL_SS001_WT041_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT041 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT041 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT041 [WIT_USKPL_SS001_WT041_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT041 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT041 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT041 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT042 [WIT_USKPL_SS001_WT042_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT042 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT042 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT042 [WIT_USKPL_SS001_WT042_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT042 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT042 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT042 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT043 [WIT_USKPL_SS001_WT043_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT043 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT043 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT043 [WIT_USKPL_SS001_WT043_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT043 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT043 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT043 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT044 [WIT_USKPL_SS001_WT044_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT044 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT044 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT044 [WIT_USKPL_SS001_WT044_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT044 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT044 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT044 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT045 [WIT_USKPL_SS001_WT045_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT045 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT045 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT045 [WIT_USKPL_SS001_WT045_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT045 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT045 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT045 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT046 [WIT_USKPL_SS001_WT046_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT046 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT046 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT046 [WIT_USKPL_SS001_WT046_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT046 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT046 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT046 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT047 [WIT_USKPL_SS001_WT047_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT047 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT047 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT047 [WIT_USKPL_SS001_WT047_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT047 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT047 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT047 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT048 [WIT_USKPL_SS001_WT048_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT048 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT048 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT048 [WIT_USKPL_SS001_WT048_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT048 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT048 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT048 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT049 [WIT_USKPL_SS001_WT049_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT049 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT049 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT049 [WIT_USKPL_SS001_WT049_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT049 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT049 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT049 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT050 [WIT_USKPL_SS001_WT050_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT050 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT050 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT050 [WIT_USKPL_SS001_WT050_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT050 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT050 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT050 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT051 [WIT_USKPL_SS001_WT051_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT051 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT051 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT051 [WIT_USKPL_SS001_WT051_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT051 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT051 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT051 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT052 [WIT_USKPL_SS001_WT052_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT052 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT052 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT052 [WIT_USKPL_SS001_WT052_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT052 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT052 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT052 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT053 [WIT_USKPL_SS001_WT053_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT053 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT053 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT053 [WIT_USKPL_SS001_WT053_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT053 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT053 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT053 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT054 [WIT_USKPL_SS001_WT054_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT054 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT054 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT054 [WIT_USKPL_SS001_WT054_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT054 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT054 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT054 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT055 [WIT_USKPL_SS001_WT055_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT055 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT055 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT055 [WIT_USKPL_SS001_WT055_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT055 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT055 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT055 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT056 [WIT_USKPL_SS001_WT056_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT056 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT056 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT056 [WIT_USKPL_SS001_WT056_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT056 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT056 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT056 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT057 [WIT_USKPL_SS001_WT057_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT057 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT057 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT057 [WIT_USKPL_SS001_WT057_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT057 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT057 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT057 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT058 [WIT_USKPL_SS001_WT058_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT058 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT058 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT058 [WIT_USKPL_SS001_WT058_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT058 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT058 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT058 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT059 [WIT_USKPL_SS001_WT059_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT059 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT059 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT059 [WIT_USKPL_SS001_WT059_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT059 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT059 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT059 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT060 [WIT_USKPL_SS001_WT060_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT060 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT060 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT060 [WIT_USKPL_SS001_WT060_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT060 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT060 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT060 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT061 [WIT_USKPL_SS001_WT061_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT061 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT061 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT061 [WIT_USKPL_SS001_WT061_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT061 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT061 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT061 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT062 [WIT_USKPL_SS001_WT062_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT062 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT062 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT062 [WIT_USKPL_SS001_WT062_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT062 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT062 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT062 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT063 [WIT_USKPL_SS001_WT063_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT063 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT063 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT063 [WIT_USKPL_SS001_WT063_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT063 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT063 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT063 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT064 [WIT_USKPL_SS001_WT064_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT064 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT064 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT064 [WIT_USKPL_SS001_WT064_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT064 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT064 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT064 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT065 [WIT_USKPL_SS001_WT065_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT065 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT065 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT065 [WIT_USKPL_SS001_WT065_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT065 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT065 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT065 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT066 [WIT_USKPL_SS001_WT066_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT066 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT066 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT066 [WIT_USKPL_SS001_WT066_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT066 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT066 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT066 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT067 [WIT_USKPL_SS001_WT067_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT067 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT067 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT067 [WIT_USKPL_SS001_WT067_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT067 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT067 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT067 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT068 [WIT_USKPL_SS001_WT068_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT068 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT068 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT068 [WIT_USKPL_SS001_WT068_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT068 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT068 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT068 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT069 [WIT_USKPL_SS001_WT069_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT069 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT069 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT069 [WIT_USKPL_SS001_WT069_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT069 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT069 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT069 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT070 [WIT_USKPL_SS001_WT070_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT070 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT070 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT070 [WIT_USKPL_SS001_WT070_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT070 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT070 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT070 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT071 [WIT_USKPL_SS001_WT071_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT071 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT071 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT071 [WIT_USKPL_SS001_WT071_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT071 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT071 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT071 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT072 [WIT_USKPL_SS001_WT072_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT072 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT072 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT072 [WIT_USKPL_SS001_WT072_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT072 WakeMod=0 OK
# ...
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT088 [WIT_USKPL_SS001_WT088_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127.fst] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT088 Actuator density=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT088 CompInflow OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT088 [WIT_USKPL_SS001_WT088_OpenFAST_NREL2p8-127_AWAKEN/NREL-2p8-127_AeroDyn15.dat] exists
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT088 WakeMod=0 OK
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT088 AirDens=1.103707, matches incflo.density=1.103707
# [ PASS] Actuator FST:WIT_USKPL_SS001_WT088 WE_RhoAir=1.103707 in DISCON matches AirDens=1.103707 and incflo.density=1.103707
# [ PASS] Sampling probes:Farm_sw1
# [ PASS] Sampling probes:Farm_hh
# [ PASS] Sampling probes:surface_siteA1 is inside domain
# [ PASS] Sampling probes:surface_siteA5 is inside domain
# [ PASS] Sampling probes:lidar_siteA1 is inside domain
# [ PASS] Sampling probes:lidar_siteC1a is inside domain
# [ PASS] Sampling probes:lidar_siteH is inside domain
# [ PASS] Sampling probes:lidar_siteG is inside domain
# [ PASS] Sampling probes:lidar_siteGC is inside domain
# [ PASS] Sampling probes:surface_siteC1a is inside domain
# [ PASS] Sampling probes:surface_siteG is inside domain
# [ PASS] Sampling probes:surface_siteH is inside domain
# [ PASS] Sampling probes:Farm_E06wake27
# [ PASS] Sampling probes:Farm_E06wake59
# [ PASS] Sampling probes:Farm_E06wake90
# [ PASS] Sampling probes:Farm_E06wake122
# [ PASS] Sampling probes:Farm_E06wake154
# [ PASS] Sampling probes:Farm_E06wake217
# [ PASS] Sampling probes:Farm_E06wake281
# [ PASS] Sampling probes:Farm_E06wake344
# [ PASS] Sampling probes:Farm_allhh
# [ PASS] Sampling probes:Farm_hh90
# [ PASS] Sampling probes:Farm_hh153
# [ PASS] Sampling probes:Farm_KP500
# [ PASS] Sampling probes:Farm_KP153
# [ PASS] Sampling probes:Farm_KP090
# [ PASS] Sampling probes:Farm_KP026
# [ PASS] Sampling probes:Farm_KP_sideplane1o
# [ PASS] Sampling probes:Farm_KP_sideplane2o
# [ PASS] Sampling probes:Farm_KP_ioflow1o
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT001_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT002_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT003_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT004_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT005_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT006_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT007_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT008_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT009_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT010_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT012_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT013_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT014_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT015_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT016_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT017_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT018_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT019_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT020_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT021_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT022_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT023_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT024_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT025_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT026_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT027_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT028_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT030_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT031_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT032_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT033_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT034_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT035_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT036_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT037_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT038_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT039_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT040_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT041_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT042_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT043_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT044_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT045_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT046_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT047_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT048_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT049_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT050_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT051_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT052_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT053_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT054_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT055_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT056_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT057_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT058_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT059_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT060_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT061_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT062_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT063_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT064_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT065_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT066_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT067_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT068_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT069_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT070_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT071_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT072_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT073_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT074_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT075_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT076_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT077_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT078_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT080_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT081_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT082_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT083_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT084_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT085_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT086_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT087_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT088_KPturbhh
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT001_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT002_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT003_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT004_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT005_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT006_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT007_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT008_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT009_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT010_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT012_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT013_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT014_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT015_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT016_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT017_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT018_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT019_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT020_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT021_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT022_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT023_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT024_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT025_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT026_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT027_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT028_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT030_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT031_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT032_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT033_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT034_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT035_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT036_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT037_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT038_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT039_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT040_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT041_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT042_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT043_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT044_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT045_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT046_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT047_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT048_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT049_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT050_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT051_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT052_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT053_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT054_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT055_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT056_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT057_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT058_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT059_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT060_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT061_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT062_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT063_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT064_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT065_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT066_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT067_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT068_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT069_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT070_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT071_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT072_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT073_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT074_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT075_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT076_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT077_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT078_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT080_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT081_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT082_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT083_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT084_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT085_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT086_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT087_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT088_KPsw
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT001_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT002_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT003_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT004_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT005_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT006_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT007_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT008_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT009_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT010_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT012_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT013_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT014_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT015_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT016_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT017_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT018_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT019_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT020_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT021_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT022_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT023_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT024_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT025_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT026_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT027_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT028_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT030_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT031_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT032_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT033_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT034_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT035_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT036_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT037_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT038_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT039_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT040_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT041_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT042_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT043_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT044_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT045_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT046_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT047_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT048_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT049_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT050_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT051_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT052_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT053_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT054_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT055_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT056_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT057_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT058_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT059_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT060_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT061_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT062_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT063_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT064_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT065_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT066_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT067_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT068_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT069_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT070_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT071_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT072_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT073_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT074_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT075_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT076_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT077_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT078_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT080_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT081_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT082_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT083_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT084_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT085_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT086_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT087_KProtor
# [ PASS] Sampling probes:WIT_USKPL_SS001_WT088_KProtor
#
# Results:
#  885 PASS
#  0 SKIP
#  0 FAIL
#  0 WARN

# %%
# Write the input file
print(case.writeAMRWindInput(inputfile))
# Out:
# # --- Simulation time control parameters ---
# time.stop_time                           = 12600.0             # Max (simulated) time to evolve [s]
# time.max_step                            = -1
# time.fixed_dt                            = 0.1                 # Fixed timestep size (in seconds). If negative, then time.cfl is used
# time.checkpoint_interval                 = 900
# time.checkpoint_start                    = 14400
# incflo.physics                           = ABL Actuator        # List of physics models to include in simulation.
# incflo.verbose                           = 3
# io.check_file                            = chk
# io.restart_file                          = /tscratch/lcheung/AWAKEN/Benchmark1/Phase3/MMC/MMC_BM3_BigPrecursor/chk14400
# incflo.use_godunov                       = true
# incflo.godunov_type                      = weno_z
# turbulence.model                         = OneEqKsgsM84
# TKE.source_terms                         = KsgsM84Src
# nodal_proj.mg_rtol                       = 1e-06
# nodal_proj.mg_atol                       = 1e-12
# mac_proj.mg_rtol                         = 1e-06
# mac_proj.mg_atol                         = 1e-12
# diffusion.mg_rtol                        = 1e-06
# diffusion.mg_atol                        = 1e-12
# temperature_diffusion.mg_rtol            = 1e-10
# temperature_diffusion.mg_atol            = 1e-13
# incflo.do_initial_proj                   = 0
# incflo.initial_iterations                = 0
# incflo.gravity                           = 0.0 0.0 -9.81       # Gravitational acceleration vector (x,y,z) [m/s^2]
# incflo.density                           = 1.103707            # Fluid density [kg/m^3]
# transport.viscosity                      = 1.771e-05           # Fluid dynamic viscosity [kg/m-s]
# transport.laminar_prandtl                = 0.7                 # Laminar prandtl number
# transport.turbulent_prandtl              = 0.3333              # Turbulent prandtl number
#
# # --- Geometry and Mesh ---
# geometry.prob_lo                         = 625500.0 4021200.0 0.0
# geometry.prob_hi                         = 649500.0 4038800.0 800.0
# amr.n_cell                               = 2400 1760 80        # Number of cells in x, y, and z directions
# amr.max_level                            = 2
# geometry.is_periodic                     = 0 0 0
# xlo.type                                 = mass_inflow_outflow
# xlo.density                              = 1.103707
# xlo.temperature                          = 0.0
# xlo.tke                                  = 0.0
# xhi.type                                 = mass_inflow_outflow
# xhi.density                              = 1.103707
# xhi.temperature                          = 0.0
# xhi.tke                                  = 0.0
# ylo.type                                 = mass_inflow_outflow
# ylo.density                              = 1.103707
# ylo.temperature                          = 0.0
# ylo.tke                                  = 0.0
# yhi.type                                 = mass_inflow_outflow
# yhi.density                              = 1.103707
# yhi.temperature                          = 0.0
# yhi.tke                                  = 0.0
# zlo.type                                 = wall_model
# zlo.tke_type                             = zero_gradient
# zhi.type                                 = slip_wall
# zhi.temperature_type                     = fixed_gradient
#
# # --- ABL parameters ---
# ICNS.source_terms                        = BoussinesqBuoyancy ActuatorForcing ABLMeanBoussinesq ABLMesoForcingMom
# ABL.stats_output_frequency               = 10
# ABL.stats_output_format                  = netcdf
# Temperature.source_terms                 = ABLMesoForcingTemp
# ABLMesoForcingMom.forcing_scheme         = direct
# ABLMesoForcingTemp.forcing_scheme        = direct
# ABL.tendency_forcing                     = true
# ABL.mesoscale_forcing                    = ./tendencyforcing.nc
# ABL.bndry_io_mode                        = 1
# ABL.bndry_file                           = /tscratch/lcheung/AWAKEN/Benchmark1/Phase3/MMC/MMC_BM3_BigPrecursor/bndry_file/
# ABL.bndry_planes                         = xlo ylo xhi yhi
# ABL.bndry_output_start_time              = 7000.0
# ABL.bndry_var_names                      = velocity temperature tke
# ABL.bndry_output_format                  = native
# incflo.velocity                          = 0.0 0.0 0.0
# ABLForcing.abl_forcing_height            = 150.0
# ABL.kappa                                = 0.4
# ABL.normal_direction                     = 2
# ABL.surface_roughness_z0                 = 0.0001
# ABL.reference_temperature                = 300.0
# ABL.surface_temp_rate                    = 0.0
# ABL.mo_beta_m                            = 16.0                # Monin-Obukhov Beta m parameter
# ABL.mo_gamma_m                           = 5.0                 # Monin-Obukhov Gamma m parameter
# ABL.mo_gamma_h                           = 5.0                 # Monin-Obukhov Gamma h parameter
# ABL.random_gauss_mean                    = 0.0
# ABL.random_gauss_var                     = 1.0
# ABL.wall_shear_stress_type               = local
# BoussinesqBuoyancy.reference_temperature = 300.0
# ABL.temperature_heights                  = 0.0 10.0 20.0 30.0 40.0 50.0 60.0 70.0 80.0 90.0 100.0 110.0 120.0 130.0 140.0 150.0 160.0 170.0 180.0 190.0 200.0 210.0 220.0 230.0 240.0 250.0 260.0 270.0 280.0 290.0 300.0 310.0 320.0 330.0 340.0 350.0 360.0 370.0 380.0 390.0 400.0 410.0 420.0 430.0 440.0 450.0 460.0 470.0 480.0 490.0 500.0 510.0 520.0 530.0 540.0 550.0 560.0 570.0 580.0 590.0 600.0 610.0 620.0 630.0 640.0 650.0 660.0 670.0 680.0 690.0 700.0 710.0 720.0 730.0 740.0 750.0 760.0 770.0 780.0 790.0 800.0 810.0 820.0 830.0 840.0 850.0 860.0 870.0 880.0 890.0 900.0 910.0 920.0 930.0 940.0 950.0 960.0 970.0 980.0 990.0 1000.0 1010.0 1020.0 1030.0 1040.0 1050.0 1060.0 1070.0 1080.0 1090.0 1100.0 1110.0 1120.0 1130.0 1140.0 1150.0 1160.0 1170.0 1180.0 1190.0 1200.0 1210.0 1220.0 1230.0 1240.0 1250.0 1260.0 1270.0 1280.0 1290.0 1300.0 1310.0 1320.0 1330.0 1340.0 1350.0 1360.0 1370.0 1380.0 1390.0 1400.0 1410.0 1420.0 1430.0 1440.0 1450.0 1460.0 1470.0 1480.0 1490.0 1500.0 1510.0 1520.0 1530.0 1540.0 1550.0 1560.0 1570.0 1580.0 1590.0 1600.0 1610.0 1620.0 1630.0 1640.0 1650.0 1660.0 1670.0 1680.0 1690.0 1700.0 1710.0 1720.0 1730.0 1740.0 1750.0 1760.0 1770.0 1780.0 1790.0 1800.0 1810.0 1820.0 1830.0 1840.0 1850.0 1860.0 1870.0 1880.0 1890.0 1900.0 1910.0 1920.0 1930.0 1940.0 1950.0 1960.0 1970.0 1980.0 1990.0 2000.0 2010.0 2020.0 2030.0 2040.0 2050.0 2060.0 2070.0 2080.0 2090.0 2100.0 2110.0 2120.0 2130.0 2140.0 2150.0 2160.0 2170.0 2180.0 2190.0 2200.0 2210.0 2220.0 2230.0 2240.0 2250.0 2260.0 2270.0 2280.0 2290.0 2300.0 2310.0 2320.0 2330.0 2340.0 2350.0 2360.0 2370.0 2380.0 2390.0 2400.0 2410.0 2420.0 2430.0 2440.0 2450.0 2460.0 2470.0 2480.0 2490.0 2500.0 2510.0 2520.0 2530.0 2540.0 2550.0 2560.0 2570.0 2580.0 2590.0 2600.0 2610.0 2620.0 2630.0 2640.0 2650.0 2660.0 2670.0 2680.0 2690.0 2700.0 2710.0 2720.0 2730.0 2740.0 2750.0 2760.0 2770.0 2780.0 2790.0 2800.0 2810.0 2820.0 2830.0 2840.0 2850.0 2860.0 2870.0 2880.0 2890.0 2900.0 2910.0 2920.0 2930.0 2940.0 2950.0 2960.0 2970.0 2980.0 2990.0 3000.0 3010.0 3020.0 3030.0 3040.0 3050.0 3060.0 3070.0 3080.0 3090.0 3100.0 3110.0 3120.0 3130.0 3140.0 3150.0 3160.0 3170.0 3180.0 3190.0 3200.0 3210.0 3220.0 3230.0 3240.0 3250.0 3260.0 3270.0 3280.0 3290.0 3300.0 3310.0 3320.0 3330.0 3340.0 3350.0 3360.0 3370.0 3380.0 3390.0 3400.0 3410.0 3420.0 3430.0 3440.0 3450.0 3460.0 3470.0 3480.0 3490.0 3500.0 3510.0 3520.0 3530.0 3540.0 3550.0 3560.0 3570.0 3580.0 3590.0 3600.0 3610.0 3620.0 3630.0 3640.0 3650.0 3660.0 3670.0 3680.0 3690.0 3700.0 3710.0 3720.0 3730.0 3740.0 3750.0 3760.0 3770.0 3780.0 3790.0 3800.0 3810.0 3820.0 3830.0 3840.0 3850.0 3860.0 3870.0 3880.0 3890.0 3900.0 3910.0 3920.0 3930.0 3940.0 3950.0 3960.0 3970.0 3980.0 3990.0 4000.0
# ABL.temperature_values                   = 303.61745471405146 303.868858587108 304.1145462228351 304.3544486987543 304.5875920011584 304.81300715643147 305.02973137144136 305.2368094455341 305.4332955218002 305.6189196574776 305.791520021455 305.9541424129186 306.09700895015317 306.22964852506436 306.3556732505793 306.48015773538464 306.5945960832089 306.69568696584923 306.7913988431376 306.8881139753319 306.9831933764323 307.07792472969277 307.17384305184777 307.26973018398326 307.36889946011377 307.4750465056469 307.58920764546326 307.71211694826206 307.8450013518159 307.9883755069978 308.1458130913051 308.32365502201 308.5284655686835 308.7643868371526 309.03424247116095 309.3414292023855 309.68923271325156 310.0807528872275 310.5193469542744 311.0072053766757 311.54451729950085 312.128962932484 312.75482638263315 313.4132715070998 314.093229892897 314.782036852744 315.46630924381634 316.1331644585193 316.77125789117093 317.3710782404229 317.92544914452264 318.4297620782748 318.88178434958894 319.2813836975001 319.6304905159029 319.9323438232766 320.1910041562701 320.41094448060926 320.5967384305045 320.75281534365206 320.8832852655234 320.9918995820346 321.08200817697093 321.1565503558141 321.2180695947695 321.2687461198826 321.3104336748407 321.34468861069263 321.3728106033952 321.3958805932382 321.41479466971526 321.4302937366957 321.4429884183705 321.45337993291605 321.46188323343864 321.4688396159478 321.4745292753431 321.47918204824276 321.48298633292893 321.4860964732525 321.48863884052713 321.4907168132414 321.4924150726603 321.49380291076267 321.49493700244625 321.4958636942828 321.4966208808754 321.4972395422104 321.4977450026403 321.4981579626232 321.4984953431287 321.498770964935 321.4989961236635 321.49918005141853 321.49933029313974 321.49945301447167 321.4995532535711 321.4996351270294 321.49970199824946 321.49975661429266 321.4998012194146 321.49983764970204 321.4998674042295 321.4998917068733 321.4999115569116 321.4999277703026 321.4999410133614 321.4999518302399 321.4999606653501 321.4999678816658 321.49997377553666 321.4999785888655 321.49998251950063 321.49998572912506 321.49998834984996 321.49999048961377 321.4999922365978 321.4999936628364 321.49999482716913 321.49999577765414 321.4999965535407 321.4999971868815 321.4999977038686 321.4999981258896 321.49999847038 321.499998751576 321.4999989811012 321.4999991684456 321.4999993213573 321.49999944616184 321.49999954802337 321.4999996311577 321.4999996990063 321.4999997543785 321.49999979956766 321.49999983644636 321.499999866543 321.4999998911042 321.4999999111473 321.499999927503 321.49999994084914 321.49999995173926 321.4999999606251 321.49999996787534 321.4999999737909 321.49999997861744 321.49999998255527 321.49999998576806 321.4999999883892 321.4999999905276 321.4999999922722 321.49999999369555 321.4999999948568 321.4999999958041 321.499999996577 321.49999999720757 321.49999999772206 321.4999999981417 321.4999999984841 321.4999999987635 321.49999999899137 321.49999999917725 321.4999999993289 321.4999999994526 321.49999999955355 321.4999999996359 321.49999999970305 321.49999999975785 321.4999999998025 321.49999999983896 321.4999999998687 321.4999999998929 321.4999999999127 321.4999999999288 321.4999999999419 321.49999999995265 321.4999999999614 321.4999999999685 321.49999999997436 321.4999999999791 321.49999999998295 321.49999999998613 321.49999999998863 321.49999999999073 321.49999999999244 321.49999999999386 321.499999999995 321.4999999999959 321.4999999999967 321.49999999999727 321.4999999999978 321.4999999999982 321.4999999999986 321.4999999999988 321.49999999999903 321.4999999999992 321.4999999999994 321.49999999999943 321.4999999999996 321.49999999999966 321.4999999999997 321.4999999999998 321.4999999999998 321.49999999999983 321.4999999999999 321.4999999999999 321.49999999999994 321.49999999999994 321.49999999999994 321.49999999999994 321.5 321.5 321.49999999999994 321.5 321.5 321.5 321.49999999999994 321.5 321.5 321.5 321.5 321.49999999999994 ...
# ABLMeanBoussinesq.read_temperature_profile = false
# ABL.perturb_velocity                     = true
# ABL.perturb_ref_height                   = 50.0
# ABL.Uperiods                             = 4.0
# ABL.Vperiods                             = 4.0
# ABL.deltaU                               = 1.0
# ABL.deltaV                               = 1.0
# ABL.perturb_temperature                  = true
# ABL.theta_amplitude                      = 0.8
# ABL.cutoff_height                        = 100.0
# time.plot_interval                       = -1
# io.plot_file                             = plt
#
# #---- tagging defs ----
# tagging.labels                           = Farm_level_0_center_643000_4029000_100 Farm_level_0_center_634000_4029000_100 WIT_USKPL_SS001_WT001_level_1_zone WIT_USKPL_SS001_WT002_level_1_zone WIT_USKPL_SS001_WT003_level_1_zone WIT_USKPL_SS001_WT004_level_1_zone WIT_USKPL_SS001_WT005_level_1_zone WIT_USKPL_SS001_WT006_level_1_zone WIT_USKPL_SS001_WT007_level_1_zone WIT_USKPL_SS001_WT008_level_1_zone WIT_USKPL_SS001_WT009_level_1_zone WIT_USKPL_SS001_WT010_level_1_zone WIT_USKPL_SS001_WT012_level_1_zone WIT_USKPL_SS001_WT013_level_1_zone WIT_USKPL_SS001_WT014_level_1_zone WIT_USKPL_SS001_WT015_level_1_zone WIT_USKPL_SS001_WT016_level_1_zone WIT_USKPL_SS001_WT017_level_1_zone WIT_USKPL_SS001_WT018_level_1_zone WIT_USKPL_SS001_WT019_level_1_zone WIT_USKPL_SS001_WT020_level_1_zone WIT_USKPL_SS001_WT021_level_1_zone WIT_USKPL_SS001_WT022_level_1_zone WIT_USKPL_SS001_WT023_level_1_zone WIT_USKPL_SS001_WT024_level_1_zone WIT_USKPL_SS001_WT025_level_1_zone WIT_USKPL_SS001_WT026_level_1_zone WIT_USKPL_SS001_WT027_level_1_zone WIT_USKPL_SS001_WT028_level_1_zone WIT_USKPL_SS001_WT030_level_1_zone WIT_USKPL_SS001_WT031_level_1_zone WIT_USKPL_SS001_WT032_level_1_zone WIT_USKPL_SS001_WT033_level_1_zone WIT_USKPL_SS001_WT034_level_1_zone WIT_USKPL_SS001_WT035_level_1_zone WIT_USKPL_SS001_WT036_level_1_zone WIT_USKPL_SS001_WT037_level_1_zone WIT_USKPL_SS001_WT038_level_1_zone WIT_USKPL_SS001_WT039_level_1_zone WIT_USKPL_SS001_WT040_level_1_zone WIT_USKPL_SS001_WT041_level_1_zone WIT_USKPL_SS001_WT042_level_1_zone WIT_USKPL_SS001_WT043_level_1_zone WIT_USKPL_SS001_WT044_level_1_zone WIT_USKPL_SS001_WT045_level_1_zone WIT_USKPL_SS001_WT046_level_1_zone WIT_USKPL_SS001_WT047_level_1_zone WIT_USKPL_SS001_WT048_level_1_zone WIT_USKPL_SS001_WT049_level_1_zone WIT_USKPL_SS001_WT050_level_1_zone WIT_USKPL_SS001_WT051_level_1_zone WIT_USKPL_SS001_WT052_level_1_zone WIT_USKPL_SS001_WT053_level_1_zone WIT_USKPL_SS001_WT054_level_1_zone WIT_USKPL_SS001_WT055_level_1_zone WIT_USKPL_SS001_WT056_level_1_zone WIT_USKPL_SS001_WT057_level_1_zone WIT_USKPL_SS001_WT058_level_1_zone WIT_USKPL_SS001_WT059_level_1_zone WIT_USKPL_SS001_WT060_level_1_zone WIT_USKPL_SS001_WT061_level_1_zone WIT_USKPL_SS001_WT062_level_1_zone WIT_USKPL_SS001_WT063_level_1_zone WIT_USKPL_SS001_WT064_level_1_zone WIT_USKPL_SS001_WT065_level_1_zone WIT_USKPL_SS001_WT066_level_1_zone WIT_USKPL_SS001_WT067_level_1_zone WIT_USKPL_SS001_WT068_level_1_zone WIT_USKPL_SS001_WT069_level_1_zone WIT_USKPL_SS001_WT070_level_1_zone WIT_USKPL_SS001_WT071_level_1_zone WIT_USKPL_SS001_WT072_level_1_zone WIT_USKPL_SS001_WT073_level_1_zone WIT_USKPL_SS001_WT074_level_1_zone WIT_USKPL_SS001_WT075_level_1_zone WIT_USKPL_SS001_WT076_level_1_zone WIT_USKPL_SS001_WT077_level_1_zone WIT_USKPL_SS001_WT078_level_1_zone WIT_USKPL_SS001_WT080_level_1_zone WIT_USKPL_SS001_WT081_level_1_zone WIT_USKPL_SS001_WT082_level_1_zone WIT_USKPL_SS001_WT083_level_1_zone WIT_USKPL_SS001_WT084_level_1_zone WIT_USKPL_SS001_WT085_level_1_zone WIT_USKPL_SS001_WT086_level_1_zone WIT_USKPL_SS001_WT087_level_1_zone WIT_USKPL_SS001_WT088_level_1_zone
# tagging.Farm_level_0_center_643000_4029000_100.type = GeometryRefinement
# tagging.Farm_level_0_center_643000_4029000_100.shapes = Farm_level_0_center_643000_4029000_100
# tagging.Farm_level_0_center_643000_4029000_100.level = 0
# tagging.Farm_level_0_center_643000_4029000_100.Farm_level_0_center_643000_4029000_100.type = box
# tagging.Farm_level_0_center_643000_4029000_100.Farm_level_0_center_643000_4029000_100.origin = 647750.0 4024750.0 0.0
# tagging.Farm_level_0_center_643000_4029000_100.Farm_level_0_center_643000_4029000_100.xaxis = 4.745506346695994e-13 7750.0 0.0
# tagging.Farm_level_0_center_643000_4029000_100.Farm_level_0_center_643000_4029000_100.yaxis = -9500.0 5.817072295949928e-13 -0.0
# tagging.Farm_level_0_center_643000_4029000_100.Farm_level_0_center_643000_4029000_100.zaxis = 0.0 0.0 175.0
# tagging.Farm_level_0_center_634000_4029000_100.type = GeometryRefinement
# tagging.Farm_level_0_center_634000_4029000_100.shapes = Farm_level_0_center_634000_4029000_100
# tagging.Farm_level_0_center_634000_4029000_100.level = 0
# tagging.Farm_level_0_center_634000_4029000_100.Farm_level_0_center_634000_4029000_100.type = box
# tagging.Farm_level_0_center_634000_4029000_100.Farm_level_0_center_634000_4029000_100.origin = 638750.0 4026300.0 0.0
# tagging.Farm_level_0_center_634000_4029000_100.Farm_level_0_center_634000_4029000_100.xaxis = 4.2250314570583687e-13 6900.0 0.0
# tagging.Farm_level_0_center_634000_4029000_100.Farm_level_0_center_634000_4029000_100.yaxis = -9500.0 5.817072295949928e-13 -0.0
# tagging.Farm_level_0_center_634000_4029000_100.Farm_level_0_center_634000_4029000_100.zaxis = 0.0 0.0 175.0
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.shapes = WIT_USKPL_SS001_WT001_level_1_zone
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.WIT_USKPL_SS001_WT001_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.WIT_USKPL_SS001_WT001_level_1_zone.origin = 634291.8924088458 4029629.351572155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.WIT_USKPL_SS001_WT001_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.WIT_USKPL_SS001_WT001_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT001_level_1_zone.WIT_USKPL_SS001_WT001_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.shapes = WIT_USKPL_SS001_WT002_level_1_zone
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.WIT_USKPL_SS001_WT002_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.WIT_USKPL_SS001_WT002_level_1_zone.origin = 633880.5624438458 4029586.0012071547 23.325000000000003
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.WIT_USKPL_SS001_WT002_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.WIT_USKPL_SS001_WT002_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT002_level_1_zone.WIT_USKPL_SS001_WT002_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.shapes = WIT_USKPL_SS001_WT003_level_1_zone
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.WIT_USKPL_SS001_WT003_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.WIT_USKPL_SS001_WT003_level_1_zone.origin = 633492.1525108458 4029643.532059155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.WIT_USKPL_SS001_WT003_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.WIT_USKPL_SS001_WT003_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT003_level_1_zone.WIT_USKPL_SS001_WT003_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.shapes = WIT_USKPL_SS001_WT004_level_1_zone
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.WIT_USKPL_SS001_WT004_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.WIT_USKPL_SS001_WT004_level_1_zone.origin = 632552.8726658458 4029545.461814155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.WIT_USKPL_SS001_WT004_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.WIT_USKPL_SS001_WT004_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT004_level_1_zone.WIT_USKPL_SS001_WT004_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.shapes = WIT_USKPL_SS001_WT005_level_1_zone
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.WIT_USKPL_SS001_WT005_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.WIT_USKPL_SS001_WT005_level_1_zone.origin = 631075.3522738458 4029620.101957155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.WIT_USKPL_SS001_WT005_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.WIT_USKPL_SS001_WT005_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT005_level_1_zone.WIT_USKPL_SS001_WT005_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.shapes = WIT_USKPL_SS001_WT006_level_1_zone
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.WIT_USKPL_SS001_WT006_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.WIT_USKPL_SS001_WT006_level_1_zone.origin = 631482.4627048458 4030494.591623155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.WIT_USKPL_SS001_WT006_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.WIT_USKPL_SS001_WT006_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT006_level_1_zone.WIT_USKPL_SS001_WT006_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.shapes = WIT_USKPL_SS001_WT007_level_1_zone
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.WIT_USKPL_SS001_WT007_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.WIT_USKPL_SS001_WT007_level_1_zone.origin = 631072.6520878458 4030681.0814761547 23.325000000000003
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.WIT_USKPL_SS001_WT007_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.WIT_USKPL_SS001_WT007_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT007_level_1_zone.WIT_USKPL_SS001_WT007_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.shapes = WIT_USKPL_SS001_WT008_level_1_zone
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.WIT_USKPL_SS001_WT008_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.WIT_USKPL_SS001_WT008_level_1_zone.origin = 630701.1425438458 4030774.851091155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.WIT_USKPL_SS001_WT008_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.WIT_USKPL_SS001_WT008_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT008_level_1_zone.WIT_USKPL_SS001_WT008_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.shapes = WIT_USKPL_SS001_WT009_level_1_zone
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.WIT_USKPL_SS001_WT009_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.WIT_USKPL_SS001_WT009_level_1_zone.origin = 630319.7627178458 4030817.421520155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.WIT_USKPL_SS001_WT009_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.WIT_USKPL_SS001_WT009_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT009_level_1_zone.WIT_USKPL_SS001_WT009_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.shapes = WIT_USKPL_SS001_WT010_level_1_zone
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.WIT_USKPL_SS001_WT010_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.WIT_USKPL_SS001_WT010_level_1_zone.origin = 635081.1023958458 4029663.4316111547 23.325000000000003
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.WIT_USKPL_SS001_WT010_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.WIT_USKPL_SS001_WT010_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT010_level_1_zone.WIT_USKPL_SS001_WT010_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.shapes = WIT_USKPL_SS001_WT012_level_1_zone
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.WIT_USKPL_SS001_WT012_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.WIT_USKPL_SS001_WT012_level_1_zone.origin = 632956.2822518458 4030035.021032155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.WIT_USKPL_SS001_WT012_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.WIT_USKPL_SS001_WT012_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT012_level_1_zone.WIT_USKPL_SS001_WT012_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.shapes = WIT_USKPL_SS001_WT013_level_1_zone
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.WIT_USKPL_SS001_WT013_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.WIT_USKPL_SS001_WT013_level_1_zone.origin = 633835.0320298459 4030879.041218155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.WIT_USKPL_SS001_WT013_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.WIT_USKPL_SS001_WT013_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT013_level_1_zone.WIT_USKPL_SS001_WT013_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.shapes = WIT_USKPL_SS001_WT014_level_1_zone
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.WIT_USKPL_SS001_WT014_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.WIT_USKPL_SS001_WT014_level_1_zone.origin = 632636.9223758458 4031002.691181155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.WIT_USKPL_SS001_WT014_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.WIT_USKPL_SS001_WT014_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT014_level_1_zone.WIT_USKPL_SS001_WT014_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.shapes = WIT_USKPL_SS001_WT015_level_1_zone
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.WIT_USKPL_SS001_WT015_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.WIT_USKPL_SS001_WT015_level_1_zone.origin = 631832.4027448458 4032048.101518155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.WIT_USKPL_SS001_WT015_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.WIT_USKPL_SS001_WT015_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT015_level_1_zone.WIT_USKPL_SS001_WT015_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.shapes = WIT_USKPL_SS001_WT016_level_1_zone
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.WIT_USKPL_SS001_WT016_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.WIT_USKPL_SS001_WT016_level_1_zone.origin = 632201.3319688458 4032303.521669155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.WIT_USKPL_SS001_WT016_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.WIT_USKPL_SS001_WT016_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT016_level_1_zone.WIT_USKPL_SS001_WT016_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.shapes = WIT_USKPL_SS001_WT017_level_1_zone
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.WIT_USKPL_SS001_WT017_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.WIT_USKPL_SS001_WT017_level_1_zone.origin = 632547.8327458458 4032574.951600155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.WIT_USKPL_SS001_WT017_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.WIT_USKPL_SS001_WT017_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT017_level_1_zone.WIT_USKPL_SS001_WT017_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.shapes = WIT_USKPL_SS001_WT018_level_1_zone
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.WIT_USKPL_SS001_WT018_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.WIT_USKPL_SS001_WT018_level_1_zone.origin = 632935.2826138458 4032570.6311981548 23.325000000000003
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.WIT_USKPL_SS001_WT018_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.WIT_USKPL_SS001_WT018_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT018_level_1_zone.WIT_USKPL_SS001_WT018_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.shapes = WIT_USKPL_SS001_WT019_level_1_zone
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.WIT_USKPL_SS001_WT019_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.WIT_USKPL_SS001_WT019_level_1_zone.origin = 636264.4726088458 4029678.881692155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.WIT_USKPL_SS001_WT019_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.WIT_USKPL_SS001_WT019_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT019_level_1_zone.WIT_USKPL_SS001_WT019_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.shapes = WIT_USKPL_SS001_WT020_level_1_zone
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.WIT_USKPL_SS001_WT020_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.WIT_USKPL_SS001_WT020_level_1_zone.origin = 635864.6722748458 4029643.401883155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.WIT_USKPL_SS001_WT020_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.WIT_USKPL_SS001_WT020_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT020_level_1_zone.WIT_USKPL_SS001_WT020_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.shapes = WIT_USKPL_SS001_WT021_level_1_zone
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.WIT_USKPL_SS001_WT021_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.WIT_USKPL_SS001_WT021_level_1_zone.origin = 635473.6822868459 4029643.331793155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.WIT_USKPL_SS001_WT021_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.WIT_USKPL_SS001_WT021_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT021_level_1_zone.WIT_USKPL_SS001_WT021_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.shapes = WIT_USKPL_SS001_WT022_level_1_zone
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.WIT_USKPL_SS001_WT022_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.WIT_USKPL_SS001_WT022_level_1_zone.origin = 635912.5126278459 4030934.811827155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.WIT_USKPL_SS001_WT022_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.WIT_USKPL_SS001_WT022_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT022_level_1_zone.WIT_USKPL_SS001_WT022_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.shapes = WIT_USKPL_SS001_WT023_level_1_zone
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.WIT_USKPL_SS001_WT023_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.WIT_USKPL_SS001_WT023_level_1_zone.origin = 636304.3919948458 4030846.5619641547 23.325000000000003
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.WIT_USKPL_SS001_WT023_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.WIT_USKPL_SS001_WT023_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT023_level_1_zone.WIT_USKPL_SS001_WT023_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.shapes = WIT_USKPL_SS001_WT024_level_1_zone
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.WIT_USKPL_SS001_WT024_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.WIT_USKPL_SS001_WT024_level_1_zone.origin = 636825.9826618459 4030848.571749155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.WIT_USKPL_SS001_WT024_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.WIT_USKPL_SS001_WT024_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT024_level_1_zone.WIT_USKPL_SS001_WT024_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.shapes = WIT_USKPL_SS001_WT025_level_1_zone
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.WIT_USKPL_SS001_WT025_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.WIT_USKPL_SS001_WT025_level_1_zone.origin = 637174.8827448458 4031020.571946155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.WIT_USKPL_SS001_WT025_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.WIT_USKPL_SS001_WT025_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT025_level_1_zone.WIT_USKPL_SS001_WT025_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.shapes = WIT_USKPL_SS001_WT026_level_1_zone
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.WIT_USKPL_SS001_WT026_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.WIT_USKPL_SS001_WT026_level_1_zone.origin = 637502.3222778458 4031293.781917155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.WIT_USKPL_SS001_WT026_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.WIT_USKPL_SS001_WT026_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT026_level_1_zone.WIT_USKPL_SS001_WT026_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.shapes = WIT_USKPL_SS001_WT027_level_1_zone
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.WIT_USKPL_SS001_WT027_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.WIT_USKPL_SS001_WT027_level_1_zone.origin = 637872.3921368459 4031166.581763155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.WIT_USKPL_SS001_WT027_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.WIT_USKPL_SS001_WT027_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT027_level_1_zone.WIT_USKPL_SS001_WT027_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.shapes = WIT_USKPL_SS001_WT028_level_1_zone
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.WIT_USKPL_SS001_WT028_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.WIT_USKPL_SS001_WT028_level_1_zone.origin = 638630.6226498458 4030574.241717155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.WIT_USKPL_SS001_WT028_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.WIT_USKPL_SS001_WT028_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT028_level_1_zone.WIT_USKPL_SS001_WT028_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.shapes = WIT_USKPL_SS001_WT030_level_1_zone
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.WIT_USKPL_SS001_WT030_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.WIT_USKPL_SS001_WT030_level_1_zone.origin = 639414.6026138458 4030507.031871155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.WIT_USKPL_SS001_WT030_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.WIT_USKPL_SS001_WT030_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT030_level_1_zone.WIT_USKPL_SS001_WT030_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.shapes = WIT_USKPL_SS001_WT031_level_1_zone
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.WIT_USKPL_SS001_WT031_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.WIT_USKPL_SS001_WT031_level_1_zone.origin = 639895.5328098459 4030599.541109155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.WIT_USKPL_SS001_WT031_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.WIT_USKPL_SS001_WT031_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT031_level_1_zone.WIT_USKPL_SS001_WT031_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.shapes = WIT_USKPL_SS001_WT032_level_1_zone
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.WIT_USKPL_SS001_WT032_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.WIT_USKPL_SS001_WT032_level_1_zone.origin = 640624.4925808458 4030609.071048155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.WIT_USKPL_SS001_WT032_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.WIT_USKPL_SS001_WT032_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT032_level_1_zone.WIT_USKPL_SS001_WT032_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.shapes = WIT_USKPL_SS001_WT033_level_1_zone
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.WIT_USKPL_SS001_WT033_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.WIT_USKPL_SS001_WT033_level_1_zone.origin = 638513.6326048458 4028620.4210991547 23.325000000000003
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.WIT_USKPL_SS001_WT033_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.WIT_USKPL_SS001_WT033_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT033_level_1_zone.WIT_USKPL_SS001_WT033_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.shapes = WIT_USKPL_SS001_WT034_level_1_zone
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.WIT_USKPL_SS001_WT034_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.WIT_USKPL_SS001_WT034_level_1_zone.origin = 638915.1322038458 4028629.991344155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.WIT_USKPL_SS001_WT034_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.WIT_USKPL_SS001_WT034_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT034_level_1_zone.WIT_USKPL_SS001_WT034_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.shapes = WIT_USKPL_SS001_WT035_level_1_zone
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.WIT_USKPL_SS001_WT035_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.WIT_USKPL_SS001_WT035_level_1_zone.origin = 639400.9625428459 4028571.801227155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.WIT_USKPL_SS001_WT035_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.WIT_USKPL_SS001_WT035_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT035_level_1_zone.WIT_USKPL_SS001_WT035_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.shapes = WIT_USKPL_SS001_WT036_level_1_zone
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.WIT_USKPL_SS001_WT036_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.WIT_USKPL_SS001_WT036_level_1_zone.origin = 641011.6122098458 4030630.591039155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.WIT_USKPL_SS001_WT036_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.WIT_USKPL_SS001_WT036_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT036_level_1_zone.WIT_USKPL_SS001_WT036_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.shapes = WIT_USKPL_SS001_WT037_level_1_zone
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.WIT_USKPL_SS001_WT037_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.WIT_USKPL_SS001_WT037_level_1_zone.origin = 641414.9921658458 4030602.131561155 23.325000000000003
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.WIT_USKPL_SS001_WT037_level_1_zone.xaxis = -63.803744000704 138.4010196909424 0.0
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.WIT_USKPL_SS001_WT037_level_1_zone.yaxis = -138.4010196909424 -63.803744000704 0.0
# tagging.WIT_USKPL_SS001_WT037_level_1_zone.WIT_USKPL_SS001_WT037_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.WIT_USKPL_SS001_WT038_level_1_zone.type = GeometryRefinement
# tagging.WIT_USKPL_SS001_WT038_level_1_zone.shapes = WIT_USKPL_SS001_WT038_level_1_zone
# tagging.WIT_USKPL_SS001_WT038_level_1_zone.level = 1
# tagging.WIT_USKPL_SS001_WT038_level_1_zone.WIT_USKPL_SS001_WT038_level_1_zone.type = box
# tagging.WIT_USKPL_SS001_WT038_level_1_zone.WIT_USKPL_SS001_WT038_level_1_zone.origin = 641824.3023748458 4030566.5818381547 23.325000000000003
# ...
# KProtor_.WIT_USKPL_SS001_WT061_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT061_KProtor.origin = 647749.0513493952 4025720.995861227 26.5
# KProtor_.WIT_USKPL_SS001_WT061_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT061_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT061_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT061_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT062_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT062_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT062_KProtor.origin = 648162.8717143952 4025716.965087227 26.5
# KProtor_.WIT_USKPL_SS001_WT062_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT062_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT062_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT062_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT063_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT063_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT063_KProtor.origin = 642520.9114583952 4024977.985408227 26.5
# KProtor_.WIT_USKPL_SS001_WT063_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT063_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT063_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT063_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT064_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT064_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT064_KProtor.origin = 642931.0216533953 4025053.815417227 26.5
# KProtor_.WIT_USKPL_SS001_WT064_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT064_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT064_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT064_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT065_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT065_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT065_KProtor.origin = 643347.6015893952 4025063.705575227 26.5
# KProtor_.WIT_USKPL_SS001_WT065_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT065_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT065_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT065_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT066_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT066_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT066_KProtor.origin = 643730.7616403952 4025052.125725227 26.5
# KProtor_.WIT_USKPL_SS001_WT066_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT066_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT066_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT066_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT067_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT067_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT067_KProtor.origin = 644167.0021843952 4024974.285210227 26.5
# KProtor_.WIT_USKPL_SS001_WT067_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT067_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT067_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT067_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT068_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT068_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT068_KProtor.origin = 644513.4519953952 4025132.795354227 26.5
# KProtor_.WIT_USKPL_SS001_WT068_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT068_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT068_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT068_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT069_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT069_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT069_KProtor.origin = 644914.6618013952 4025093.015239227 26.5
# KProtor_.WIT_USKPL_SS001_WT069_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT069_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT069_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT069_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT070_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT070_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT070_KProtor.origin = 645344.0721183952 4025049.065540227 26.5
# KProtor_.WIT_USKPL_SS001_WT070_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT070_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT070_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT070_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT071_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT071_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT071_KProtor.origin = 645932.0618253952 4024898.345335227 26.5
# KProtor_.WIT_USKPL_SS001_WT071_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT071_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT071_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT071_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT072_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT072_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT072_KProtor.origin = 638251.0821703952 4027531.795808227 26.5
# KProtor_.WIT_USKPL_SS001_WT072_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT072_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT072_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT072_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT073_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT073_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT073_KProtor.origin = 638695.8317933952 4027384.845399227 26.5
# KProtor_.WIT_USKPL_SS001_WT073_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT073_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT073_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT073_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT074_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT074_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT074_KProtor.origin = 640055.0115123952 4026780.135194227 26.5
# KProtor_.WIT_USKPL_SS001_WT074_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT074_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT074_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT074_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT075_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT075_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT075_KProtor.origin = 640373.1421773952 4026363.855994227 26.5
# KProtor_.WIT_USKPL_SS001_WT075_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT075_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT075_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT075_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT076_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT076_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT076_KProtor.origin = 641293.1716193953 4026766.855054227 26.5
# KProtor_.WIT_USKPL_SS001_WT076_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT076_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT076_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT076_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT077_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT077_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT077_KProtor.origin = 641642.4521783952 4027202.215590227 26.5
# KProtor_.WIT_USKPL_SS001_WT077_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT077_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT077_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT077_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT078_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT078_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT078_KProtor.origin = 642050.5921523952 4027509.765413227 26.5
# KProtor_.WIT_USKPL_SS001_WT078_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT078_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT078_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT078_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT080_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT080_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT080_KProtor.origin = 637836.5214153952 4027340.915367227 26.5
# KProtor_.WIT_USKPL_SS001_WT080_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT080_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT080_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT080_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT081_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT081_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT081_KProtor.origin = 637352.0321453952 4027127.425621227 26.5
# KProtor_.WIT_USKPL_SS001_WT081_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT081_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT081_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT081_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT082_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT082_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT082_KProtor.origin = 636964.4317033952 4027160.405463227 26.5
# KProtor_.WIT_USKPL_SS001_WT082_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT082_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT082_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT082_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT083_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT083_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT083_KProtor.origin = 636567.6419703952 4027102.625197227 26.5
# KProtor_.WIT_USKPL_SS001_WT083_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT083_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT083_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT083_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT084_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT084_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT084_KProtor.origin = 636175.1914633953 4027069.806049227 26.5
# KProtor_.WIT_USKPL_SS001_WT084_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT084_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT084_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT084_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT085_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT085_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT085_KProtor.origin = 635675.2214533952 4027416.495507227 26.5
# KProtor_.WIT_USKPL_SS001_WT085_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT085_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT085_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT085_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT086_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT086_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT086_KProtor.origin = 635290.9118203953 4027342.024994227 26.5
# KProtor_.WIT_USKPL_SS001_WT086_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT086_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT086_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT086_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT087_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT087_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT087_KProtor.origin = 634978.8519193953 4027109.276030227 26.5
# KProtor_.WIT_USKPL_SS001_WT087_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT087_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT087_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT087_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
# KProtor_.WIT_USKPL_SS001_WT088_KProtor.type = PlaneSampler
# KProtor_.WIT_USKPL_SS001_WT088_KProtor.num_points = 153 45
# KProtor_.WIT_USKPL_SS001_WT088_KProtor.origin = 634587.3218963952 4027044.055469227 26.5
# KProtor_.WIT_USKPL_SS001_WT088_KProtor.axis1 = -1380.3776242141237 -636.3628010568902 0.0
# KProtor_.WIT_USKPL_SS001_WT088_KProtor.axis2 = 0.0 0.0 443.5
# KProtor_.WIT_USKPL_SS001_WT088_KProtor.offset_vector = -0.4186597375374278 0.9081431738250814 0.0
# KProtor_.WIT_USKPL_SS001_WT088_KProtor.offsets = 0.0 255.0 510.0 765.0 1020.0 1275.0 1530.0 1785.0 2040.0
#
# #---- extra params ----
# #== END AMR-WIND INPUT ==
