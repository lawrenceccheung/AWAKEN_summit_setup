# %% [markdown]
# # Domain size check

# %%
# Load the amrwind-frontend module

# Location of amrwind-frontend 
amrwindfedirs = ['/projects/wind_uq/lcheung/amrwind-frontend',
                 '/ccs/proj/cfd162/lcheung/amrwind-frontend/']
import sys, os
for x in amrwindfedirs: sys.path.insert(1, x)


# Load the libraries
import amrwind_frontend  as amrwind
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy             as np
import math

# Also ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Make all plots inline 
# %matplotlib inline

# %%
# Add this to load local packages
import sys
#sys.path.insert(1, '/ascldap/users/lcheung/.local/lib/python2.7/site-packages')
import utm
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the data from the database of all turbines
df = pd.read_csv('../../../uswtdb/uswtdb_v3_3_20210114.csv',low_memory=False)

# %%
turbines=[]
addKingPlains     = True
addArmadilloFlats = True
addThunderRanch   = False
addBreckinridge   = False
addChisholmView   = False

# %%
# All turbines must fit within these utm limits 
turb_inside_box = [[620000, 650000],  # UTM Easting
                   [4.009E6, 4.035E6],  # UTM Northing  
                  ]

# %% [markdown]
# ### King Plains turbines

# %%
KPturbs1=df[df['p_name']=="unknown Noble County"]
KPturbs2=df[df['p_name']=="unknown Garfield County"]

KPcount = 0

if addKingPlains:
    ge2p8='GE2.8-127'
    turblist = []
    # Turbines from Noble County
    for index, row in KPturbs1.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue
        datarow = {'faa_asn':row['faa_asn'].replace('OE','KP'), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':ge2p8}
        turbines.append(datarow)
        KPcount += 1
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    
    # Turbines from Garfield County
    for index, row in KPturbs2.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue        
        datarow = {'faa_asn':row['faa_asn'].replace('OE','KP'), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':ge2p8}
        if utmxy[1]>4020000:  # Remove the ones from Armadillo Ranch
            turbines.append(datarow)    
            KPcount += 1
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
        
    print("King Plains: %i turbines"%(KPcount))
    print('Turbine types: '+repr(turblist))
# Out:
# King Plains: 88 turbines
# Turbine types: ['GE2.8-127']

# %% [markdown]
# ### Armadillo flats turbines

# %%
# This is the old approach
if addArmadilloFlats and False:
    AFturbs=df[df['p_name']=="Armadillo Flats"]
    turblist = []
    # Turbines from Armadillo Flats
    for index, row in AFturbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue        
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','AF').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    
    print("Armadillo Flats: %i turbines"%(len(AFturbs)))
    print('Turbine types: '+repr(turblist))
    
# This the new approach
if addArmadilloFlats:
    newdf = pd.read_csv('../../../farmlayout/AF_BR_Turbines.csv',low_memory=False)
    AFturbs=newdf[newdf['Turbine Display Name'].str.startswith("WAF1")]
    turblist = []
    turbtypes = []
    # Turbines from Armadillo Flats
    for index, row in AFturbs.iterrows():
        #utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        name    = row['Turbine Display Name']+'-AF'
        lat     = row['Turbine Latitude']
        long    = row['Turbine Longitude']
        Easting = row['Easting']
        Northing= row['Northing']        
        t_model = row['Turbine Type'].replace('1.7 MW','GE1.7-103').replace('2.3 MW', 'GE2.3-116')
        utmxy   = (Easting, Northing) #(lat, long)
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue        
        datarow = {'faa_asn':name, 
                   'lat':lat, 'long':long, 'utm':(utmxy[0], utmxy[1]), 
                   't_model':t_model}
        turbines.append(datarow)
        turbtypes.append(datarow['t_model'])
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])     

    print("Armadillo Flats: %i turbines"%(len(AFturbs)))
    print('Turbine types: '+repr(turblist))
    for t in turblist:
        print("%s: %i"%(t,turbtypes.count(t)))
# Out:
# Armadillo Flats: 126 turbines
# Turbine types: ['GE1.7-103', 'GE2.3-116']
# GE1.7-103: 80
# GE2.3-116: 46

# %% [markdown]
# ## Thunder Ranch turbines

# %%
TRturbs=df[df['p_name']=="Thunder Ranch"]

# %%
if addThunderRanch:
    turblist = []
    for index, row in TRturbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue        
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','TR').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    print("Thunder Ranch: %i turbines"%(len(TRturbs)))
    print('Turbine types: '+repr(turblist))

# %% [markdown]
# ## Breckenridge turbines

# %%
BRturbs=df[df['p_name']=="Breckinridge"]

# %%
if addBreckinridge:
    turblist = []
    for index, row in BRturbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue        
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','BR').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
    print("Breckinridge: %i turbines"%(len(BRturbs)))
    print('Turbine types: '+repr(turblist))

# %% [markdown]
# ## Add Chisholm View

# %%
CV1turbs=df[df['p_name']=="Chisholm View"]
CV2turbs=df[df['p_name']=="Chisholm View II"]

# %%
CVcount = 0

if addChisholmView:
    turblist = []
    for index, row in CV1turbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue        
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','CV').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)   
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
        CVcount += 1
    for index, row in CV2turbs.iterrows():
        utmxy   = utm.from_latlon(row['ylat'], row['xlong'])
        if ((utmxy[0] < turb_inside_box[0][0]) or (utmxy[0] > turb_inside_box[0][1]) or 
            (utmxy[1] < turb_inside_box[1][0]) or (utmxy[1] > turb_inside_box[1][1])):
            continue        
        datarow = {'faa_asn':str(row['faa_asn']).replace('OE','CV').replace('nan','T'+str(index)), 
                   'lat':row['ylat'], 'long':row['xlong'], 'utm':(utmxy[0], utmxy[1]), 
                   't_model':row['t_model']}
        turbines.append(datarow)   
        if datarow['t_model'] not in turblist: turblist.append(datarow['t_model'])
        CVcount += 1
    print("Chisholm View: %i turbines"%(CVcount))
    print('Turbine types: '+repr(turblist))

# %%
print("Total turbines: %i"%(len(turbines)))
# Out:
# Total turbines: 214

# %% [markdown]
# ### Write the CSV file

# %%
summitcsv = 'turbines.csv'

verbose=False

# CSV file should have columns with
# name, x, y, type, yaw, hubheight, options
header="""# name, x, y, type, yaw, hubheight, options"""
with open(summitcsv, 'w') as f:
    f.write(header+'\n')
    if verbose: print(header)
    for x in turbines: 
        #line='%s, %f, %f, %s, , ,'%(x['faa_asn'], x['lat'], x['long'], 'Summit_'+x['t_model'])
        line='%s, %f, %f, %s, , ,'%(x['faa_asn'], x['utm'][0], x['utm'][1], 'Summit_'+x['t_model'])
        f.write(line+'\n')
        if verbose: print(line)

# %% [markdown]
# ## AWAKEN Wind farm layout for Summit

# %% [markdown]
# **Note**: to make sure that the correct turbines are in place for setting up this layout file, make sure something like this file is in place:

# %%
with open("../../../turbines/summitlayoutturbs.yaml")as f: print(f.read())
# Out:
# turbines:
#   Joukowski_GE1p68-82.5_calibLCC:
#     turbinetype_name:            "Summit_GE1.68-82.5"
#     turbinetype_comment:         Calibrated Joukowski Model
#     # See data in /projects/AWAKEN/lcheung/awaken.github/TurbineCheckout/NREL-1.68-82.5.csv
#     # Calibration notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE1.68-82.5/RunCalibration_Joukowski_Eps5.00_V10_newcurves.ipynb
#     # Plot curves notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE1.68-82.5/PlotCurves5.ipynb
#     cp_table:                     0.3016713057677416 0.39345186124735865 0.3932593872884728 0.3916920326945722 0.39000648367796215 0.3884360746578687 0.387129236715039 0.386181402329401 0.38565332474606967 0.38557671355846646 0.38519215792947603 0.38432907066672434 0.38861989389694285 0.4062033815759146 0.40357836305334926 0.37955694089972913 0.34474609939979 0.30627114196178934 0.268216840493811 0.24923712453314853 0.22172972498450214 0.17367047677103206 0.13664974727612442 0.1082060950027497 0.08634223902504749 0.06949132044205408 0.056446985164931664 0.04629510134017421 0.038346025144364915 0.03208095870576853
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      82.5
#     Actuator_hub_height:          80
#     Actuator_output_frequency:    1
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    10.0    # might need to play with this
#     # --------------------
#     Actuator_wind_speed:          3.0 3.8896499632398522 4.684006996752298 5.377830233987224 5.9665420922679235 6.446258473946166 6.813814392205923 7.066784852446476 7.203500851477442 7.223060388969041 7.3207863594297695 7.53515307893962 7.8647462371540815 8.307391303370766 8.860167873258565 9.519428936578255 10.280824938773396 11.139332477682313 12.089287446041034 12.622632732353626 13.124422401115686 14.2379079149135 15.42239763215957 16.67007673876378 17.972713521001403 19.321713675239483 20.708177009893888 22.122956165519167 23.556716965618214 25.0
#     Actuator_rpm:                 8.000000000407963 8.000000000407963 9.602449293650405 11.0248217322322 12.231710571559455 13.215153216626533 13.968661285704481 14.487263418223835 14.767538073926923 14.807636106893261 15.007979248283226 15.44744177593674 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291 15.760974947029291
#     Actuator_thrust_coeff:        1.0117545076546912 0.883314192303627 0.8818404900751321 0.8818404900751318 0.881840490075132 0.8818404900751319 0.8818404900751319 0.8818404900751319 0.8818404900751315 0.8818404900751319 0.8818404900751322 0.881840490075132 0.8712367627531024 0.7867752979507233 0.7257269236862279 0.6286847514451789 0.5390146754884892 0.45913367150244344 0.3898129866147723 0.35756691210576774 0.3136815237231712 0.24127707449985478 0.18856357329696818 0.14943933647824204 0.12000663360983989 0.09758134469844537 0.08054549223984131 0.06724291097749342 0.056974742018472614 0.04897929796220479
#     # --------------------
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   Joukowski_GE1.715-103_calib:
#     turbinetype_name:             "Summit_GE1.715-103"
#     turbinetype_comment:          Calibrated Joukowski Model
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      103
#     Actuator_hub_height:          80
#     Actuator_output_frequency:    1
#     # --------------------
#     # Plot curves notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE1.7-103/PlotCurves3.ipynb
#     # Calibration notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE1.7-103/RunCalibration_Joukowski_dx_Eps5.ipynb
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    13.0    # might need to play with this
#     Actuator_wind_speed:          3.0 3.889649963239854 4.684006996752303 5.377830233987229 5.966542092267928 6.44625847394617 6.8138143922059236 7.066784852446481 7.203500851477444 7.22306038896904 7.320786359429763 7.535153078939617 7.864746237154081 8.30739130337076 8.860167873258558 9.519428936578247 10.280824938773394 10.681872976809931 11.13933247768231 12.08928744604103 13.12442240111568 14.237907914913496 15.422397632159566 16.670076738763772 17.972713521001396 19.321713675239476 20.708177009893884 22.122956165519163 23.556716965618207 25.0
#     Actuator_rpm:                 8.000000000407963 8.000000000407963 8.000000000407963 8.915211469393155 9.891160966263108 10.68642091347471 11.29574448739556 11.715111602091959 11.941755432331782 11.97418066804842 12.136187956267158 12.491558905753875 13.037948913712258 13.771753106017414 14.688130120808689 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277
#     Actuator_thrust_coeff:        1.1409841836260257 0.9482259036041606 0.8334389504747425 0.8144879858280086 0.8144879858280089 0.8144879858280087 0.8144879858280089 0.8144879858280087 0.814487985828009 0.814487985828009 0.8144879858280089 0.8144879858280085 0.769031688060892 0.6904868066653629 0.607026893875481 0.5258624112793866 0.4508563728896142 0.4429667182262618 0.3441900398282224 0.2627970090552418 0.2028465297072238 0.1581634901080046 0.12466485192904814 0.09944345440468834 0.08018126095888073 0.06565832966439472 0.054319986694619404 0.04568030208339344 0.03896700467518228 0.03360712014602656
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   Joukowski_GE1.7-103_calib:
#     turbinetype_name:             "Summit_GE1.7-103"
#     turbinetype_comment:          Calibrated Joukowski Model
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      103
#     Actuator_hub_height:          80
#     Actuator_output_frequency:    1
#     # --------------------
#     # Plot curves notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE1.7-103/PlotCurves3.ipynb
#     # Calibration notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE1.7-103/RunCalibration_Joukowski_dx_Eps5.ipynb
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    13.0    # might need to play with this
#     Actuator_wind_speed:          3.0 3.889649963239854 4.684006996752303 5.377830233987229 5.966542092267928 6.44625847394617 6.8138143922059236 7.066784852446481 7.203500851477444 7.22306038896904 7.320786359429763 7.535153078939617 7.864746237154081 8.30739130337076 8.860167873258558 9.519428936578247 10.280824938773394 10.681872976809931 11.13933247768231 12.08928744604103 13.12442240111568 14.237907914913496 15.422397632159566 16.670076738763772 17.972713521001396 19.321713675239476 20.708177009893884 22.122956165519163 23.556716965618207 25.0
#     Actuator_rpm:                 8.000000000407963 8.000000000407963 8.000000000407963 8.915211469393155 9.891160966263108 10.68642091347471 11.29574448739556 11.715111602091959 11.941755432331782 11.97418066804842 12.136187956267158 12.491558905753875 13.037948913712258 13.771753106017414 14.688130120808689 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277 14.735742990092277
#     Actuator_thrust_coeff:        1.1409841836260257 0.9482259036041606 0.8334389504747425 0.8144879858280086 0.8144879858280089 0.8144879858280087 0.8144879858280089 0.8144879858280087 0.814487985828009 0.814487985828009 0.8144879858280089 0.8144879858280085 0.769031688060892 0.6904868066653629 0.607026893875481 0.5258624112793866 0.4508563728896142 0.4429667182262618 0.3441900398282224 0.2627970090552418 0.2028465297072238 0.1581634901080046 0.12466485192904814 0.09944345440468834 0.08018126095888073 0.06565832966439472 0.054319986694619404 0.04568030208339344 0.03896700467518228 0.03360712014602656
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   Joukowski_GE1.79-100_calib:
#     turbinetype_name:             "Summit_GE1.79-100"
#     turbinetype_comment:          Calibrated Joukowski Model
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      100
#     Actuator_hub_height:          80
#     Actuator_output_frequency:    1
#     # Plot curves notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE1.79-100/PlotCurves4.ipynb
#     # Calibration notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE2.3-116/RunCalibration_Joukowski_Eps5.00.ipynb
#     # --------------------
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    13.0    # might need to play with this
#     # Performance tables come from https://github.com/scottryn/openfast-turbine-models/blob/awaken/IEA-scaled/NREL-1.79-100/NREL-1.79-100.csv
#     Actuator_wind_speed:          3.0 3.889649963239854 4.684006996752303 5.377830233987229 5.966542092267928 6.44625847394617 6.8138143922059236 7.066784852446481 7.203500851477444 7.22306038896904 7.320786359429763 7.535153078939617 7.864746237154081 8.30739130337076 8.860167873258558 9.519428936578247 10.280824938773394 10.681872976809931 11.13933247768231 12.08928744604103 13.12442240111568 14.237907914913496 15.422397632159566 16.670076738763772 17.972713521001396 19.321713675239476 20.708177009893884 22.122956165519163 23.556716965618207 25.0
#     Actuator_rpm:                 8 8 8 9.172052607 10.17611854 10.99428938 11.62116715 12.05261594 12.28578923 12.31914861 12.48582322 12.85143216 13.41356329 14.16850788 15.11128509 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965 15.16026965
#     Actuator_thrust_coeff:        1.158093814 0.958191954 0.842281443 0.841410733 0.841410733 0.841410733 0.841410733 0.841410733 0.841410733 0.841410733 0.841410733 0.841410733 0.784534886 0.743327664 0.653457742 0.566093507 0.485349168 0.448263929 0.387457153 0.293997037 0.226171155 0.176059266 0.13865674 0.110481935 0.089183188 0.072941144 0.060464209 0.05074999 0.043180894 0.037323406
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   Joukowski_GE2.3-116_calib:
#     turbinetype_name:             "Summit_GE2.3-116"
#     turbinetype_comment:          Calibrated Joukowski Model
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      116
#     Actuator_hub_height:          79.13
#     Actuator_output_frequency:    1
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    13.0    # might need to play with this
#     # --------------------
#     # Calibration notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE2.3-116v2/PlotCurves5.ipynb
#     # Plot curves notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE2.3-116v2/RunCalibration_Joukowski_Eps5.00.ipynb
#     # Performance tables come from https://raw.githubusercontent.com/scottryn/openfast-turbine-models/awaken/IEA-scaled/NREL-2.3-116v2/NREL-2.3-116v2.csv
#     Actuator_wind_speed:          3.0 3.88964996324 4.68400699675 5.37783023399 5.96654209227 6.44625847395 6.81381439221 7.06678485245 7.20350085148 7.22306038897 7.32078635943 7.53515307894 7.86474623715 8.30739130337 8.86016787326 9.51942893658 10.2808249388 10.666701665 11.1393324777 12.089287446 13.1244224011 14.2379079149 15.4223976322 16.6700767388 17.972713521 19.3217136752 20.7081770099 22.1229561655 23.5567169656 25.0
#     Actuator_rpm:                 5.5000000004 5.75037302746 6.92473300917 7.95046603577 8.82080470964 9.53000686616 10.0733934584 10.4473794276 10.6494973561 10.6784137465 10.8228896736 11.1398047208 11.6270680029 12.2814647413 13.0986774745 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928 13.1411379928
#     Actuator_thrust_coeff:        0.954507219906 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.825528199043 0.783349572265 0.70350019482 0.618468919247 0.535777323951 0.459357035319 0.42672327994 0.365913371426 0.278322400085 0.214295350009 0.16682330754 0.131321242632 0.104627252356 0.0843043046388 0.0688873781101 0.0570148296211 0.0479287006257 0.0408743046551 0.0353712993522
#     # --------------------
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   Joukowski_GE24-107_calibLCC:
#     turbinetype_name:            "Summit_GE2.4-107"
#     turbinetype_comment:         Calibrated Joukowski Model
#     # Data from: /projects/AWAKEN/lcheung/awaken.github/TurbineCheckout/NREL-2.4-107.csv
#     # Calibration notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE2.4-107/RunCalibration_Joukowski_Eps5.00_V10.ipynb
#     # Plot curves notebook in ~/nscratch/2021/AWAKEN/turbinerun/GE2.4-107/PlotCurves5.ipynb
#     cp_table:                     0.36494385462317414 0.4057145978707475 0.4084886140722456 0.40946212302108115 0.4096561912443821 0.4095095462889279 0.40925413639551833 0.40901754531776574 0.4088697364261277 0.4088478196027903 0.40873507340273457 0.4084632901716705 0.407995749539033 0.4170768820129709 0.40588823577147537 0.3796030302648449 0.34406136739661386 0.30542169789935647 0.29577684585916003 0.24594889649219775 0.19222345625083997 0.1505595894610731 0.1184647817941693 0.0938067981129045 0.07485292870062624 0.06024300928446688 0.04893519660859818 0.04013447234603446 0.033243315049715394 0.02781156743979472
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      107
#     Actuator_hub_height:          80
#     Actuator_output_frequency:    1
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    10.0    # might need to play with this
#     # --------------------
#     Actuator_wind_speed:          3.0 3.8896499632398522 4.684006996752298 5.377830233987224 5.9665420922679235 6.446258473946166 6.813814392205923 7.066784852446476 7.203500851477442 7.223060388969041 7.3207863594297695 7.53515307893962 7.8647462371540815 8.307391303370766 8.860167873258565 9.519428936578255 10.280824938773396 11.139332477682313 11.368266947340883 12.089287446041034 13.124422401115686 14.2379079149135 15.42239763215957 16.67007673876378 17.972713521001403 19.321713675239483 20.708177009893888 22.122956165519167 23.556716965618214 25.0
#     Actuator_rpm:                 5.500000000399841 6.216061563190254 7.485525980331192 8.59432702859619 9.535149259037933 10.301785483264918 10.889177726117152 11.293450596268706 11.511936854590438 11.543195011582549 11.699371185389309 12.041951298809709 12.568675138134543 13.276067579163733 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472 14.000000000236472
#     Actuator_thrust_coeff:        0.9417637121427401 0.8591023656623112 0.8591023656623112 0.8591023656623115 0.8591023656623114 0.8591023656623114 0.8591023656623114 0.8591023656623114 0.8591023656623115 0.859102365662311 0.8591023656623115 0.8591023656623114 0.8591023656623112 0.7946025198026082 0.7010491180644189 0.6073318868751941 0.5207061845780487 0.4435376564475198 0.4258539432711849 0.34314148550753276 0.26171231400949135 0.20244647825140952 0.15862645919422833 0.1258607265652833 0.10102264915823013 0.08221636164540955 0.06771371069636782 0.05668709221197275 0.04797694606348537 0.04122339888144193
#     # --------------------
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   Joukowski_GE2.5-116_calib:
#     turbinetype_name:             "Summit_GE2.5-116"
#     turbinetype_comment:          Calibrated Joukowski Model
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      116
#     Actuator_hub_height:          90
#     Actuator_output_frequency:    1
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    13.0    # might need to play with this
#     # --------------------
#     # Performance tables come from https://raw.githubusercontent.com/NREL/openfast-turbine-models/master/IEA-scaled/NREL-2.5-116/NREL-2.5-116_openfast.csv
#     Actuator_wind_speed:          3.0 3.889649963239854 4.684006996752303 5.377830233987229 5.966542092267928 6.44625847394617 6.8138143922059236 7.066784852446481 7.203500851477444 7.22306038896904 7.320786359429763 7.535153078939617 7.864746237154081 8.30739130337076 8.860167873258558 9.519428936578247 10.280824938773394 10.589724312062877 11.13933247768231 12.08928744604103 13.12442240111568 14.237907914913496 15.422397632159566 16.670076738763772 17.972713521001396 19.321713675239476 20.708177009893884 22.122956165519163 23.556716965618207 25.0
#     Actuator_rpm:                 5.500000000399841 5.7503730274604 6.924733009169061 7.950466035772244 8.820804709636782 9.530006866155707 10.073393458373337 10.447379427563192 10.649497356086282 10.678413746477254 10.82288967359941 11.139804720841314 11.627068002870239 12.28146474128283 13.098677474494233 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643
#     Actuator_thrust_coeff:        0.795419507524108 0.8163759621542088 0.8163759621542089 0.8163759621542088 0.8163759621542088 0.8163759621542093 0.8163759621542093 0.816375962154209 0.8163759621542089 0.816375962154209 0.8163759621542089 0.8163759621542088 0.8163759621542088 0.7816497292837605 0.6881024487256834 0.5960935792514858 0.5110705883010171 0.48169007343985104 0.3992418445397665 0.301726241148816 0.23137184415660814 0.17948146484830918 0.1408250546606467 0.11178366795199553 0.08975645587417404 0.07310080594700819 0.060299514659720915 0.0504505646442757 0.04286514300370846 0.03692885272686376
#     # --------------------
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   Summit_GE2.8-127:
#     turbinetype_name:    "Summit_GE2.8-127"
#     turbinetype_comment:          THIS IS A PLACEHOLDER
#     Actuator_type:                JoukowskyDisk
#     Actuator_rotor_diameter:      127
#     Actuator_hub_height:          90
#     Actuator_output_frequency:    1
#     Actuator_diameters_to_sample: 2.5     # How far upstream to sample inflow wind
#     Actuator_epsilon:             [5.0, 5.0, 5.0]   # Epsilon in Z (might need to play with this guy)
#     Actuator_num_points_r:        40      # number of radial (might need to play with this guy)
#     Actuator_num_points_t:        5       # number of pts in theta (might need to play with this guy)
#     Actuator_vortex_core_size:    13.0    # might need to play with this
#     # --------------------
#     # Performance tables come from https://raw.githubusercontent.com/NREL/openfast-turbine-models/master/IEA-scaled/NREL-2.5-116/NREL-2.5-116_openfast.csv
#     Actuator_wind_speed:          3.0 3.889649963239854 4.684006996752303 5.377830233987229 5.966542092267928 6.44625847394617 6.8138143922059236 7.066784852446481 7.203500851477444 7.22306038896904 7.320786359429763 7.535153078939617 7.864746237154081 8.30739130337076 8.860167873258558 9.519428936578247 10.280824938773394 10.589724312062877 11.13933247768231 12.08928744604103 13.12442240111568 14.237907914913496 15.422397632159566 16.670076738763772 17.972713521001396 19.321713675239476 20.708177009893884 22.122956165519163 23.556716965618207 25.0
#     Actuator_rpm:                 5.500000000399841 5.7503730274604 6.924733009169061 7.950466035772244 8.820804709636782 9.530006866155707 10.073393458373337 10.447379427563192 10.649497356086282 10.678413746477254 10.82288967359941 11.139804720841314 11.627068002870239 12.28146474128283 13.098677474494233 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643 13.141137992834643
#     Actuator_thrust_coeff:        0.795419507524108 0.8163759621542088 0.8163759621542089 0.8163759621542088 0.8163759621542088 0.8163759621542093 0.8163759621542093 0.816375962154209 0.8163759621542089 0.816375962154209 0.8163759621542089 0.8163759621542088 0.8163759621542088 0.7816497292837605 0.6881024487256834 0.5960935792514858 0.5110705883010171 0.48169007343985104 0.3992418445397665 0.301726241148816 0.23137184415660814 0.17948146484830918 0.1408250546606467 0.11178366795199553 0.08975645587417404 0.07310080594700819 0.060299514659720915 0.0504505646442757 0.04286514300370846 0.03692885272686376
#     # --------------------
#     Actuator_use_tip_correction:  True
#     Actuator_use_root_correction: True
#     Actuator_num_blades:          3
#   nrel2.8_127_ADM_bugfix:
#     turbinetype_name:             "Summit_GE2.8-127_ADM"
#     turbinetype_comment:
#     Actuator_type:                TurbineFastDisk
#     Actuator_openfast_input_file: OpenFAST3p3_NREL2p8-127.bugfix/NREL-2p8-127.fst
#     Actuator_rotor_diameter:      127
#     Actuator_hub_height:          90
#     Actuator_num_points_blade:    64
#     Actuator_num_points_tower:    12
#     Actuator_epsilon:             [5.0, 5.0, 5.0]
#     Actuator_epsilon_tower:       [5.0, 5.0, 5.0]
#     Actuator_openfast_start_time: 0.0
#     Actuator_openfast_stop_time:  10000.0
#     Actuator_nacelle_drag_coeff:  1.0
#     Actuator_nacelle_area:        8.0
#     Actuator_output_frequency:    1
#     turbinetype_filedir: OpenFAST3p3_NREL2p8-127.bugfix

# %% [markdown]
# ## Set up the ABL parameters and conditions

# %%
# Start the AMR-Wind case
case = amrwind.MyApp.init_nogui()

# %%
WS     = 10.05         # Wind speed, m/s
WDir   = 180           # Wind direction, degrees
farm_domainsize = [3*10240.0, 3*10240.0, 1920]
farm_center     = [635000, 4.0235E6]   # In utm
#print(utm.from_latlon(36.587395, -97.756294))
#farm_center          = utm.to_latlon(640000, 4030000, 14, 'S')
print("Farm center = "+repr(farm_center)) # in lat/long
farm_background_mesh = 10
# Out:
# Farm center = [635000, 4023500.0]

# %%
# Set the wind speed and direction
case.setAMRWindInput('useWSDir', True)                           # Allows you to specify wind speed + wind direction 
case.setAMRWindInput('ABL_windspeed', WS, forcechange=True)     # Wind speed of 9 m/s
case.setAMRWindInput('ABL_winddir',   WDir, forcechange=True)     # Wind direction of 175 degrees
case.ABL_calculateWindVector()

# %%
# Set some tolerances (leave this alone)
tols = """
nodal_proj.mg_rtol                       = 1e-06               
nodal_proj.mg_atol                       = 1e-12               
mac_proj.mg_rtol                         = 1e-06               
mac_proj.mg_atol                         = 1e-12               
diffusion.mg_rtol                        = 1e-06               
diffusion.mg_atol                        = 1e-12               
temperature_diffusion.mg_rtol            = 1e-10               
temperature_diffusion.mg_atol            = 1e-13               
"""
case.loadAMRWindInput(tols, string=True);

# %%
case.loadTurbineCSVFile(summitcsv)

# %%
case.setAMRWindInput('turbines_coordsys', 'utm')

# Set up the domain 
case.setAMRWindInput('turbines_domainsize',         farm_domainsize)
case.setAMRWindInput('turbines_backgroundmeshsize', farm_background_mesh)
case.setAMRWindInput('turbines_autocalccenter',     False)
case.setAMRWindInput('turbines_farmcenter',         [farm_center[0], farm_center[1]])
case.setAMRWindInput('turbines_deleteprev', True)

# %%
# Preview the turbine layout
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=125)
case.setAMRWindInput('turbines_plotnames', False)
#case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
case.turbines_previewAllTurbines(ax=ax)

rect = patches.Rectangle((turb_inside_box[0][0], turb_inside_box[1][0]), 
                         turb_inside_box[0][1]-turb_inside_box[0][0], 
                         turb_inside_box[1][1]-turb_inside_box[1][0], linewidth=1, edgecolor='k', linestyle='--', facecolor='none')
ax.add_patch(rect)

# %%
case.getAMRWindInput('turbines_farmcenter')
# Out:
# [635000.0, 4023500.0]

# %%
case.turbines_createAllTurbines()

# Print out existing list of turbines, just to confirm that the turbines got made
print(len(case.listboxpopupwindict['listboxactuator'].getitemlist()))
# Out:
# CANNOT update: ABLMeanBoussinesq use forcechange=True in setval()
# 214

# %% [markdown]
# ## Add refinements

# %%
refinementcsv="""
# CSV file should have columns with
# level, upstream, downstream, lateral, below, above, options
level, upstream, downstream, lateral, below, above, options
#0,     13800,    15000,      18500,  100,  250,      center:farm units:meter
# KP
0,     6000,    6000,      9300,  100,  350, center:specified units:meter centerx:639000 centery:4029000 centerz:100
# AF
0,     8000,    8000,      8000,  100,  350, center:specified units:meter centerx:628000 centery:4017500 centerz:100   
#0,     4000,    3000,      7000,  100,  350, center:specified units:meter centerx:618000 centery:4035000 centerz:100

# Turbine refinement
1,     0.6,    0.6,     0.6,    0.525, 0.525, orientation:nacdir
"""
case.setAMRWindInput('refine_csvtextbox', refinementcsv)
case.setAMRWindInput('refine_deleteprev', True)

# %%
case.refine_createAllZones()

# %%
# Plot the domain (total domain)
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=150)
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
case.plotDomain(ax=ax)
ax.axis('scaled')
# Out:
# (618104.0, 651896.0, 4006604.0, 4040396.0)

# %%
# Plot the domain (total domain)
fig, ax = plt.subplots(figsize=(8,8), facecolor='w', dpi=150)
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = True
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XZ'
case.plotDomain(ax=ax)
ax.axis('auto')
# Out:
# (618104.0, 651896.0, -338.39203947324677, 2027.5424780701546)

# %%
case.listboxpopupwindict['listboxactuator'].deleteall()
print(case.listboxpopupwindict['listboxactuator'].getitemlist())
# Out:
# []

# %%
# Estimate mesh size
case.estimateMeshSize(verbose=False)
# Out:
# ESTIMATED MESH SIZE
#    Level       Ncells                      Cell Size
#        0   1811939328             10.0 x 10.0 x 10.0
#        1   1725120000                5.0 x 5.0 x 5.0
#        2     32850400                2.5 x 2.5 x 2.5
#   TOTAL:   3569909728

# %%
# Set up averaging
metmastpprosetup = case.get_default_postprosetupdict()
metmastpprosetup['postprocessing_setup_name'] = 'sampling'
metmastpprosetup['postprocessing_setup_type'] = 'Sampling'
metmastpprosetup['postprocessing_setup_output_frequency'] =  2000
metmastpprosetup['postprocessing_setup_fields']           =  'velocity'
case.add_postprosetup(metmastpprosetup, verbose=True)

sampleplane = case.get_default_samplingdict()
# Set up a sampling plane at two heights: z=60m and z=91m
sampleplane['sampling_name']         = 'p_hub'
sampleplane['sampling_type']         = 'PlaneSampler'
sampleplane['sampling_p_num_points'] = [1025, 1025]
sampleplane['sampling_p_origin']     = case.getAMRWindInput('geometry.prob_lo')
sampleplane['sampling_p_axis1']      = [4*10240, 0, 0]
sampleplane['sampling_p_axis2']      = [0, 4*10240, 0]
sampleplane['sampling_p_normal']     = [0, 0, 1]      # This is the direction I want to move/offset the planes
sampleplane['sampling_p_offsets']    = '60 91'        # This is how much to offset the planes
case.add_sampling(sampleplane)
# Out:
# postprocessing_setup_name: 'sampling'
# postprocessing_setup_type: 'Sampling'
# postprocessing_setup_output_frequency: 2000
# postprocessing_setup_fields: 'velocity'
# postprocessing_setup_derived_fields: None
# postprocessing_setup_averaging_window: None
# postprocessing_setup_averaging_start_time: None
# postprocessing_setup_averaging_stop_time: None

# %%
# Plot the domain (total domain)
fig, ax = plt.subplots(figsize=(5,5), facecolor='w', dpi=150)
case.popup_storteddata['plotdomain']['plot_turbines']        = case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_refineboxes']     = case.listboxpopupwindict['listboxtagging'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY'
#case.popup_storteddata['plotdomain']['plot_sampleprobes']    = ['p_hub']
case.plotDomain(ax=ax)
ax.axis('scaled')
plt.xlabel('UTM X [m]')
plt.ylabel('UTM Y [m]')
plt.title('Simulated AWAKEN Domain')
# Out:
# Text(0.5, 1.0, 'Simulated AWAKEN Domain')

# %% [markdown]
# ## Set AMR-Wind inputs

# %%
# Set the time constants
maxtime = 30000
dt      = 0.125
#case.setAMRWindInput('time.max_step',  80000)

case.setAMRWindInput('time.stop_time', maxtime)
case.setAMRWindInput('time.max_step',  -1) #int(maxtime/dt))
case.setAMRWindInput('time_control', ['const dt'])
case.setAMRWindInput('time.fixed_dt',  0.125)
case.setAMRWindInput('time.checkpoint_interval',  8000)
case.setAMRWindInput('time.plot_interval',  8000)

# %%
# Set some basic parameters
case.setAMRWindInput('incflo.physics',      ['ABL'])  # Must have ABL physics to do ABL calculations
case.setAMRWindInput('incflo.verbose',      3)        # This is optional, verbose=3 means more info in the output logs
case.setAMRWindInput('io.check_file',       'chk')    # What to name the checkpoint files

case.setAMRWindInput('incflo.use_godunov',  True)       # Always use a godunov scheme
case.setAMRWindInput('incflo.godunov_type', 'weno_z')   # Use 'weno_z' 

case.setAMRWindInput('turbulence.model',    ['OneEqKsgsM84'])    # One equation k-sgs subgrid scale model
case.setAMRWindInput('TKE.source_terms',    ['KsgsM84Src'])      # The corresponding source term

case.setAMRWindInput('transport.viscosity', 1.853e-05)           # viscosity
case.setAMRWindInput('incflo.density',      1.17)                # density

# %%
# Set the wind speed and direction
case.setAMRWindInput('useWSDir', True)                           # Allows you to specify wind speed + wind direction 
case.setAMRWindInput('ABL_windspeed', WS, forcechange=True)     # Wind speed of 9 m/s
case.setAMRWindInput('ABL_winddir',   WDir, forcechange=True)     # Wind direction of 175 degrees
case.ABL_calculateWindVector()

# %%
# Now set up ABL specific forces, parameters, etc.
case.setAMRWindInput('ICNS.source_terms',     ['ABLForcing','BoussinesqBuoyancy', 'CoriolisForcing', 'ABLMeanBoussinesq'])
# Out:
# CANNOT update: ABLMeanBoussinesq use forcechange=True in setval()

# %%
# This cell sets up boundary conditions
case.setAMRWindInput('is_periodicx', True)     # periodic in x
case.setAMRWindInput('is_periodicy', True)     # periodic in y
case.setAMRWindInput('is_periodicz', False)    # Enforce some boundary conditions in z

# Boundary conditions in z
case.setAMRWindInput('zlo.type',              'wall_model')          
case.setAMRWindInput('zlo.temperature_type',  'wall_model')          
case.setAMRWindInput('zlo.tke_type',          'zero_gradient')       
case.setAMRWindInput('zhi.type',              'slip_wall')           
case.setAMRWindInput('zhi.temperature_type',  'fixed_gradient')      
case.setAMRWindInput('zhi.temperature',       0.00125)

# %%
case.setAMRWindInput('ABL.stats_output_frequency',   1)           # Output ABL stats every iteration            
case.setAMRWindInput('ABL.stats_output_format',   'netcdf')       # Use netcdf output because that's how we postprocess

#case.setAMRWindInput('incflo.velocity',     [8.69, 0.0, 0.0])    # Already taken care of
case.setAMRWindInput('ABLForcing.abl_forcing_height',   91)       # Hub height wind speed you want specify 
case.setAMRWindInput('ABL.kappa',                       0.4)      # Kolmogorov constant

case.setAMRWindInput('ABL.normal_direction',      2)              # vertical is in z
case.setAMRWindInput('ABL.surface_roughness_z0',  0.1)            # Surface roughess, SOMETHING WE WILL PROBABLY WANT TO ITERATE ON
case.setAMRWindInput('ABL.reference_temperature', 303.803)        # Correspond to what was measured at ARM
case.setAMRWindInput('ABL.surface_temp_rate',     -0.07)          # d(Temperature)/dt ---> set this to zero for unstable ABL
case.setAMRWindInput('ABL.surface_temp_flux',     None)           # Surface temperature flux (K*m/s) --> Use this for unstable ABL's (ITERATE ON THIS TOO)

# Monin-Obukhov parameters (No need to change)
case.setAMRWindInput('ABL.mo_beta_m',             16.0)
case.setAMRWindInput('ABL.mo_gamma_m',            5.0)
case.setAMRWindInput('ABL.mo_gamma_h',            5.0)
case.setAMRWindInput('ABL.random_gauss_mean',     0.0)
case.setAMRWindInput('ABL.random_gauss_var',      1.0)

# %%
case.setAMRWindInput('CoriolisForcing.latitude',  36.57236455833334 )        # Sets up the latitude of the site
case.setAMRWindInput('BoussinesqBuoyancy.reference_temperature', 303.803)    # The reference temperature

# These inputs set up the initial temperature profile (Same as Nalu-Wind temperature profile)
case.setAMRWindInput('ABL.temperature_heights', '0       500.0  600.0    960.0')
case.setAMRWindInput('ABL.temperature_values',  '305.803 305.803 313.803 314.253')

# %%
# This is a case where we don't want to use the defaults in amrwind-frontend
case.setAMRWindInput('ABL.perturb_ref_height', 50.0)
case.setAMRWindInput('ABL.Uperiods', 4.0)
case.setAMRWindInput('ABL.Vperiods', 4.0)
case.setAMRWindInput('ABL.deltaU',   1.0)
case.setAMRWindInput('ABL.deltaV',   1.0)
case.setAMRWindInput('ABL.theta_amplitude',   None)
case.setAMRWindInput('ABL.cutoff_height',   None)
case.setAMRWindInput('ABL.perturb_velocity', True)
case.setAMRWindInput('ABL.perturb_temperature', False)

# %%
case.extradictparams['amr.blocking_factor'] = 16 
case.extradictparams['amr.max_grid_size']   = 64

# %%
# Check that all inputs are okay
check=case.validate()
# Out:
# -- Checking inputs --
# [ PASS] max_level:           max_level = 2 >= 0
# [ PASS] dt & CFL:            DT and CFL OK
# [ FAIL] restart dir:         Restart directory  does not exist
# [ SKIP] boundary plane dir:  ABL.bndry_io_mode is not 1
# [ PASS] Actuator physics:    incflo.physics and ICNS.source_terms OK for Actuators
# [ SKIP] Actuator FST:        No Actuators
# [ SKIP] Sampling probes:     Not active or no sampling planes
#
# Results:
#  3 PASS
#  3 SKIP
#  1 FAIL
#  0 WARN

# %%
# Write the input file
precursorinputfile = 'MMC_domain1.inp'
print(case.writeAMRWindInput(precursorinputfile))
# Out:
# # --- Simulation time control parameters ---
# time.stop_time                           = 30000.0             # Max (simulated) time to evolve [s]
# time.max_step                            = -1
# time.fixed_dt                            = 0.125               # Fixed timestep size (in seconds). If negative, then time.cfl is used
# time.checkpoint_interval                 = 8000
# incflo.physics                           = ABL                 # List of physics models to include in simulation.
# incflo.verbose                           = 3
# io.check_file                            = chk
# incflo.use_godunov                       = true
# incflo.godunov_type                      = weno_z
# turbulence.model                         = OneEqKsgsM84
# TKE.source_terms                         = KsgsM84Src
# nodal_proj.mg_rtol                       = 1e-06
# nodal_proj.mg_atol                       = 1e-12
# mac_proj.mg_rtol                         = 1e-06
# mac_proj.mg_atol                         = 1e-12
# diffusion.mg_rtol                        = 1e-06
# diffusion.mg_atol                        = 1e-12
# temperature_diffusion.mg_rtol            = 1e-10
# temperature_diffusion.mg_atol            = 1e-13
# incflo.gravity                           = 0.0 0.0 -9.81       # Gravitational acceleration vector (x,y,z) [m/s^2]
# incflo.density                           = 1.17                # Fluid density [kg/m^3]
# transport.viscosity                      = 1.853e-05           # Fluid dynamic viscosity [kg/m-s]
# transport.laminar_prandtl                = 0.7                 # Laminar prandtl number
# transport.turbulent_prandtl              = 0.3333              # Turbulent prandtl number
#
# # --- Geometry and Mesh ---
# geometry.prob_lo                         = 619640.0 4008140.0 0.0
# geometry.prob_hi                         = 650360.0 4038860.0 1920.0
# amr.n_cell                               = 3072 3072 192       # Number of cells in x, y, and z directions
# amr.max_level                            = 2
# geometry.is_periodic                     = 1 1 0
# zlo.type                                 = wall_model
# zlo.temperature_type                     = wall_model
# zlo.tke_type                             = zero_gradient
# zhi.type                                 = slip_wall
# zhi.temperature_type                     = fixed_gradient
# zhi.temperature                          = 0.00125
#
# # --- ABL parameters ---
# ICNS.source_terms                        = ABLForcing BoussinesqBuoyancy CoriolisForcing ABLMeanBoussinesq
# ABL.stats_output_frequency               = 1
# ABL.stats_output_format                  = netcdf
# incflo.velocity                          = 6.153850165715451e-16 10.05 0.0
# ABLForcing.abl_forcing_height            = 91.0
# ABL.kappa                                = 0.4
# ABL.normal_direction                     = 2
# ABL.surface_roughness_z0                 = 0.1
# ABL.reference_temperature                = 303.803
# ABL.surface_temp_rate                    = -0.07
# ABL.mo_beta_m                            = 16.0                # Monin-Obukhov Beta m parameter
# ABL.mo_gamma_m                           = 5.0                 # Monin-Obukhov Gamma m parameter
# ABL.mo_gamma_h                           = 5.0                 # Monin-Obukhov Gamma h parameter
# ABL.random_gauss_mean                    = 0.0
# ABL.random_gauss_var                     = 1.0
# CoriolisForcing.latitude                 = 36.57236455833334
# CoriolisForcing.rotational_time_period   = 86164.0900027328
# CoriolisForcing.north_vector             = 0.0 1.0 0.0
# CoriolisForcing.east_vector              = 1.0 0.0 0.0
# BoussinesqBuoyancy.reference_temperature = 303.803
# ABL.temperature_heights                  = 0       500.0  600.0    960.0
# ABL.temperature_values                   = 305.803 305.803 313.803 314.253
# ABL.perturb_velocity                     = true
# ABL.perturb_ref_height                   = 50.0
# ABL.Uperiods                             = 4.0
# ABL.Vperiods                             = 4.0
# ABL.deltaU                               = 1.0
# ABL.deltaV                               = 1.0
# ABL.perturb_temperature                  = false
# time.plot_interval                       = 8000
# io.plot_file                             = plt
# io.KE_int                                = -1
#
# #---- tagging defs ----
# tagging.labels                           = Farm_level_0_center_639000_4029000_100 Farm_level_0_center_628000_4017500_100 2019-WTW-4713-KP_level_1_zone 2019-WTW-4655-KP_level_1_zone 2019-WTW-4651-KP_level_1_zone 2019-WTW-4726-KP_level_1_zone 2019-WTW-4671-KP_level_1_zone 2019-WTW-4715-KP_level_1_zone 2019-WTW-4691-KP_level_1_zone 2019-WTW-7913-KP_level_1_zone 2019-WTW-4657-KP_level_1_zone 2019-WTW-4694-KP_level_1_zone 2019-WTW-4718-KP_level_1_zone 2019-WTW-4690-KP_level_1_zone 2019-WTW-4656-KP_level_1_zone 2019-WTW-4697-KP_level_1_zone 2019-WTW-4698-KP_level_1_zone 2019-WTW-4701-KP_level_1_zone 2019-WTW-4723-KP_level_1_zone 2019-WTW-4673-KP_level_1_zone 2019-WTW-4716-KP_level_1_zone 2019-WTW-4693-KP_level_1_zone 2019-WTW-4725-KP_level_1_zone 2019-WTW-7915-KP_level_1_zone 2019-WTW-4674-KP_level_1_zone 2019-WTW-4689-KP_level_1_zone 2019-WTW-7921-KP_level_1_zone 2019-WTW-4710-KP_level_1_zone 2019-WTW-4648-KP_level_1_zone 2019-WTW-4721-KP_level_1_zone 2019-WTW-4652-KP_level_1_zone 2019-WTW-4658-KP_level_1_zone 2019-WTW-4692-KP_level_1_zone 2019-WTW-4695-KP_level_1_zone 2019-WTW-7914-KP_level_1_zone 2019-WTW-4675-KP_level_1_zone 2019-WTW-4702-KP_level_1_zone 2019-WTW-4704-KP_level_1_zone 2019-WTW-4712-KP_level_1_zone 2019-WTW-7916-KP_level_1_zone 2019-WTW-4711-KP_level_1_zone 2019-WTW-7912-KP_level_1_zone 2019-WTW-4654-KP_level_1_zone 2019-WTW-4650-KP_level_1_zone 2019-WTW-4653-KP_level_1_zone 2019-WTW-4722-KP_level_1_zone 2019-WTW-4717-KP_level_1_zone 2019-WTW-4703-KP_level_1_zone 2019-WTW-4709-KP_level_1_zone 2019-WTW-4672-KP_level_1_zone 2019-WTW-4696-KP_level_1_zone 2019-WTW-4724-KP_level_1_zone 2019-WTW-7910-KP_level_1_zone 2019-WTW-4683-KP_level_1_zone 2019-WTW-4737-KP_level_1_zone 2019-WTW-4732-KP_level_1_zone 2019-WTW-4668-KP_level_1_zone 2019-WTW-4643-KP_level_1_zone 2019-WTW-4663-KP_level_1_zone 2019-WTW-7919-KP_level_1_zone 2019-WTW-4730-KP_level_1_zone 2019-WTW-7918-KP_level_1_zone 2019-WTW-4736-KP_level_1_zone 2019-WTW-4731-KP_level_1_zone 2019-WTW-4677-KP_level_1_zone 2019-WTW-4670-KP_level_1_zone 2019-WTW-4642-KP_level_1_zone 2019-WTW-4662-KP_level_1_zone 2019-WTW-7920-KP_level_1_zone 2019-WTW-4678-KP_level_1_zone 2019-WTW-7911-KP_level_1_zone 2019-WTW-4664-KP_level_1_zone 2019-WTW-4679-KP_level_1_zone 2019-WTW-4669-KP_level_1_zone 2019-WTW-4687-KP_level_1_zone 2019-WTW-4680-KP_level_1_zone 2019-WTW-4666-KP_level_1_zone 2019-WTW-4644-KP_level_1_zone 2019-WTW-4682-KP_level_1_zone 2019-WTW-7917-KP_level_1_zone 2019-WTW-4676-KP_level_1_zone 2019-WTW-4667-KP_level_1_zone 2019-WTW-4681-KP_level_1_zone 2019-WTW-4740-KP_level_1_zone 2019-WTW-4686-KP_level_1_zone 2019-WTW-4741-KP_level_1_zone 2019-WTW-4665-KP_level_1_zone 2019-WTW-4641-KP_level_1_zone 2019-WTW-4661-KP_level_1_zone 2019-WTW-4729-KP_level_1_zone WAF1-0001-AF_level_1_zone WAF1-0002-AF_level_1_zone WAF1-0003-AF_level_1_zone WAF1-0004-AF_level_1_zone WAF1-0005-AF_level_1_zone WAF1-0006-AF_level_1_zone WAF1-0007-AF_level_1_zone WAF1-0008-AF_level_1_zone WAF1-0009-AF_level_1_zone WAF1-0010-AF_level_1_zone WAF1-0011-AF_level_1_zone WAF1-0012-AF_level_1_zone WAF1-0013-AF_level_1_zone WAF1-0014-AF_level_1_zone WAF1-0015-AF_level_1_zone WAF1-0016-AF_level_1_zone WAF1-0017-AF_level_1_zone WAF1-0018-AF_level_1_zone WAF1-0019-AF_level_1_zone WAF1-0020-AF_level_1_zone WAF1-0021-AF_level_1_zone WAF1-0022-AF_level_1_zone WAF1-0023-AF_level_1_zone WAF1-0024-AF_level_1_zone WAF1-0025-AF_level_1_zone WAF1-0026-AF_level_1_zone WAF1-0027-AF_level_1_zone WAF1-0028-AF_level_1_zone WAF1-0029-AF_level_1_zone WAF1-0030-AF_level_1_zone WAF1-0031-AF_level_1_zone WAF1-0032-AF_level_1_zone WAF1-0033-AF_level_1_zone WAF1-0034-AF_level_1_zone WAF1-0035-AF_level_1_zone WAF1-0036-AF_level_1_zone WAF1-0037-AF_level_1_zone WAF1-0038-AF_level_1_zone WAF1-0039-AF_level_1_zone WAF1-0040-AF_level_1_zone WAF1-0041-AF_level_1_zone WAF1-0042-AF_level_1_zone WAF1-0043-AF_level_1_zone WAF1-0044-AF_level_1_zone WAF1-0045-AF_level_1_zone WAF1-0046-AF_level_1_zone WAF1-0047-AF_level_1_zone WAF1-0048-AF_leve ...
# tagging.Farm_level_0_center_639000_4029000_100.type = GeometryRefinement
# tagging.Farm_level_0_center_639000_4029000_100.shapes = Farm_level_0_center_639000_4029000_100
# tagging.Farm_level_0_center_639000_4029000_100.level = 0
# tagging.Farm_level_0_center_639000_4029000_100.Farm_level_0_center_639000_4029000_100.type = box
# tagging.Farm_level_0_center_639000_4029000_100.Farm_level_0_center_639000_4029000_100.origin = 648300.0 4023000.0 0.0
# tagging.Farm_level_0_center_639000_4029000_100.Farm_level_0_center_639000_4029000_100.xaxis = 7.347880794884119e-13 12000.0 0.0
# tagging.Farm_level_0_center_639000_4029000_100.Farm_level_0_center_639000_4029000_100.yaxis = -18600.0 1.1389215232070384e-12 -0.0
# tagging.Farm_level_0_center_639000_4029000_100.Farm_level_0_center_639000_4029000_100.zaxis = 0.0 0.0 450.0
# tagging.Farm_level_0_center_628000_4017500_100.type = GeometryRefinement
# tagging.Farm_level_0_center_628000_4017500_100.shapes = Farm_level_0_center_628000_4017500_100
# tagging.Farm_level_0_center_628000_4017500_100.level = 0
# tagging.Farm_level_0_center_628000_4017500_100.Farm_level_0_center_628000_4017500_100.type = box
# tagging.Farm_level_0_center_628000_4017500_100.Farm_level_0_center_628000_4017500_100.origin = 636000.0 4009500.0 0.0
# tagging.Farm_level_0_center_628000_4017500_100.Farm_level_0_center_628000_4017500_100.xaxis = 9.797174393178826e-13 16000.0 0.0
# tagging.Farm_level_0_center_628000_4017500_100.Farm_level_0_center_628000_4017500_100.yaxis = -16000.0 9.797174393178826e-13 -0.0
# tagging.Farm_level_0_center_628000_4017500_100.Farm_level_0_center_628000_4017500_100.zaxis = 0.0 0.0 450.0
# tagging.2019-WTW-4713-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4713-KP_level_1_zone.shapes = 2019-WTW-4713-KP_level_1_zone
# tagging.2019-WTW-4713-KP_level_1_zone.level = 1
# tagging.2019-WTW-4713-KP_level_1_zone.2019-WTW-4713-KP_level_1_zone.type = box
# tagging.2019-WTW-4713-KP_level_1_zone.2019-WTW-4713-KP_level_1_zone.origin = 644676.801753 4027032.0859629996 23.325000000000003
# tagging.2019-WTW-4713-KP_level_1_zone.2019-WTW-4713-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4713-KP_level_1_zone.2019-WTW-4713-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4713-KP_level_1_zone.2019-WTW-4713-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4655-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4655-KP_level_1_zone.shapes = 2019-WTW-4655-KP_level_1_zone
# tagging.2019-WTW-4655-KP_level_1_zone.level = 1
# tagging.2019-WTW-4655-KP_level_1_zone.2019-WTW-4655-KP_level_1_zone.type = box
# tagging.2019-WTW-4655-KP_level_1_zone.2019-WTW-4655-KP_level_1_zone.origin = 642173.3223679999 4030618.310509 23.325000000000003
# tagging.2019-WTW-4655-KP_level_1_zone.2019-WTW-4655-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4655-KP_level_1_zone.2019-WTW-4655-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4655-KP_level_1_zone.2019-WTW-4655-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4651-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4651-KP_level_1_zone.shapes = 2019-WTW-4651-KP_level_1_zone
# tagging.2019-WTW-4651-KP_level_1_zone.level = 1
# tagging.2019-WTW-4651-KP_level_1_zone.2019-WTW-4651-KP_level_1_zone.type = box
# tagging.2019-WTW-4651-KP_level_1_zone.2019-WTW-4651-KP_level_1_zone.origin = 640600.2094739999 4030569.3164439998 23.325000000000003
# tagging.2019-WTW-4651-KP_level_1_zone.2019-WTW-4651-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4651-KP_level_1_zone.2019-WTW-4651-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4651-KP_level_1_zone.2019-WTW-4651-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4726-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4726-KP_level_1_zone.shapes = 2019-WTW-4726-KP_level_1_zone
# tagging.2019-WTW-4726-KP_level_1_zone.level = 1
# tagging.2019-WTW-4726-KP_level_1_zone.2019-WTW-4726-KP_level_1_zone.type = box
# tagging.2019-WTW-4726-KP_level_1_zone.2019-WTW-4726-KP_level_1_zone.origin = 647121.8196299999 4026249.0911689997 23.325000000000003
# tagging.2019-WTW-4726-KP_level_1_zone.2019-WTW-4726-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4726-KP_level_1_zone.2019-WTW-4726-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4726-KP_level_1_zone.2019-WTW-4726-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4671-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4671-KP_level_1_zone.shapes = 2019-WTW-4671-KP_level_1_zone
# tagging.2019-WTW-4671-KP_level_1_zone.level = 1
# tagging.2019-WTW-4671-KP_level_1_zone.2019-WTW-4671-KP_level_1_zone.type = box
# tagging.2019-WTW-4671-KP_level_1_zone.2019-WTW-4671-KP_level_1_zone.origin = 643793.700753 4029792.523641 23.325000000000003
# tagging.2019-WTW-4671-KP_level_1_zone.2019-WTW-4671-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4671-KP_level_1_zone.2019-WTW-4671-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4671-KP_level_1_zone.2019-WTW-4671-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4715-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4715-KP_level_1_zone.shapes = 2019-WTW-4715-KP_level_1_zone
# tagging.2019-WTW-4715-KP_level_1_zone.level = 1
# tagging.2019-WTW-4715-KP_level_1_zone.2019-WTW-4715-KP_level_1_zone.type = box
# tagging.2019-WTW-4715-KP_level_1_zone.2019-WTW-4715-KP_level_1_zone.origin = 641480.7158349999 4025508.836081 23.325000000000003
# tagging.2019-WTW-4715-KP_level_1_zone.2019-WTW-4715-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4715-KP_level_1_zone.2019-WTW-4715-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4715-KP_level_1_zone.2019-WTW-4715-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4691-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4691-KP_level_1_zone.shapes = 2019-WTW-4691-KP_level_1_zone
# tagging.2019-WTW-4691-KP_level_1_zone.level = 1
# tagging.2019-WTW-4691-KP_level_1_zone.2019-WTW-4691-KP_level_1_zone.type = box
# tagging.2019-WTW-4691-KP_level_1_zone.2019-WTW-4691-KP_level_1_zone.origin = 640601.739569 4027734.109735 23.325000000000003
# tagging.2019-WTW-4691-KP_level_1_zone.2019-WTW-4691-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4691-KP_level_1_zone.2019-WTW-4691-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4691-KP_level_1_zone.2019-WTW-4691-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-7913-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-7913-KP_level_1_zone.shapes = 2019-WTW-7913-KP_level_1_zone
# tagging.2019-WTW-7913-KP_level_1_zone.level = 1
# tagging.2019-WTW-7913-KP_level_1_zone.2019-WTW-7913-KP_level_1_zone.type = box
# tagging.2019-WTW-7913-KP_level_1_zone.2019-WTW-7913-KP_level_1_zone.origin = 639014.994021 4027311.4856189997 23.325000000000003
# tagging.2019-WTW-7913-KP_level_1_zone.2019-WTW-7913-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-7913-KP_level_1_zone.2019-WTW-7913-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-7913-KP_level_1_zone.2019-WTW-7913-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4657-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4657-KP_level_1_zone.shapes = 2019-WTW-4657-KP_level_1_zone
# tagging.2019-WTW-4657-KP_level_1_zone.level = 1
# tagging.2019-WTW-4657-KP_level_1_zone.2019-WTW-4657-KP_level_1_zone.type = box
# tagging.2019-WTW-4657-KP_level_1_zone.2019-WTW-4657-KP_level_1_zone.origin = 643003.653405 4030642.528327 23.325000000000003
# tagging.2019-WTW-4657-KP_level_1_zone.2019-WTW-4657-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4657-KP_level_1_zone.2019-WTW-4657-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4657-KP_level_1_zone.2019-WTW-4657-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4694-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4694-KP_level_1_zone.shapes = 2019-WTW-4694-KP_level_1_zone
# tagging.2019-WTW-4694-KP_level_1_zone.level = 1
# tagging.2019-WTW-4694-KP_level_1_zone.2019-WTW-4694-KP_level_1_zone.type = box
# tagging.2019-WTW-4694-KP_level_1_zone.2019-WTW-4694-KP_level_1_zone.origin = 641735.4286359999 4028564.059465 23.325000000000003
# tagging.2019-WTW-4694-KP_level_1_zone.2019-WTW-4694-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4694-KP_level_1_zone.2019-WTW-4694-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4694-KP_level_1_zone.2019-WTW-4694-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4718-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4718-KP_level_1_zone.shapes = 2019-WTW-4718-KP_level_1_zone
# tagging.2019-WTW-4718-KP_level_1_zone.level = 1
# tagging.2019-WTW-4718-KP_level_1_zone.2019-WTW-4718-KP_level_1_zone.type = box
# tagging.2019-WTW-4718-KP_level_1_zone.2019-WTW-4718-KP_level_1_zone.origin = 642697.597465 4025583.369623 23.325000000000003
# tagging.2019-WTW-4718-KP_level_1_zone.2019-WTW-4718-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4718-KP_level_1_zone.2019-WTW-4718-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4718-KP_level_1_zone.2019-WTW-4718-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4690-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4690-KP_level_1_zone.shapes = 2019-WTW-4690-KP_level_1_zone
# tagging.2019-WTW-4690-KP_level_1_zone.level = 1
# tagging.2019-WTW-4690-KP_level_1_zone.2019-WTW-4690-KP_level_1_zone.type = box
# tagging.2019-WTW-4690-KP_level_1_zone.2019-WTW-4690-KP_level_1_zone.origin = 640252.144241 4027298.795134 23.325000000000003
# tagging.2019-WTW-4690-KP_level_1_zone.2019-WTW-4690-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4690-KP_level_1_zone.2019-WTW-4690-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4690-KP_level_1_zone.2019-WTW-4690-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4656-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4656-KP_level_1_zone.shapes = 2019-WTW-4656-KP_level_1_zone
# tagging.2019-WTW-4656-KP_level_1_zone.level = 1
# tagging.2019-WTW-4656-KP_level_1_zone.2019-WTW-4656-KP_level_1_zone.type = box
# tagging.2019-WTW-4656-KP_level_1_zone.2019-WTW-4656-KP_level_1_zone.origin = 642557.11706 4030536.515718 23.325000000000003
# tagging.2019-WTW-4656-KP_level_1_zone.2019-WTW-4656-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4656-KP_level_1_zone.2019-WTW-4656-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4656-KP_level_1_zone.2019-WTW-4656-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4697-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4697-KP_level_1_zone.shapes = 2019-WTW-4697-KP_level_1_zone
# tagging.2019-WTW-4697-KP_level_1_zone.level = 1
# tagging.2019-WTW-4697-KP_level_1_zone.2019-WTW-4697-KP_level_1_zone.type = box
# tagging.2019-WTW-4697-KP_level_1_zone.2019-WTW-4697-KP_level_1_zone.origin = 643016.856099 4028637.1623629997 23.325000000000003
# tagging.2019-WTW-4697-KP_level_1_zone.2019-WTW-4697-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4697-KP_level_1_zone.2019-WTW-4697-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4697-KP_level_1_zone.2019-WTW-4697-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4698-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4698-KP_level_1_zone.shapes = 2019-WTW-4698-KP_level_1_zone
# tagging.2019-WTW-4698-KP_level_1_zone.level = 1
# tagging.2019-WTW-4698-KP_level_1_zone.2019-WTW-4698-KP_level_1_zone.type = box
# tagging.2019-WTW-4698-KP_level_1_zone.2019-WTW-4698-KP_level_1_zone.origin = 643424.953181 4028670.2081669997 23.325000000000003
# tagging.2019-WTW-4698-KP_level_1_zone.2019-WTW-4698-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4698-KP_level_1_zone.2019-WTW-4698-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4698-KP_level_1_zone.2019-WTW-4698-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4701-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4701-KP_level_1_zone.shapes = 2019-WTW-4701-KP_level_1_zone
# tagging.2019-WTW-4701-KP_level_1_zone.level = 1
# tagging.2019-WTW-4701-KP_level_1_zone.2019-WTW-4701-KP_level_1_zone.type = box
# tagging.2019-WTW-4701-KP_level_1_zone.2019-WTW-4701-KP_level_1_zone.origin = 644999.6459039999 4027992.4540689997 23.325000000000003
# tagging.2019-WTW-4701-KP_level_1_zone.2019-WTW-4701-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4701-KP_level_1_zone.2019-WTW-4701-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4701-KP_level_1_zone.2019-WTW-4701-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4723-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4723-KP_level_1_zone.shapes = 2019-WTW-4723-KP_level_1_zone
# tagging.2019-WTW-4723-KP_level_1_zone.level = 1
# tagging.2019-WTW-4723-KP_level_1_zone.2019-WTW-4723-KP_level_1_zone.type = box
# tagging.2019-WTW-4723-KP_level_1_zone.2019-WTW-4723-KP_level_1_zone.origin = 644891.199895 4025430.1050839997 23.325000000000003
# tagging.2019-WTW-4723-KP_level_1_zone.2019-WTW-4723-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4723-KP_level_1_zone.2019-WTW-4723-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4723-KP_level_1_zone.2019-WTW-4723-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4673-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4673-KP_level_1_zone.shapes = 2019-WTW-4673-KP_level_1_zone
# tagging.2019-WTW-4673-KP_level_1_zone.level = 1
# tagging.2019-WTW-4673-KP_level_1_zone.2019-WTW-4673-KP_level_1_zone.type = box
# tagging.2019-WTW-4673-KP_level_1_zone.2019-WTW-4673-KP_level_1_zone.origin = 638489.464818 4028581.023273 23.325000000000003
# tagging.2019-WTW-4673-KP_level_1_zone.2019-WTW-4673-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4673-KP_level_1_zone.2019-WTW-4673-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4673-KP_level_1_zone.2019-WTW-4673-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4716-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4716-KP_level_1_zone.shapes = 2019-WTW-4716-KP_level_1_zone
# tagging.2019-WTW-4716-KP_level_1_zone.level = 1
# tagging.2019-WTW-4716-KP_level_1_zone.2019-WTW-4716-KP_level_1_zone.type = box
# tagging.2019-WTW-4716-KP_level_1_zone.2019-WTW-4716-KP_level_1_zone.origin = 641890.950726 4025584.891204 23.325000000000003
# tagging.2019-WTW-4716-KP_level_1_zone.2019-WTW-4716-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4716-KP_level_1_zone.2019-WTW-4716-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4716-KP_level_1_zone.2019-WTW-4716-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4693-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4693-KP_level_1_zone.shapes = 2019-WTW-4693-KP_level_1_zone
# tagging.2019-WTW-4693-KP_level_1_zone.level = 1
# tagging.2019-WTW-4693-KP_level_1_zone.2019-WTW-4693-KP_level_1_zone.type = box
# tagging.2019-WTW-4693-KP_level_1_zone.2019-WTW-4693-KP_level_1_zone.origin = 641420.429254 4028070.4481349997 23.325000000000003
# tagging.2019-WTW-4693-KP_level_1_zone.2019-WTW-4693-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4693-KP_level_1_zone.2019-WTW-4693-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4693-KP_level_1_zone.2019-WTW-4693-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4725-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4725-KP_level_1_zone.shapes = 2019-WTW-4725-KP_level_1_zone
# tagging.2019-WTW-4725-KP_level_1_zone.level = 1
# tagging.2019-WTW-4725-KP_level_1_zone.2019-WTW-4725-KP_level_1_zone.type = box
# tagging.2019-WTW-4725-KP_level_1_zone.2019-WTW-4725-KP_level_1_zone.origin = 646708.2281259999 4026253.0681149997 23.325000000000003
# tagging.2019-WTW-4725-KP_level_1_zone.2019-WTW-4725-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4725-KP_level_1_zone.2019-WTW-4725-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4725-KP_level_1_zone.2019-WTW-4725-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-7915-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-7915-KP_level_1_zone.shapes = 2019-WTW-7915-KP_level_1_zone
# tagging.2019-WTW-7915-KP_level_1_zone.level = 1
# tagging.2019-WTW-7915-KP_level_1_zone.2019-WTW-7915-KP_level_1_zone.type = box
# tagging.2019-WTW-7915-KP_level_1_zone.2019-WTW-7915-KP_level_1_zone.origin = 643126.78826 4025505.3332439996 23.325000000000003
# tagging.2019-WTW-7915-KP_level_1_zone.2019-WTW-7915-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-7915-KP_level_1_zone.2019-WTW-7915-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-7915-KP_level_1_zone.2019-WTW-7915-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4674-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4674-KP_level_1_zone.shapes = 2019-WTW-4674-KP_level_1_zone
# tagging.2019-WTW-4674-KP_level_1_zone.level = 1
# tagging.2019-WTW-4674-KP_level_1_zone.2019-WTW-4674-KP_level_1_zone.type = box
# tagging.2019-WTW-4674-KP_level_1_zone.2019-WTW-4674-KP_level_1_zone.origin = 638890.39917 4028591.214756 23.325000000000003
# tagging.2019-WTW-4674-KP_level_1_zone.2019-WTW-4674-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4674-KP_level_1_zone.2019-WTW-4674-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4674-KP_level_1_zone.2019-WTW-4674-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4689-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4689-KP_level_1_zone.shapes = 2019-WTW-4689-KP_level_1_zone
# tagging.2019-WTW-4689-KP_level_1_zone.level = 1
# tagging.2019-WTW-4689-KP_level_1_zone.2019-WTW-4689-KP_level_1_zone.type = box
# tagging.2019-WTW-4689-KP_level_1_zone.2019-WTW-4689-KP_level_1_zone.origin = 639331.7638559999 4026895.8026389997 23.325000000000003
# tagging.2019-WTW-4689-KP_level_1_zone.2019-WTW-4689-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4689-KP_level_1_zone.2019-WTW-4689-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4689-KP_level_1_zone.2019-WTW-4689-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-7921-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-7921-KP_level_1_zone.shapes = 2019-WTW-7921-KP_level_1_zone
# tagging.2019-WTW-7921-KP_level_1_zone.level = 1
# tagging.2019-WTW-7921-KP_level_1_zone.2019-WTW-7921-KP_level_1_zone.type = box
# tagging.2019-WTW-7921-KP_level_1_zone.2019-WTW-7921-KP_level_1_zone.origin = 639390.663247 4030467.2006079997 23.325000000000003
# tagging.2019-WTW-7921-KP_level_1_zone.2019-WTW-7921-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-7921-KP_level_1_zone.2019-WTW-7921-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-7921-KP_level_1_zone.2019-WTW-7921-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4710-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4710-KP_level_1_zone.shapes = 2019-WTW-4710-KP_level_1_zone
# tagging.2019-WTW-4710-KP_level_1_zone.level = 1
# tagging.2019-WTW-4710-KP_level_1_zone.2019-WTW-4710-KP_level_1_zone.type = box
# tagging.2019-WTW-4710-KP_level_1_zone.2019-WTW-4710-KP_level_1_zone.origin = 643456.272473 4027401.618622 23.325000000000003
# tagging.2019-WTW-4710-KP_level_1_zone.2019-WTW-4710-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4710-KP_level_1_zone.2019-WTW-4710-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4710-KP_level_1_zone.2019-WTW-4710-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4648-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4648-KP_level_1_zone.shapes = 2019-WTW-4648-KP_level_1_zone
# tagging.2019-WTW-4648-KP_level_1_zone.level = 1
# tagging.2019-WTW-4648-KP_level_1_zone.2019-WTW-4648-KP_level_1_zone.type = box
# tagging.2019-WTW-4648-KP_level_1_zone.2019-WTW-4648-KP_level_1_zone.origin = 638989.68724 4030805.7378249997 23.325000000000003
# tagging.2019-WTW-4648-KP_level_1_zone.2019-WTW-4648-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4648-KP_level_1_zone.2019-WTW-4648-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4648-KP_level_1_zone.2019-WTW-4648-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4721-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4721-KP_level_1_zone.shapes = 2019-WTW-4721-KP_level_1_zone
# tagging.2019-WTW-4721-KP_level_1_zone.level = 1
# tagging.2019-WTW-4721-KP_level_1_zone.2019-WTW-4721-KP_level_1_zone.type = box
# tagging.2019-WTW-4721-KP_level_1_zone.2019-WTW-4721-KP_level_1_zone.origin = 643874.550971 4025624.344683 23.325000000000003
# tagging.2019-WTW-4721-KP_level_1_zone.2019-WTW-4721-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4721-KP_level_1_zone.2019-WTW-4721-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4721-KP_level_1_zone.2019-WTW-4721-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4652-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4652-KP_level_1_zone.shapes = 2019-WTW-4652-KP_level_1_zone
# tagging.2019-WTW-4652-KP_level_1_zone.level = 1
# tagging.2019-WTW-4652-KP_level_1_zone.2019-WTW-4652-KP_level_1_zone.type = box
# tagging.2019-WTW-4652-KP_level_1_zone.2019-WTW-4652-KP_level_1_zone.origin = 640986.506246 4030591.6885809996 23.325000000000003
# tagging.2019-WTW-4652-KP_level_1_zone.2019-WTW-4652-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4652-KP_level_1_zone.2019-WTW-4652-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4652-KP_level_1_zone.2019-WTW-4652-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4658-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4658-KP_level_1_zone.shapes = 2019-WTW-4658-KP_level_1_zone
# tagging.2019-WTW-4658-KP_level_1_zone.level = 1
# tagging.2019-WTW-4658-KP_level_1_zone.2019-WTW-4658-KP_level_1_zone.type = box
# tagging.2019-WTW-4658-KP_level_1_zone.2019-WTW-4658-KP_level_1_zone.origin = 643427.0932369999 4030647.8688999997 23.325000000000003
# tagging.2019-WTW-4658-KP_level_1_zone.2019-WTW-4658-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4658-KP_level_1_zone.2019-WTW-4658-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4658-KP_level_1_zone.2019-WTW-4658-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4692-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4692-KP_level_1_zone.shapes = 2019-WTW-4692-KP_level_1_zone
# tagging.2019-WTW-4692-KP_level_1_zone.level = 1
# tagging.2019-WTW-4692-KP_level_1_zone.2019-WTW-4692-KP_level_1_zone.type = box
# tagging.2019-WTW-4692-KP_level_1_zone.2019-WTW-4692-KP_level_1_zone.origin = 641010.1816319999 4028040.9032779997 23.325000000000003
# tagging.2019-WTW-4692-KP_level_1_zone.2019-WTW-4692-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4692-KP_level_1_zone.2019-WTW-4692-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4692-KP_level_1_zone.2019-WTW-4692-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4695-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4695-KP_level_1_zone.shapes = 2019-WTW-4695-KP_level_1_zone
# tagging.2019-WTW-4695-KP_level_1_zone.level = 1
# tagging.2019-WTW-4695-KP_level_1_zone.2019-WTW-4695-KP_level_1_zone.type = box
# tagging.2019-WTW-4695-KP_level_1_zone.2019-WTW-4695-KP_level_1_zone.origin = 642152.7183579999 4028622.162385 23.325000000000003
# tagging.2019-WTW-4695-KP_level_1_zone.2019-WTW-4695-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4695-KP_level_1_zone.2019-WTW-4695-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4695-KP_level_1_zone.2019-WTW-4695-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-7914-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-7914-KP_level_1_zone.shapes = 2019-WTW-7914-KP_level_1_zone
# tagging.2019-WTW-7914-KP_level_1_zone.level = 1
# tagging.2019-WTW-7914-KP_level_1_zone.2019-WTW-7914-KP_level_1_zone.type = box
# tagging.2019-WTW-7914-KP_level_1_zone.2019-WTW-7914-KP_level_1_zone.origin = 642534.1219039999 4027360.2154159998 23.325000000000003
# tagging.2019-WTW-7914-KP_level_1_zone.2019-WTW-7914-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-7914-KP_level_1_zone.2019-WTW-7914-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-7914-KP_level_1_zone.2019-WTW-7914-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4675-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4675-KP_level_1_zone.shapes = 2019-WTW-4675-KP_level_1_zone
# tagging.2019-WTW-4675-KP_level_1_zone.level = 1
# tagging.2019-WTW-4675-KP_level_1_zone.2019-WTW-4675-KP_level_1_zone.type = box
# tagging.2019-WTW-4675-KP_level_1_zone.2019-WTW-4675-KP_level_1_zone.origin = 639376.5976359999 4028532.112909 23.325000000000003
# tagging.2019-WTW-4675-KP_level_1_zone.2019-WTW-4675-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4675-KP_level_1_zone.2019-WTW-4675-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4675-KP_level_1_zone.2019-WTW-4675-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4702-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4702-KP_level_1_zone.shapes = 2019-WTW-4702-KP_level_1_zone
# tagging.2019-WTW-4702-KP_level_1_zone.level = 1
# tagging.2019-WTW-4702-KP_level_1_zone.2019-WTW-4702-KP_level_1_zone.type = box
# tagging.2019-WTW-4702-KP_level_1_zone.2019-WTW-4702-KP_level_1_zone.origin = 645434.325553 4027988.3097079997 23.325000000000003
# tagging.2019-WTW-4702-KP_level_1_zone.2019-WTW-4702-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4702-KP_level_1_zone.2019-WTW-4702-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4702-KP_level_1_zone.2019-WTW-4702-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4704-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4704-KP_level_1_zone.shapes = 2019-WTW-4704-KP_level_1_zone
# tagging.2019-WTW-4704-KP_level_1_zone.level = 1
# tagging.2019-WTW-4704-KP_level_1_zone.2019-WTW-4704-KP_level_1_zone.type = box
# tagging.2019-WTW-4704-KP_level_1_zone.2019-WTW-4704-KP_level_1_zone.origin = 647050.6615589999 4027777.232924 23.325000000000003
# tagging.2019-WTW-4704-KP_level_1_zone.2019-WTW-4704-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4704-KP_level_1_zone.2019-WTW-4704-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4704-KP_level_1_zone.2019-WTW-4704-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4712-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4712-KP_level_1_zone.shapes = 2019-WTW-4712-KP_level_1_zone
# tagging.2019-WTW-4712-KP_level_1_zone.level = 1
# tagging.2019-WTW-4712-KP_level_1_zone.2019-WTW-4712-KP_level_1_zone.type = box
# tagging.2019-WTW-4712-KP_level_1_zone.2019-WTW-4712-KP_level_1_zone.origin = 644265.033666 4027382.0873709996 23.325000000000003
# tagging.2019-WTW-4712-KP_level_1_zone.2019-WTW-4712-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4712-KP_level_1_zone.2019-WTW-4712-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4712-KP_level_1_zone.2019-WTW-4712-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-7916-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-7916-KP_level_1_zone.shapes = 2019-WTW-7916-KP_level_1_zone
# tagging.2019-WTW-7916-KP_level_1_zone.level = 1
# tagging.2019-WTW-7916-KP_level_1_zone.2019-WTW-7916-KP_level_1_zone.type = box
# tagging.2019-WTW-7916-KP_level_1_zone.2019-WTW-7916-KP_level_1_zone.origin = 643473.366173 4025663.858856 23.325000000000003
# tagging.2019-WTW-7916-KP_level_1_zone.2019-WTW-7916-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-7916-KP_level_1_zone.2019-WTW-7916-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-7916-KP_level_1_zone.2019-WTW-7916-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4711-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4711-KP_level_1_zone.shapes = 2019-WTW-4711-KP_level_1_zone
# tagging.2019-WTW-4711-KP_level_1_zone.level = 1
# tagging.2019-WTW-4711-KP_level_1_zone.2019-WTW-4711-KP_level_1_zone.type = box
# tagging.2019-WTW-4711-KP_level_1_zone.2019-WTW-4711-KP_level_1_zone.origin = 643859.5908209999 4027434.1592019997 23.325000000000003
# tagging.2019-WTW-4711-KP_level_1_zone.2019-WTW-4711-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4711-KP_level_1_zone.2019-WTW-4711-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4711-KP_level_1_zone.2019-WTW-4711-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-7912-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-7912-KP_level_1_zone.shapes = 2019-WTW-7912-KP_level_1_zone
# tagging.2019-WTW-7912-KP_level_1_zone.level = 1
# tagging.2019-WTW-7912-KP_level_1_zone.2019-WTW-7912-KP_level_1_zone.type = box
# tagging.2019-WTW-7912-KP_level_1_zone.2019-WTW-7912-KP_level_1_zone.origin = 638606.7551869999 4030534.619023 23.325000000000003
# tagging.2019-WTW-7912-KP_level_1_zone.2019-WTW-7912-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-7912-KP_level_1_zone.2019-WTW-7912-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-7912-KP_level_1_zone.2019-WTW-7912-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4654-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4654-KP_level_1_zone.shapes = 2019-WTW-4654-KP_level_1_zone
# tagging.2019-WTW-4654-KP_level_1_zone.level = 1
# tagging.2019-WTW-4654-KP_level_1_zone.2019-WTW-4654-KP_level_1_zone.type = box
# tagging.2019-WTW-4654-KP_level_1_zone.2019-WTW-4654-KP_level_1_zone.origin = 641800.44211 4030527.0850199996 23.325000000000003
# tagging.2019-WTW-4654-KP_level_1_zone.2019-WTW-4654-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4654-KP_level_1_zone.2019-WTW-4654-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4654-KP_level_1_zone.2019-WTW-4654-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4650-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4650-KP_level_1_zone.shapes = 2019-WTW-4650-KP_level_1_zone
# tagging.2019-WTW-4650-KP_level_1_zone.level = 1
# tagging.2019-WTW-4650-KP_level_1_zone.2019-WTW-4650-KP_level_1_zone.type = box
# tagging.2019-WTW-4650-KP_level_1_zone.2019-WTW-4650-KP_level_1_zone.origin = 639870.9062549999 4030559.6111339997 23.325000000000003
# tagging.2019-WTW-4650-KP_level_1_zone.2019-WTW-4650-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4650-KP_level_1_zone.2019-WTW-4650-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4650-KP_level_1_zone.2019-WTW-4650-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4653-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4653-KP_level_1_zone.shapes = 2019-WTW-4653-KP_level_1_zone
# tagging.2019-WTW-4653-KP_level_1_zone.level = 1
# tagging.2019-WTW-4653-KP_level_1_zone.2019-WTW-4653-KP_level_1_zone.type = box
# tagging.2019-WTW-4653-KP_level_1_zone.2019-WTW-4653-KP_level_1_zone.origin = 641390.688418 4030562.3278489998 23.325000000000003
# tagging.2019-WTW-4653-KP_level_1_zone.2019-WTW-4653-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4653-KP_level_1_zone.2019-WTW-4653-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4653-KP_level_1_zone.2019-WTW-4653-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4722-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4722-KP_level_1_zone.shapes = 2019-WTW-4722-KP_level_1_zone
# tagging.2019-WTW-4722-KP_level_1_zone.level = 1
# tagging.2019-WTW-4722-KP_level_1_zone.2019-WTW-4722-KP_level_1_zone.type = box
# tagging.2019-WTW-4722-KP_level_1_zone.2019-WTW-4722-KP_level_1_zone.origin = 644303.1752739999 4025581.0887949998 23.325000000000003
# tagging.2019-WTW-4722-KP_level_1_zone.2019-WTW-4722-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4722-KP_level_1_zone.2019-WTW-4722-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4722-KP_level_1_zone.2019-WTW-4722-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4717-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4717-KP_level_1_zone.shapes = 2019-WTW-4717-KP_level_1_zone
# tagging.2019-WTW-4717-KP_level_1_zone.level = 1
# tagging.2019-WTW-4717-KP_level_1_zone.2019-WTW-4717-KP_level_1_zone.type = box
# tagging.2019-WTW-4717-KP_level_1_zone.2019-WTW-4717-KP_level_1_zone.origin = 642307.1128219999 4025594.706861 23.325000000000003
# tagging.2019-WTW-4717-KP_level_1_zone.2019-WTW-4717-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4717-KP_level_1_zone.2019-WTW-4717-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4717-KP_level_1_zone.2019-WTW-4717-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4703-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4703-KP_level_1_zone.shapes = 2019-WTW-4703-KP_level_1_zone
# tagging.2019-WTW-4703-KP_level_1_zone.level = 1
# tagging.2019-WTW-4703-KP_level_1_zone.2019-WTW-4703-KP_level_1_zone.type = box
# tagging.2019-WTW-4703-KP_level_1_zone.2019-WTW-4703-KP_level_1_zone.origin = 645870.107141 4027966.7839189996 23.325000000000003
# tagging.2019-WTW-4703-KP_level_1_zone.2019-WTW-4703-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4703-KP_level_1_zone.2019-WTW-4703-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4703-KP_level_1_zone.2019-WTW-4703-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4709-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4709-KP_level_1_zone.shapes = 2019-WTW-4709-KP_level_1_zone
# tagging.2019-WTW-4709-KP_level_1_zone.level = 1
# tagging.2019-WTW-4709-KP_level_1_zone.2019-WTW-4709-KP_level_1_zone.type = box
# tagging.2019-WTW-4709-KP_level_1_zone.2019-WTW-4709-KP_level_1_zone.origin = 643041.569043 4027352.042381 23.325000000000003
# tagging.2019-WTW-4709-KP_level_1_zone.2019-WTW-4709-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4709-KP_level_1_zone.2019-WTW-4709-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4709-KP_level_1_zone.2019-WTW-4709-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4672-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4672-KP_level_1_zone.shapes = 2019-WTW-4672-KP_level_1_zone
# tagging.2019-WTW-4672-KP_level_1_zone.level = 1
# tagging.2019-WTW-4672-KP_level_1_zone.2019-WTW-4672-KP_level_1_zone.type = box
# tagging.2019-WTW-4672-KP_level_1_zone.2019-WTW-4672-KP_level_1_zone.origin = 644231.002531 4029835.3053429998 23.325000000000003
# tagging.2019-WTW-4672-KP_level_1_zone.2019-WTW-4672-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4672-KP_level_1_zone.2019-WTW-4672-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4672-KP_level_1_zone.2019-WTW-4672-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4696-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4696-KP_level_1_zone.shapes = 2019-WTW-4696-KP_level_1_zone
# tagging.2019-WTW-4696-KP_level_1_zone.level = 1
# tagging.2019-WTW-4696-KP_level_1_zone.2019-WTW-4696-KP_level_1_zone.type = box
# tagging.2019-WTW-4696-KP_level_1_zone.2019-WTW-4696-KP_level_1_zone.origin = 642591.184532 4028636.137357 23.325000000000003
# tagging.2019-WTW-4696-KP_level_1_zone.2019-WTW-4696-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# tagging.2019-WTW-4696-KP_level_1_zone.2019-WTW-4696-KP_level_1_zone.yaxis = -152.4 9.331808609502832e-15 -0.0
# tagging.2019-WTW-4696-KP_level_1_zone.2019-WTW-4696-KP_level_1_zone.zaxis = 0.0 0.0 133.35
# tagging.2019-WTW-4724-KP_level_1_zone.type = GeometryRefinement
# tagging.2019-WTW-4724-KP_level_1_zone.shapes = 2019-WTW-4724-KP_level_1_zone
# tagging.2019-WTW-4724-KP_level_1_zone.level = 1
# tagging.2019-WTW-4724-KP_level_1_zone.2019-WTW-4724-KP_level_1_zone.type = box
# tagging.2019-WTW-4724-KP_level_1_zone.2019-WTW-4724-KP_level_1_zone.origin = 646323.546919 4026245.679238 23.325000000000003
# tagging.2019-WTW-4724-KP_level_1_zone.2019-WTW-4724-KP_level_1_zone.xaxis = 9.331808609502832e-15 152.4 0.0
# ...
# tagging.WAF1-0105-AF_level_1_zone.WAF1-0105-AF_level_1_zone.origin = 632516.56 4014486.1 25.924999999999997
# tagging.WAF1-0105-AF_level_1_zone.WAF1-0105-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0105-AF_level_1_zone.WAF1-0105-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0105-AF_level_1_zone.WAF1-0105-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0106-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0106-AF_level_1_zone.shapes = WAF1-0106-AF_level_1_zone
# tagging.WAF1-0106-AF_level_1_zone.level  = 1
# tagging.WAF1-0106-AF_level_1_zone.WAF1-0106-AF_level_1_zone.type = box
# tagging.WAF1-0106-AF_level_1_zone.WAF1-0106-AF_level_1_zone.origin = 632903.87 4013994.6300000004 25.924999999999997
# tagging.WAF1-0106-AF_level_1_zone.WAF1-0106-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0106-AF_level_1_zone.WAF1-0106-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0106-AF_level_1_zone.WAF1-0106-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0107-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0107-AF_level_1_zone.shapes = WAF1-0107-AF_level_1_zone
# tagging.WAF1-0107-AF_level_1_zone.level  = 1
# tagging.WAF1-0107-AF_level_1_zone.WAF1-0107-AF_level_1_zone.type = box
# tagging.WAF1-0107-AF_level_1_zone.WAF1-0107-AF_level_1_zone.origin = 633235.7300000001 4014415.02 25.924999999999997
# tagging.WAF1-0107-AF_level_1_zone.WAF1-0107-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0107-AF_level_1_zone.WAF1-0107-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0107-AF_level_1_zone.WAF1-0107-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0108-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0108-AF_level_1_zone.shapes = WAF1-0108-AF_level_1_zone
# tagging.WAF1-0108-AF_level_1_zone.level  = 1
# tagging.WAF1-0108-AF_level_1_zone.WAF1-0108-AF_level_1_zone.type = box
# tagging.WAF1-0108-AF_level_1_zone.WAF1-0108-AF_level_1_zone.origin = 633613.75 4014718.9400000004 25.924999999999997
# tagging.WAF1-0108-AF_level_1_zone.WAF1-0108-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0108-AF_level_1_zone.WAF1-0108-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0108-AF_level_1_zone.WAF1-0108-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0109-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0109-AF_level_1_zone.shapes = WAF1-0109-AF_level_1_zone
# tagging.WAF1-0109-AF_level_1_zone.level  = 1
# tagging.WAF1-0109-AF_level_1_zone.WAF1-0109-AF_level_1_zone.type = box
# tagging.WAF1-0109-AF_level_1_zone.WAF1-0109-AF_level_1_zone.origin = 633933.99 4014868.82 18.22999999999999
# tagging.WAF1-0109-AF_level_1_zone.WAF1-0109-AF_level_1_zone.xaxis = 8.523541722065578e-15 139.2 0.0
# tagging.WAF1-0109-AF_level_1_zone.WAF1-0109-AF_level_1_zone.yaxis = -139.2 8.523541722065578e-15 -0.0
# tagging.WAF1-0109-AF_level_1_zone.WAF1-0109-AF_level_1_zone.zaxis = 0.0 0.0 121.80000000000001
# tagging.WAF1-0110-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0110-AF_level_1_zone.shapes = WAF1-0110-AF_level_1_zone
# tagging.WAF1-0110-AF_level_1_zone.level  = 1
# tagging.WAF1-0110-AF_level_1_zone.WAF1-0110-AF_level_1_zone.type = box
# tagging.WAF1-0110-AF_level_1_zone.WAF1-0110-AF_level_1_zone.origin = 634167.81 4014134.1300000004 25.924999999999997
# tagging.WAF1-0110-AF_level_1_zone.WAF1-0110-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0110-AF_level_1_zone.WAF1-0110-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0110-AF_level_1_zone.WAF1-0110-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0111-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0111-AF_level_1_zone.shapes = WAF1-0111-AF_level_1_zone
# tagging.WAF1-0111-AF_level_1_zone.level  = 1
# tagging.WAF1-0111-AF_level_1_zone.WAF1-0111-AF_level_1_zone.type = box
# tagging.WAF1-0111-AF_level_1_zone.WAF1-0111-AF_level_1_zone.origin = 632742.53 4018823.4 18.22999999999999
# tagging.WAF1-0111-AF_level_1_zone.WAF1-0111-AF_level_1_zone.xaxis = 8.523541722065578e-15 139.2 0.0
# tagging.WAF1-0111-AF_level_1_zone.WAF1-0111-AF_level_1_zone.yaxis = -139.2 8.523541722065578e-15 -0.0
# tagging.WAF1-0111-AF_level_1_zone.WAF1-0111-AF_level_1_zone.zaxis = 0.0 0.0 121.80000000000001
# tagging.WAF1-0112-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0112-AF_level_1_zone.shapes = WAF1-0112-AF_level_1_zone
# tagging.WAF1-0112-AF_level_1_zone.level  = 1
# tagging.WAF1-0112-AF_level_1_zone.WAF1-0112-AF_level_1_zone.type = box
# tagging.WAF1-0112-AF_level_1_zone.WAF1-0112-AF_level_1_zone.origin = 630826.5900000001 4013471.08 25.924999999999997
# tagging.WAF1-0112-AF_level_1_zone.WAF1-0112-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0112-AF_level_1_zone.WAF1-0112-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0112-AF_level_1_zone.WAF1-0112-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0113-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0113-AF_level_1_zone.shapes = WAF1-0113-AF_level_1_zone
# tagging.WAF1-0113-AF_level_1_zone.level  = 1
# tagging.WAF1-0113-AF_level_1_zone.WAF1-0113-AF_level_1_zone.type = box
# tagging.WAF1-0113-AF_level_1_zone.WAF1-0113-AF_level_1_zone.origin = 631243.6900000001 4013218.31 25.924999999999997
# tagging.WAF1-0113-AF_level_1_zone.WAF1-0113-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0113-AF_level_1_zone.WAF1-0113-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0113-AF_level_1_zone.WAF1-0113-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0114-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0114-AF_level_1_zone.shapes = WAF1-0114-AF_level_1_zone
# tagging.WAF1-0114-AF_level_1_zone.level  = 1
# tagging.WAF1-0114-AF_level_1_zone.WAF1-0114-AF_level_1_zone.type = box
# tagging.WAF1-0114-AF_level_1_zone.WAF1-0114-AF_level_1_zone.origin = 631597.62 4013572.1 25.924999999999997
# tagging.WAF1-0114-AF_level_1_zone.WAF1-0114-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0114-AF_level_1_zone.WAF1-0114-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0114-AF_level_1_zone.WAF1-0114-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0115-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0115-AF_level_1_zone.shapes = WAF1-0115-AF_level_1_zone
# tagging.WAF1-0115-AF_level_1_zone.level  = 1
# tagging.WAF1-0115-AF_level_1_zone.WAF1-0115-AF_level_1_zone.type = box
# tagging.WAF1-0115-AF_level_1_zone.WAF1-0115-AF_level_1_zone.origin = 632057.8 4013274.0900000003 25.924999999999997
# tagging.WAF1-0115-AF_level_1_zone.WAF1-0115-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0115-AF_level_1_zone.WAF1-0115-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0115-AF_level_1_zone.WAF1-0115-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0116-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0116-AF_level_1_zone.shapes = WAF1-0116-AF_level_1_zone
# tagging.WAF1-0116-AF_level_1_zone.level  = 1
# tagging.WAF1-0116-AF_level_1_zone.WAF1-0116-AF_level_1_zone.type = box
# tagging.WAF1-0116-AF_level_1_zone.WAF1-0116-AF_level_1_zone.origin = 632454.87 4013192.0700000003 25.924999999999997
# tagging.WAF1-0116-AF_level_1_zone.WAF1-0116-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0116-AF_level_1_zone.WAF1-0116-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0116-AF_level_1_zone.WAF1-0116-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0117-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0117-AF_level_1_zone.shapes = WAF1-0117-AF_level_1_zone
# tagging.WAF1-0117-AF_level_1_zone.level  = 1
# tagging.WAF1-0117-AF_level_1_zone.WAF1-0117-AF_level_1_zone.type = box
# tagging.WAF1-0117-AF_level_1_zone.WAF1-0117-AF_level_1_zone.origin = 633790.8 4013286.3600000003 25.924999999999997
# tagging.WAF1-0117-AF_level_1_zone.WAF1-0117-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0117-AF_level_1_zone.WAF1-0117-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0117-AF_level_1_zone.WAF1-0117-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0118-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0118-AF_level_1_zone.shapes = WAF1-0118-AF_level_1_zone
# tagging.WAF1-0118-AF_level_1_zone.level  = 1
# tagging.WAF1-0118-AF_level_1_zone.WAF1-0118-AF_level_1_zone.type = box
# tagging.WAF1-0118-AF_level_1_zone.WAF1-0118-AF_level_1_zone.origin = 634107.64 4013415.1 25.924999999999997
# tagging.WAF1-0118-AF_level_1_zone.WAF1-0118-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0118-AF_level_1_zone.WAF1-0118-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0118-AF_level_1_zone.WAF1-0118-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0119-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0119-AF_level_1_zone.shapes = WAF1-0119-AF_level_1_zone
# tagging.WAF1-0119-AF_level_1_zone.level  = 1
# tagging.WAF1-0119-AF_level_1_zone.WAF1-0119-AF_level_1_zone.type = box
# tagging.WAF1-0119-AF_level_1_zone.WAF1-0119-AF_level_1_zone.origin = 630787.7000000001 4012327.3800000004 25.924999999999997
# tagging.WAF1-0119-AF_level_1_zone.WAF1-0119-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0119-AF_level_1_zone.WAF1-0119-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0119-AF_level_1_zone.WAF1-0119-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0120-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0120-AF_level_1_zone.shapes = WAF1-0120-AF_level_1_zone
# tagging.WAF1-0120-AF_level_1_zone.level  = 1
# tagging.WAF1-0120-AF_level_1_zone.WAF1-0120-AF_level_1_zone.type = box
# tagging.WAF1-0120-AF_level_1_zone.WAF1-0120-AF_level_1_zone.origin = 633002.25 4011643.22 25.924999999999997
# tagging.WAF1-0120-AF_level_1_zone.WAF1-0120-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0120-AF_level_1_zone.WAF1-0120-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0120-AF_level_1_zone.WAF1-0120-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0121-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0121-AF_level_1_zone.shapes = WAF1-0121-AF_level_1_zone
# tagging.WAF1-0121-AF_level_1_zone.level  = 1
# tagging.WAF1-0121-AF_level_1_zone.WAF1-0121-AF_level_1_zone.type = box
# tagging.WAF1-0121-AF_level_1_zone.WAF1-0121-AF_level_1_zone.origin = 633789.71 4011963.4099999997 18.22999999999999
# tagging.WAF1-0121-AF_level_1_zone.WAF1-0121-AF_level_1_zone.xaxis = 8.523541722065578e-15 139.2 0.0
# tagging.WAF1-0121-AF_level_1_zone.WAF1-0121-AF_level_1_zone.yaxis = -139.2 8.523541722065578e-15 -0.0
# tagging.WAF1-0121-AF_level_1_zone.WAF1-0121-AF_level_1_zone.zaxis = 0.0 0.0 121.80000000000001
# tagging.WAF1-0122-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0122-AF_level_1_zone.shapes = WAF1-0122-AF_level_1_zone
# tagging.WAF1-0122-AF_level_1_zone.level  = 1
# tagging.WAF1-0122-AF_level_1_zone.WAF1-0122-AF_level_1_zone.type = box
# tagging.WAF1-0122-AF_level_1_zone.WAF1-0122-AF_level_1_zone.origin = 634195.47 4011966.6999999997 18.22999999999999
# tagging.WAF1-0122-AF_level_1_zone.WAF1-0122-AF_level_1_zone.xaxis = 8.523541722065578e-15 139.2 0.0
# tagging.WAF1-0122-AF_level_1_zone.WAF1-0122-AF_level_1_zone.yaxis = -139.2 8.523541722065578e-15 -0.0
# tagging.WAF1-0122-AF_level_1_zone.WAF1-0122-AF_level_1_zone.zaxis = 0.0 0.0 121.80000000000001
# tagging.WAF1-0123-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0123-AF_level_1_zone.shapes = WAF1-0123-AF_level_1_zone
# tagging.WAF1-0123-AF_level_1_zone.level  = 1
# tagging.WAF1-0123-AF_level_1_zone.WAF1-0123-AF_level_1_zone.type = box
# tagging.WAF1-0123-AF_level_1_zone.WAF1-0123-AF_level_1_zone.origin = 634491.52 4012470.17 18.22999999999999
# tagging.WAF1-0123-AF_level_1_zone.WAF1-0123-AF_level_1_zone.xaxis = 8.523541722065578e-15 139.2 0.0
# tagging.WAF1-0123-AF_level_1_zone.WAF1-0123-AF_level_1_zone.yaxis = -139.2 8.523541722065578e-15 -0.0
# tagging.WAF1-0123-AF_level_1_zone.WAF1-0123-AF_level_1_zone.zaxis = 0.0 0.0 121.80000000000001
# tagging.WAF1-0124-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0124-AF_level_1_zone.shapes = WAF1-0124-AF_level_1_zone
# tagging.WAF1-0124-AF_level_1_zone.level  = 1
# tagging.WAF1-0124-AF_level_1_zone.WAF1-0124-AF_level_1_zone.type = box
# tagging.WAF1-0124-AF_level_1_zone.WAF1-0124-AF_level_1_zone.origin = 634885.52 4012496.56 18.22999999999999
# tagging.WAF1-0124-AF_level_1_zone.WAF1-0124-AF_level_1_zone.xaxis = 8.523541722065578e-15 139.2 0.0
# tagging.WAF1-0124-AF_level_1_zone.WAF1-0124-AF_level_1_zone.yaxis = -139.2 8.523541722065578e-15 -0.0
# tagging.WAF1-0124-AF_level_1_zone.WAF1-0124-AF_level_1_zone.zaxis = 0.0 0.0 121.80000000000001
# tagging.WAF1-0125-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0125-AF_level_1_zone.shapes = WAF1-0125-AF_level_1_zone
# tagging.WAF1-0125-AF_level_1_zone.level  = 1
# tagging.WAF1-0125-AF_level_1_zone.WAF1-0125-AF_level_1_zone.type = box
# tagging.WAF1-0125-AF_level_1_zone.WAF1-0125-AF_level_1_zone.origin = 632979.51 4010778.24 25.924999999999997
# tagging.WAF1-0125-AF_level_1_zone.WAF1-0125-AF_level_1_zone.xaxis = 7.568317218730642e-15 123.6 0.0
# tagging.WAF1-0125-AF_level_1_zone.WAF1-0125-AF_level_1_zone.yaxis = -123.6 7.568317218730642e-15 -0.0
# tagging.WAF1-0125-AF_level_1_zone.WAF1-0125-AF_level_1_zone.zaxis = 0.0 0.0 108.15
# tagging.WAF1-0126-AF_level_1_zone.type   = GeometryRefinement
# tagging.WAF1-0126-AF_level_1_zone.shapes = WAF1-0126-AF_level_1_zone
# tagging.WAF1-0126-AF_level_1_zone.level  = 1
# tagging.WAF1-0126-AF_level_1_zone.WAF1-0126-AF_level_1_zone.type = box
# tagging.WAF1-0126-AF_level_1_zone.WAF1-0126-AF_level_1_zone.origin = 633337.7899999999 4010773.35 18.22999999999999
# tagging.WAF1-0126-AF_level_1_zone.WAF1-0126-AF_level_1_zone.xaxis = 8.523541722065578e-15 139.2 0.0
# tagging.WAF1-0126-AF_level_1_zone.WAF1-0126-AF_level_1_zone.yaxis = -139.2 8.523541722065578e-15 -0.0
# tagging.WAF1-0126-AF_level_1_zone.WAF1-0126-AF_level_1_zone.zaxis = 0.0 0.0 121.80000000000001
#
# #---- postprocessing defs ----
# incflo.post_processing                   = sampling
# sampling.type                            = Sampling
# sampling.output_frequency                = 2000
# sampling.fields                          = velocity
#
# #---- sample defs ----
# sampling.labels                          = p_hub
# sampling.p_hub.type                      = PlaneSampler
# sampling.p_hub.num_points                = 1025 1025
# sampling.p_hub.origin                    = 619640.0 4008140.0 0.0
# sampling.p_hub.axis1                     = 40960.0 0.0 0.0
# sampling.p_hub.axis2                     = 0.0 40960.0 0.0
# sampling.p_hub.normal                    = 0.0 0.0 1.0
# sampling.p_hub.offsets                   = 60 91
#
# #---- extra params ----
# amr.blocking_factor                      = 16
# amr.max_grid_size                        = 64
# #== END AMR-WIND INPUT ==
