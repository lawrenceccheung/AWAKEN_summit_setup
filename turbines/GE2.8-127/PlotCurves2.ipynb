# %% [markdown]
# #  Plot NREL 2.8-127 Performance curve for AMR-Wind+OpenFAST

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

# %matplotlib inline

# Important header information
amrwindfedir = '/projects/wind_uq/lcheung/amrwind-frontend/'  # where amrwind-frontend resides
import sys, os
sys.path.insert(1, amrwindfedir)
import OpenFASTutil as OpenFAST

# %%
# Load ruamel or pyyaml as needed
try:
    import ruamel.yaml as yaml
    print("# Loaded ruamel.yaml")
    useruamel=True
    loaderkwargs = {'Loader':yaml.RoundTripLoader}
    dumperkwargs = {'Dumper':yaml.RoundTripDumper, 'indent':4, 'default_flow_style':False} 
except:
    import yaml as yaml
    print("# Loaded yaml")
    useruamel=False
    loaderkwargs = {}
    dumperkwargs = {'default_flow_style':False }
    
if useruamel: Loader=yaml.load
else:         Loader=yaml.safe_load
# Out:
# # Loaded ruamel.yaml

# %%
# Define some helper functions

def avgoutputs(pddat, tavg, keys, timekey='Time'):
    """
    Function to average the pddat over a specific time
    """
    t = pddat[timekey].values
    
    # Filter the appropriate times
    timefilter = (tavg[0]<=t)&(t<=tavg[1])
    tfilter   = t[timefilter]
    # Get the total time
    dt = np.amax(tfilter) - np.amin(tfilter)

    outdict = {}
    for key in keys:
        #f = pddat[key].values
        try:
            outdict[key] = np.trapz(pddat[key].values[timefilter], x=tfilter, axis=0) / dt
        except:
            pass
    return outdict

readoutfile = lambda f: pd.read_csv(f,sep='\s+',skiprows=(0,1,2,3,4,5,7), header=(0),skipinitialspace=True)

def calcCt(p,  rho, U, rmax, ctkey='RtAeroFxh'):
    thrust = p[ctkey]
    A = np.pi*rmax*rmax
    Q = 0.5*rho*U*U*A
    Ct = thrust/Q
    return Ct

# Grep a file for a pattern
def grepfile(filename, pattern):
    file = open(filename, "r")
    for line in file:
        if line.startswith(pattern):
            return line
    return None

# Stuff for loading calibration runs
def merge_two_dicts(x, y):
    for k, g in y.items(): x[k] = g
    return x

def loadLogFile(logfile, extradict={}):
    # Load a log file
    fp = open(logfile, 'r')
    yamldict = Loader(fp, **loaderkwargs)
    fp.close()
    returnlist=[]
    for k, g in yamldict.items():
        returnlist.append(merge_two_dicts(g, extradict))
    return returnlist

def avgNCdat(ncfile, turbname, tavg, avgq):
    ncdat = Dataset(ncfile)
    return avgoutputs(ncdat[turbname], tavg, avgq)

def loadPC_OF(logfile, extradict, firsttag, outfile, tavg, avgq, prefixdir=''):
    PC = loadLogFile(prefixdir+logfile, extradict=extradict)
    # Set up the first tag
    PC[0]['tag'] = firsttag
    # Set up the out files
    for x in PC: 
        x['outfile']=prefixdir+x['dir']+outfile
    # Load the power curves from the netCDF data
    for pc in PC:
        datafile = pc['outfile']
        outdat   = readoutfile(datafile)
        pc.update(avgoutputs(outdat, tavg, avgq))
        #pc.update(avgNCdat(datafile, turbname, tavg, avgq))
    return PC

def loadPC_Joukowski(logfile, extradict, firsttag, ncfile, turbname, tavg, avgq, prefixdir=''):
    PC = loadLogFile(prefixdir+logfile, extradict=extradict)
    # Set up the first tag
    PC[0]['tag'] = firsttag
    # Set up the out files
    for x in PC: 
        x['outfile']=prefixdir+x['dir']+ncfile
    # Load the power curves from the netCDF data
    for pc in PC:
        datafile = pc['outfile']
        pc.update(avgNCdat(datafile, turbname, tavg, avgq))
    return PC

# %%
# Global averaging parameters
tavg = [300, 360]
avgq = ['GenPwr', 'RotSpeed', 'BldPitch1', 'RotTorq','RtAeroFxh', 'RotThrust'] # RtAeroCt, 'RtAeroFxh'
#avgq = ['GenPwr', 'RotSpeed', 'BldPitch1', 'GenTq','RotTorq','RtAeroCt']
pcvar= ['generator power [kW]', 'rotor speed [RPM]', 'blade pitch [deg]', 
        'rotor torque [kN-m]', 'rotor thrust [kN]', '']
rho  = 1.225
rmax = 127.0/2

# %% [markdown]
# ## Load the OpenFAST only runs

# %%
# Load the OpenFAST only data
basedir = '/pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve'
prefix  = 'nrel_'
wsvec   = np.arange(3, 16, 0.5)
PC_OpenFAST = []

# Load the data
for ws in wsvec:
    #datafile = basedir+'/'+prefix+str(ws)+'mps'+'/'+prefix+str(ws)+'mps.out'
    datafile = basedir+'/'+prefix+str(ws)+'mps'+'/NREL-2p8-127.out'
    print(datafile)
    outdat   = readoutfile(datafile)
    outdict  = avgoutputs(outdat, [120, 180], avgq)
    outdict['WS'] = ws
    #for i, bstr in enumerate(['B1N%iFx', 'B2N%iFx', 'B3N%iFx']):
    #    outdict['B%iFx'%i] = mergebladeprop(outdict, bstr, range(1,10))
    #outdict['B2Fx'] = mergebladeprop(outdict, 'B2N%iFx', range(1,10))
    #outdict['B3Fx'] = mergebladeprop(outdict, 'B3N%iFx', range(1,10))
    PC_OpenFAST.append(outdict)
# Out:
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_3.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_3.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_4.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_4.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_5.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_5.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_6.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_6.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_7.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_7.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_8.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_8.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_9.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_9.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_10.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_10.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_11.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_11.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_12.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_12.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_13.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_13.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_14.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_14.5mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_15.0mps/NREL-2p8-127.out
# /pscratch/ndeveld/ldrd-awc/of-sims/wind-sweep-NREL-2p8-127-5_10_22/power_curve/nrel_15.5mps/NREL-2p8-127.out

# %% [markdown]
# ## Load the AMR-Wind runs

# %%
# Load AMR-Wind OpenFAST data

# Change this directory to wherever the cases were run
amrdir = '/nscratch/lcheung/2021/AWAKEN/turbinerun/GE2.8-127.ADM_bugfixed/' 
PC_amr = [] #OrderedDict()

PC_amr = loadPC_OF('RunCalibration_dx2.5_Eps5.00_logfile.yaml',
              {'tag':'', 'ms':'o', 'mfc':'b', 'color':'b'}, 
              'AMR-Wind OF ADM $\epsilon=5$', 
              '/T0_OpenFAST3p3_NREL2p8-127.bugfix/NREL-2p8-127.out', tavg, avgq, prefixdir=amrdir)

amrdir2 = '/nscratch/lcheung/2021/AWAKEN/turbinerun/GE2.8-127/testCalibrate/' 
PC_amr2 = [] #OrderedDict()
#PC_amr2 = loadPC_OF('RunCalibration_Eps2.50_logfile.yaml',
#              {'tag':'', 'ms':'+', 'mfc':'c', 'color':'k'}, 
#              'AMR-Wind ADM $\epsilon=2.5$ N=64', 
#              '/T0_OpenFAST3p1_NREL2p8-127/NREL-2p8-127.out', tavg, avgq, prefixdir=amrdir2)

# %%
# Get original design power curve
# Note that this file is available at https://github.com/NREL/openfast-turbine-models/tree/master/IEA-scaled/NREL-2.8-127
pc = pd.read_csv('NREL-2.8-127.csv')

# %%
# Put curves to plot here
plotcurves = PC_amr + PC_amr2 #+ PC_amr3 + PC_amr2 + PC_amr4

figsize = (4,2)
dpi     = 125
turbmodel = 'GE2.8-127'

# Plot quantities
for iq, q in enumerate(avgq):
    plt.figure(q, figsize=figsize, dpi=dpi)
    # Plot original power curve
    if len(pcvar[iq])>0:
        plt.plot(pc['wind speed [m/s]'], pc[pcvar[iq]], 'k--', label='Design Power Curve')
    
    # Plot OpenFAST powercurve
    p = [x[q] for x in PC_OpenFAST] 
    scale=1000.0 if max(np.array(p))>10000 else 1.0
    #scale=1
    plt.plot(wsvec, np.array(p)/scale, 'k-.', label='OpenFAST only', linewidth=0.5)

    # Plot AMR-Wind power curve
    for p in plotcurves:
        plotq = 'RotThrust' if q=='RtAeroFxh' else q  #print(p['tag'],p[q]/scale)
        scale=1000.0 if np.max(p[plotq])>10000 else 1.0
        mfc='w' if 'mfc' not in p else p['mfc']
        plt.plot(p['WS'], p[plotq]/scale, marker=p['ms'], mfc=mfc, mec=p['color'], linewidth=0, ms=5, label=p['tag'])
        
        
    plt.legend(fontsize=6) # loc='lower right',
    plt.xlabel('WS [m/s]')
    plt.xlim([2,15])
    plt.grid(linestyle=':')
    plt.title(q)
    plt.tight_layout()

plt.figure('GenPwr')
plt.title('%s Turbine power [kW]'%turbmodel)
plt.ylim([0, 3000])
plt.savefig('%s-GenPwr.png'%turbmodel)

plt.figure('RotThrust')
plt.title('%s Turbine thrust [kN]'%turbmodel)
plt.savefig('%s-thrust.png'%turbmodel)

# Plot real Ct
plt.figure(figsize=(6,3), dpi=150)
plt.plot(pc['wind speed [m/s]'], pc['Ct [-]'], 'k--', label='Design Power Curve')

for p in plotcurves:
    density = p['rho'] if 'rho' in p else rho
    ctx = calcCt(p, density, p['WS'], rmax, ctkey='RotThrust')*1000
    mfc='w' if 'mfc' not in p else p['mfc']
    plt.plot(p['WS'], ctx, marker=p['ms'], mfc=mfc, mec=p['color'], linewidth=0, ms=5, label=p['tag'])

ct = [calcCt(x, rho, x['WS'], rmax) for x in PC_OpenFAST] 
plt.plot(wsvec, ct, 'k-.', label='OpenFAST only', linewidth=0.5)
    
    
plt.legend(fontsize=6) # loc='lower right',
plt.xlabel('WS [m/s]')
plt.xlim([2,15])
plt.grid(linestyle=':')
plt.title('Ct')
plt.tight_layout()
