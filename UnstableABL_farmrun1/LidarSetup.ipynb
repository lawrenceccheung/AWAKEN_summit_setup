# %% [markdown]
# # Translate lidar setup from AMR-Wind to Nalu-Wind

# %%
# Load the amrwind-frontend module
# Add any possible locations of amr-wind-frontend here
amrwindfedirs = ['/ascldap/users/lcheung/wind_uq/amrwind-frontend/',
                 '/ccs/proj/cfd162/lcheung/amrwind-frontend/']
import sys, os, shutil
for x in amrwindfedirs: sys.path.insert(1, x)

# Load the libraries
import amrwind_frontend  as amrwind
import matplotlib.pyplot as plt
import numpy             as np
import math
import pandas as pd
import postproamrwindsample as ppsample
import time
import utm
import yaml as yaml
from IPython.display import display, Markdown, Latex

# Also ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Make all plots inline 
# %matplotlib inline

Loader=yaml.safe_load

# %%
def convertNaluLidar(naludict, overridecenter=None, periodic=True):
    amrdict = {}
    amrdict['name'] = naludict['name'].replace('/','_')
    lidarspec       = naludict['scanning_lidar_specifications']
    
    sweep_angle           = lidarspec['sweep_angle']
    stare_time            = lidarspec['stare_time']
    step_delta_angle      = lidarspec['step_delta_angle']
    elevation_angles      = lidarspec['elevation_angles']
    T_per_ele             = stare_time*(sweep_angle/step_delta_angle)
    T_per_scan            = len(elevation_angles)*T_per_ele 
    # Get the lidar center angle
    axis                  = lidarspec['axis']
    sweep_center = np.arctan2(float(axis[1]), float(axis[0]))*180.0/np.pi  # Compute sweep_center from axis
    #print(sweep_center)
    azi1         = sweep_center - 0.5*sweep_angle
    azi2         = sweep_center + 0.5*sweep_angle
    
    amrdict['origin']     = lidarspec['center'] if overridecenter is None else overridecenter
    amrdict['length']     = lidarspec['beam_length']
    amrdict['num_points'] = naludict['points_along_line']
    amrdict['periodic']   = periodic
    t_between_azisweep    = 0.001
    
    t_table   = []
    azi_table = []
    ele_table = []
    
    if ('ground_direction') in lidarspec and lidarspec['ground_direction']==[1,0,0]:
        for dazi in elevation_angles:
            azi0    = sweep_center + dazi
            ele1    = -0.5*sweep_angle
            ele2    = +0.5*sweep_angle
            t_seg   = [0.0, T_per_scan]
            azi_seg = [azi0, azi0]
            ele_seg = [ele1, ele2]
            if len(t_table)>0:
                t0    = t_table[-1]
                t_seg = [t0+t+t_between_azisweep for t in t_seg]
            t_table = t_table + t_seg
            azi_table = azi_table + azi_seg
            ele_table = ele_table + ele_seg
    else:
        for ele in elevation_angles:
            t_seg   = [0.0, T_per_scan]
            azi_seg = [azi1, azi2]
            ele_seg = [ele, ele]
            if len(t_table)>0:
                t0    = t_table[-1]
                t_seg = [t0+t+t_between_azisweep for t in t_seg]
            t_table = t_table + t_seg
            azi_table = azi_table + azi_seg
            ele_table = ele_table + ele_seg
    
    # Convert to strings
    amrdict['time_table']      = ' '.join([repr(x) for x in t_table])
    amrdict['azimuth_table']   = ' '.join([repr(x) for x in azi_table])
    amrdict['elevation_table'] = ' '.join([repr(x) for x in ele_table])

    return amrdict

def plotLidarDict(axs, d, formatfunc=None):
    str2list = lambda l: [float(x) for x in l.split()] 
    time_table = str2list(d['time_table'])
    azimuth_table   = str2list(d['azimuth_table'])
    elevation_table = str2list(d['elevation_table'])
    axs[0].plot(time_table, azimuth_table)
    axs[1].plot(time_table, elevation_table)
    if formatfunc is not None:
        formatfunc(axs)
    return

def getTurbSubset(csvfile, suffix):
    # Load the data from the database of all turbines
    allturbsdf = pd.read_csv(csvfile, low_memory=False)
    # Get just the King Plains turbines
    subset = [] 
    for x in allturbsdf.iterrows():
        if x[1]['# name'].endswith(suffix):
            subset.append(x[1])
    subsetdf = pd.DataFrame(subset[:])
    return subsetdf

# %%
naluyaml="""
    - name: lidar/FarmStats_Up  #Farm statistics (upstream)
      from_target_part: &allparts 1
      type: scanning
      frequency: 10 #Hz
      points_along_line: 667
      output: text
      reuse_search_data: no            
      scanning_lidar_specifications:
        center: [10050.588260, 8081.533244, 91.0]    # Location of the scanning LIDAR
        beam_length: 2000.0 #m
        axis: [0.087155742,-0.996194698,0] # Zero angle vector for the angular sweep; [0.087155742,-0.996194698,0] for inflow scan and [-0.087155742,0.996194698,0] for wake scan
        stare_time: 1.9 #s
        sweep_angle: 120 #deg, Extent of angular sweep between sweep_angle/2 to -sweep_angle/2
        step_delta_angle: 10 #deg
        reset_time_delta: 0 #s, Time to reset LIDAR after sweep. 
        elevation_angles: [-10,-8,-6,-4,-2,0,2,4,6,8,10]

    - name: lidar/FarmStats_Dn  # Farm statistics (downstream)
      from_target_part: *allparts
      type: scanning
      frequency: 10 #Hz
      points_along_line: 667
      output: text
      reuse_search_data: no            
      scanning_lidar_specifications:
        center: [10050.588260, 8081.533244, 91.0]    # Location of the scanning LIDAR
        beam_length: 2000.0 #m
        axis: [-0.087155742,0.996194698,0] # Zero angle vector for the angular sweep; [0.087155742,-0.996194698,0] for inflow scan and [-0.087155742,0.996194698,0] for wake scan
        stare_time: 1.9 #s
        sweep_angle: 120 #deg, Extent of angular sweep between sweep_angle/2 to -sweep_angle/2
        step_delta_angle: 10 #deg
        reset_time_delta: 0 #s, Time to reset LIDAR after sweep. 
        elevation_angles: [-10,-8,-6,-4,-2,0,2,4,6,8,10]

    - name: lidar/WakeStats  # Wake statistics
      from_target_part: *allparts
      type: scanning
      frequency: 10 #Hz
      points_along_line: 667
      output: text
      reuse_search_data: no            
      scanning_lidar_specifications:
        center: [10050.588260, 8081.533244, 91.0]    # Location of the scanning LIDAR
        beam_length: 2000.0 #m
        axis: [-0.087155742,0.996194698,0] # Zero angle vector for the angular sweep; [0.087155742,-0.996194698,0] for inflow scan and [-0.087155742,0.996194698,0] for wake scan
        stare_time: 1.4 #s
        sweep_angle: 30 #deg, Extent of angular sweep between sweep_angle/2 to -sweep_angle/2
        step_delta_angle: 3 #deg
        reset_time_delta: 0 #s, Time to reset LIDAR after sweep. 
        elevation_angles: [-15,-12,-9,-6,-3,0,3,6,9,12,15]

    - name: lidar/SpeedupStats  # Speedup statistics
      from_target_part: *allparts
      type: scanning
      frequency: 10 #Hz
      points_along_line: 667
      output: text
      reuse_search_data: no            
      scanning_lidar_specifications:
        center: [10050.588260, 8081.533244, 91.0]    # Location of the scanning LIDAR
        beam_length: 2000.0 #m
        axis: [0.087155742,-0.996194698,0] # Zero angle vector for the angular sweep; [0.087155742,-0.996194698,0] for inflow scan and [-0.087155742,0.996194698,0] for wake scan
        stare_time: 1.3 #s
        sweep_angle: 360 #deg, Extent of angular sweep between sweep_angle/2 to -sweep_angle/2
        step_delta_angle: 2 #deg
        reset_time_delta: 0 #s, Time to reset LIDAR after sweep. 
        elevation_angles: [0]

    - name: lidar/InflowTurb  # Inflow turbulence
      from_target_part: *allparts
      type: scanning
      frequency: 10 #Hz
      points_along_line: 667
      output: text
      reuse_search_data: no            
      scanning_lidar_specifications:
        center: [10050.588260, 8081.533244, 91.0]    # Location of the scanning LIDAR
        beam_length: 2000.0 #m
        axis: [0.087155742,-0.996194698,0] # Zero angle vector for the angular sweep; [0.087155742,-0.996194698,0] for inflow scan and [-0.087155742,0.996194698,0] for wake scan
        stare_time: 1.3 #s
        sweep_angle: 30 #deg, Extent of angular sweep between sweep_angle/2 to -sweep_angle/2
        step_delta_angle: 2 #deg
        reset_time_delta: 0 #s, Time to reset LIDAR after sweep. 
        elevation_angles: [0]

    - name: lidar/HorizWakeMeand  # Horizontal wake meandering
      from_target_part: *allparts
      type: scanning
      frequency: 10 #Hz
      points_along_line: 667
      output: text
      reuse_search_data: no            
      scanning_lidar_specifications:
        center: [10050.588260, 8081.533244, 91.0]    # Location of the scanning LIDAR
        beam_length: 2000.0 #m
        axis: [-0.087155742,0.996194698,0] # Zero angle vector for the angular sweep; [0.087155742,-0.996194698,0] for inflow scan and [-0.087155742,0.996194698,0] for wake scan
        stare_time: 1.3 #s
        sweep_angle: 30 #deg, Extent of angular sweep between sweep_angle/2 to -sweep_angle/2
        step_delta_angle: 2 #deg
        reset_time_delta: 0 #s, Time to reset LIDAR after sweep. 
        elevation_angles: [0]

    - name: lidar/VerticalWakeMeand  # Vertical wake meandering
      from_target_part: *allparts
      type: scanning
      frequency: 10 #Hz
      points_along_line: 667
      output: text
      reuse_search_data: no            
      scanning_lidar_specifications:
        center: [10050.588260, 8081.533244, 91.0]    # Location of the scanning LIDAR
        beam_length: 2000.0 #m
        axis: [-0.087155742,0.996194698,0] # Zero angle vector for the angular sweep; [0.087155742,-0.996194698,0] for inflow scan and [-0.087155742,0.996194698,0] for wake scan
        stare_time: 1.3 #s
        sweep_angle: 30 #deg, Extent of angular sweep between sweep_angle/2 to -sweep_angle/2
        step_delta_angle: 2 #deg
        reset_time_delta: 0 #s, Time to reset LIDAR after sweep. 
        elevation_angles: [0]
        ground_direction: [1,0,0] # turn the sweep direction vertical

"""

# %%
yamldict = Loader(naluyaml)

# %%
def formatfunc(axs):
    #axs[0].set_xlim([0, 3000])
    axs[0].grid(ls=':')
    axs[1].grid(ls=':')
    axs[1].set_xlabel('Time [s]')
    axs[0].set_ylabel('Azimuth [deg]')
    axs[1].set_ylabel('Elevation [deg]')
    return

for p in yamldict:
    fig, axs = plt.subplots(2,1, figsize=(8,3.5), dpi=150, sharex=True)
    amrp = convertNaluLidar(p)
    print(amrp)
    plotLidarDict(axs, amrp, formatfunc=formatfunc)
    fig.suptitle(amrp['name'])
# Out:
# {'name': 'lidar_FarmStats_Up', 'origin': [10050.58826, 8081.533244, 91.0], 'length': 2000.0, 'num_points': 667, 'periodic': True, 'time_table': '0.0 250.79999999999995 250.80099999999996 501.6009999999999 501.60199999999986 752.4019999999998 752.4029999999998 1003.2029999999997 1003.2039999999997 1254.0039999999997 1254.0049999999997 1504.8049999999996 1504.8059999999996 1755.6059999999995 1755.6069999999995 2006.4069999999995 2006.4079999999994 2257.2079999999996 2257.209 2508.009 2508.01 2758.8100000000004', 'azimuth_table': '-145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513', 'elevation_table': '-10 -10 -8 -8 -6 -6 -4 -4 -2 -2 0 0 2 2 4 4 6 6 8 8 10 10'}
# {'name': 'lidar_FarmStats_Dn', 'origin': [10050.58826, 8081.533244, 91.0], 'length': 2000.0, 'num_points': 667, 'periodic': True, 'time_table': '0.0 250.79999999999995 250.80099999999996 501.6009999999999 501.60199999999986 752.4019999999998 752.4029999999998 1003.2029999999997 1003.2039999999997 1254.0039999999997 1254.0049999999997 1504.8049999999996 1504.8059999999996 1755.6059999999995 1755.6069999999995 2006.4069999999995 2006.4079999999994 2257.2079999999996 2257.209 2508.009 2508.01 2758.8100000000004', 'azimuth_table': '34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835', 'elevation_table': '-10 -10 -8 -8 -6 -6 -4 -4 -2 -2 0 0 2 2 4 4 6 6 8 8 10 10'}
# {'name': 'lidar_WakeStats', 'origin': [10050.58826, 8081.533244, 91.0], 'length': 2000.0, 'num_points': 667, 'periodic': True, 'time_table': '0.0 154.0 154.001 308.001 308.00199999999995 462.00199999999995 462.00299999999993 616.0029999999999 616.0039999999999 770.0039999999999 770.0049999999999 924.0049999999999 924.0059999999999 1078.0059999999999 1078.0069999999998 1232.0069999999998 1232.0079999999998 1386.0079999999998 1386.0089999999998 1540.0089999999998 1540.0099999999998 1694.0099999999998', 'azimuth_table': '79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835', 'elevation_table': '-15 -15 -12 -12 -9 -9 -6 -6 -3 -3 0 0 3 3 6 6 9 9 12 12 15 15'}
# {'name': 'lidar_SpeedupStats', 'origin': [10050.58826, 8081.533244, 91.0], 'length': 2000.0, 'num_points': 667, 'periodic': True, 'time_table': '0.0 234.0', 'azimuth_table': '-265.0000000422165 94.99999995778349', 'elevation_table': '0 0'}
# {'name': 'lidar_InflowTurb', 'origin': [10050.58826, 8081.533244, 91.0], 'length': 2000.0, 'num_points': 667, 'periodic': True, 'time_table': '0.0 19.5', 'azimuth_table': '-100.00000004221651 -70.00000004221651', 'elevation_table': '0 0'}
# {'name': 'lidar_HorizWakeMeand', 'origin': [10050.58826, 8081.533244, 91.0], 'length': 2000.0, 'num_points': 667, 'periodic': True, 'time_table': '0.0 19.5', 'azimuth_table': '79.9999999577835 109.9999999577835', 'elevation_table': '0 0'}
# {'name': 'lidar_VerticalWakeMeand', 'origin': [10050.58826, 8081.533244, 91.0], 'length': 2000.0, 'num_points': 667, 'periodic': True, 'time_table': '0.0 19.5', 'azimuth_table': '94.9999999577835 94.9999999577835', 'elevation_table': '-15.0 15.0'}

# %% [markdown]
# # Start the AMR-Wind domain plot

# %%
summitcsv    = 'UnstableABL_farmrun_turbines.csv'
KPturbdf = getTurbSubset(summitcsv, '-KP')

# %%
case = amrwind.MyApp.init_nogui()

# %%
case.setAMRWindInput('geometry.prob_lo',                         [588800.0, 3978800.0, 0.0])
case.setAMRWindInput('geometry.prob_hi',                         [691200.0, 4081200.0, 2560.0])
case.setAMRWindInput('amr.n_cell',                               [5120, 5120, 128])       # Number of cells in x, y, and z directions

# %%
# Set up averaging
lidarpprosetup = case.get_default_postprosetupdict()
lidarpprosetup['postprocessing_setup_name'] = 'lidar_'
lidarpprosetup['postprocessing_setup_type'] = 'Sampling'
lidarpprosetup['postprocessing_setup_output_frequency'] =  1
lidarpprosetup['postprocessing_setup_fields']           =  'velocity'
case.add_postprosetup(lidarpprosetup, verbose=True)
# Out:
# postprocessing_setup_name: 'lidar_'
# postprocessing_setup_type: 'Sampling'
# postprocessing_setup_output_frequency: 1
# postprocessing_setup_fields: 'velocity'
# postprocessing_setup_averaging_window: None
# postprocessing_setup_averaging_start_time: None
# postprocessing_setup_averaging_stop_time: None

# %%
overridecenter = [643050.588260, 4025581.533244, 91]  # On top of 2019-WTW-7915-KP
verbose = False
# Add metmast 
for lidar in yamldict:
    amrdict = convertNaluLidar(lidar, overridecenter=overridecenter)
    sampledict = case.get_default_samplingdict()
    sampledict['sampling_name']     = amrdict['name']
    del amrdict['name']
    sampledict['sampling_outputto'] = 'lidar_'
    sampledict['sampling_type']     = 'LidarSampler'
    #print(amrdict)
    for k, g in amrdict.items():
        sampledict['sampling_lidar_'+k] = g
    #sampledict['sampling_l_num_points'] = 50
    #sampledict['sampling_l_start']      = [site['utm'][0], site['utm'][1], 10]
    #sampledict['sampling_l_end']        = [site['utm'][0], site['utm'][1], 500]
    case.add_sampling(sampledict, verbose=verbose)
    if verbose: print('=================')

# %%
# Plot the domain
fig, axs = plt.subplots(1,2,figsize=(14,7), facecolor='w', dpi=125)

# Set any additional items to plot
case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':1, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{'title':'Lidar probes', 'fontsize':6, 'loc':'upper right', 'markerscale':2}"
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = ['lidar_FarmStats_Up',
                                                                'lidar_FarmStats_Dn',
                                                                #'lidar_WakeStats',
                                                                #'lidar_SpeedupStats',
                                                                #'lidar_InflowTurb',
                                                                #'lidar_HorizWakeMeand',
                                                                #'lidar_VerticalWakeMeand'
                                                               ] #case.listboxpopupwindict['listboxsampling'].getitemlist() 
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY' #'YZ'
case.popup_storteddata['plotdomain']['plot_refineboxes']     = [] 
case.popup_storteddata['plotdomain']['plot_turbines']        = [] #case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False

ax = axs[0]
case.plotDomain(ax=ax, verbose=False, plotskip=5)

# Plot the turbines on top of it
for x in KPturbdf.iterrows():    
    ax.plot(float(x[1][' x']), float(x[1][' y']), 'ks', markersize=4)

ax.set_aspect('auto')
ax.set_xlim([638000,  648000])
ax.set_ylim([4022500, 4032500])
ax.set_xlabel('UTM Easting [m]')
ax.set_ylabel('UTM Northing [m]')

# Plot the side view
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'YZ'
ax = axs[1]
case.plotDomain(ax=ax, verbose=False, plotskip=5)
ax.set_aspect('auto')
ax.set_xlim([4022500, 4028500])
ax.set_xlabel('UTM Northing [m]')
# Out:
# Text(0.5, 0, 'UTM Northing [m]')

# %%
# Plot the domain
fig, ax = plt.subplots(figsize=(7,7), facecolor='w', dpi=125)

# Set any additional items to plot
case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':1, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{'title':'Lidar probes', 'fontsize':6, 'loc':'upper right', 'markerscale':2}"
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = [#'lidar_FarmStats_Up',
                                                                #'lidar_FarmStats_Dn',
                                                                'lidar_SpeedupStats',
                                                                'lidar_WakeStats',
                                                                'lidar_InflowTurb',
                                                                #'lidar_HorizWakeMeand',
                                                                #'lidar_VerticalWakeMeand'
                                                               ] #case.listboxpopupwindict['listboxsampling'].getitemlist() 
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY' #'YZ'
case.popup_storteddata['plotdomain']['plot_refineboxes']     = [] 
case.popup_storteddata['plotdomain']['plot_turbines']        = [] #case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False
start = time.time()
case.plotDomain(ax=ax, verbose=False, plotskip=5)

# Plot the turbines on top of it
for x in KPturbdf.iterrows():    plt.plot(float(x[1][' x']), float(x[1][' y']), 'ks', markersize=4)

ax.set_aspect('auto')
ax.set_xlim([638000,  648000])
ax.set_ylim([4022500, 4032500])
#ax.set_xlim([640000,  646000])
#ax.set_ylim([4022500, 4028500])
ax.set_xlabel('UTM Easting [m]')
ax.set_ylabel('UTM Northing [m]')
# Out:
# Text(0, 0.5, 'UTM Northing [m]')

# %%
# Plot the domain
fig, axs = plt.subplots(1,2,figsize=(14,7), facecolor='w', dpi=125)

# Set any additional items to plot
case.popup_storteddata['plotdomain']['plot_sampleprobes_style']  = "{'markersize':1, 'marker':'.', 'linestyle':'None', }"
case.popup_storteddata['plotdomain']['plot_sampleprobes_legend'] = "{'title':'Lidar probes', 'fontsize':6, 'loc':'upper right', 'markerscale':2}"
case.popup_storteddata['plotdomain']['plot_sampleprobes']    = [#'lidar_FarmStats_Up',
                                                                #'lidar_FarmStats_Dn',
                                                                #'lidar_SpeedupStats',
                                                                #'lidar_WakeStats',
                                                                #'lidar_InflowTurb',
                                                                'lidar_HorizWakeMeand',
                                                                'lidar_VerticalWakeMeand'
                                                               ] #case.listboxpopupwindict['listboxsampling'].getitemlist() 
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'XY' #'YZ'
case.popup_storteddata['plotdomain']['plot_refineboxes']     = [] 
case.popup_storteddata['plotdomain']['plot_turbines']        = [] #case.listboxpopupwindict['listboxactuator'].getitemlist()
case.popup_storteddata['plotdomain']['plot_windnortharrows'] = False
ax=axs[0]
case.plotDomain(ax=ax, verbose=False, plotskip=5)

# Plot the turbines on top of it
for x in KPturbdf.iterrows():    ax.plot(float(x[1][' x']), float(x[1][' y']), 'ks', markersize=4)

ax.set_aspect('auto')
ax.set_xlim([638000,  648000])
ax.set_ylim([4022500, 4032500])
#ax.set_xlim([640000,  646000])
#ax.set_ylim([4022500, 4028500])
ax.set_xlabel('UTM Easting [m]')
ax.set_ylabel('UTM Northing [m]')

# Plot the side view
case.popup_storteddata['plotdomain']['plot_chooseview']      = 'YZ'
ax = axs[1]
case.plotDomain(ax=ax, verbose=False, plotskip=5)
ax.set_aspect('auto')
ax.set_xlim([4022500, 4028500])
ax.set_xlabel('UTM Northing [m]')
# Out:
# Text(0.5, 0, 'UTM Northing [m]')

# %%
print(case.writeAMRWindInput(''))
# Out:
# # --- Simulation time control parameters ---
# time.stop_time                           = 100.0               # Max (simulated) time to evolve [s]
# time.max_step                            = -1
# time.fixed_dt                            = -1.0                # Fixed timestep size (in seconds). If negative, then time.cfl is used
# incflo.verbose                           = 0
# io.check_file                            = chk
# incflo.use_godunov                       = true
# incflo.godunov_type                      = weno_z
# incflo.gravity                           = 0.0 0.0 -9.81       # Gravitational acceleration vector (x,y,z) [m/s^2]
# incflo.density                           = 1.0                 # Fluid density [kg/m^3]
# transport.viscosity                      = 1.872e-05           # Fluid dynamic viscosity [kg/m-s]
# transport.laminar_prandtl                = 0.7                 # Laminar prandtl number
# transport.turbulent_prandtl              = 0.3333              # Turbulent prandtl number
#
# # --- Geometry and Mesh ---
# geometry.prob_lo                         = 588800.0 3978800.0 0.0
# geometry.prob_hi                         = 691200.0 4081200.0 2560.0
# amr.n_cell                               = 5120 5120 128       # Number of cells in x, y, and z directions
# amr.max_level                            = 0
# geometry.is_periodic                     = 1 1 0
# zlo.type                                 = no_slip_wall
# zhi.type                                 = no_slip_wall
#
# # --- ABL parameters ---
# ICNS.source_terms                        =
# ABLForcing.abl_forcing_height            = 0.0
# time.plot_interval                       = 1000
# io.plot_file                             = plt
# io.KE_int                                = -1
#
# #---- postprocessing defs ----
# incflo.post_processing                   = lidar_
# lidar_.type                              = Sampling
# lidar_.output_frequency                  = 1
# lidar_.fields                            = velocity
#
# #---- sample defs ----
# lidar_.labels                            = lidar_FarmStats_Up lidar_FarmStats_Dn lidar_WakeStats lidar_SpeedupStats lidar_InflowTurb lidar_HorizWakeMeand lidar_VerticalWakeMeand
# lidar_.lidar_FarmStats_Up.type           = LidarSampler
# lidar_.lidar_FarmStats_Up.num_points     = 667
# lidar_.lidar_FarmStats_Up.length         = 2000.0
# lidar_.lidar_FarmStats_Up.origin         = 643050.58826 4025581.533244 91.0
# lidar_.lidar_FarmStats_Up.periodic       = true
# lidar_.lidar_FarmStats_Up.time_table     = 0.0 250.79999999999995 250.80099999999996 501.6009999999999 501.60199999999986 752.4019999999998 752.4029999999998 1003.2029999999997 1003.2039999999997 1254.0039999999997 1254.0049999999997 1504.8049999999996 1504.8059999999996 1755.6059999999995 1755.6069999999995 2006.4069999999995 2006.4079999999994 2257.2079999999996 2257.209 2508.009 2508.01 2758.8100000000004
# lidar_.lidar_FarmStats_Up.azimuth_table  = -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513 -145.00000004221653 -25.000000042216513
# lidar_.lidar_FarmStats_Up.elevation_table = -10 -10 -8 -8 -6 -6 -4 -4 -2 -2 0 0 2 2 4 4 6 6 8 8 10 10
# lidar_.lidar_FarmStats_Dn.type           = LidarSampler
# lidar_.lidar_FarmStats_Dn.num_points     = 667
# lidar_.lidar_FarmStats_Dn.length         = 2000.0
# lidar_.lidar_FarmStats_Dn.origin         = 643050.58826 4025581.533244 91.0
# lidar_.lidar_FarmStats_Dn.periodic       = true
# lidar_.lidar_FarmStats_Dn.time_table     = 0.0 250.79999999999995 250.80099999999996 501.6009999999999 501.60199999999986 752.4019999999998 752.4029999999998 1003.2029999999997 1003.2039999999997 1254.0039999999997 1254.0049999999997 1504.8049999999996 1504.8059999999996 1755.6059999999995 1755.6069999999995 2006.4069999999995 2006.4079999999994 2257.2079999999996 2257.209 2508.009 2508.01 2758.8100000000004
# lidar_.lidar_FarmStats_Dn.azimuth_table  = 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835 34.9999999577835 154.9999999577835
# lidar_.lidar_FarmStats_Dn.elevation_table = -10 -10 -8 -8 -6 -6 -4 -4 -2 -2 0 0 2 2 4 4 6 6 8 8 10 10
# lidar_.lidar_WakeStats.type              = LidarSampler
# lidar_.lidar_WakeStats.num_points        = 667
# lidar_.lidar_WakeStats.length            = 2000.0
# lidar_.lidar_WakeStats.origin            = 643050.58826 4025581.533244 91.0
# lidar_.lidar_WakeStats.periodic          = true
# lidar_.lidar_WakeStats.time_table        = 0.0 154.0 154.001 308.001 308.00199999999995 462.00199999999995 462.00299999999993 616.0029999999999 616.0039999999999 770.0039999999999 770.0049999999999 924.0049999999999 924.0059999999999 1078.0059999999999 1078.0069999999998 1232.0069999999998 1232.0079999999998 1386.0079999999998 1386.0089999999998 1540.0089999999998 1540.0099999999998 1694.0099999999998
# lidar_.lidar_WakeStats.azimuth_table     = 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835 79.9999999577835 109.9999999577835
# lidar_.lidar_WakeStats.elevation_table   = -15 -15 -12 -12 -9 -9 -6 -6 -3 -3 0 0 3 3 6 6 9 9 12 12 15 15
# lidar_.lidar_SpeedupStats.type           = LidarSampler
# lidar_.lidar_SpeedupStats.num_points     = 667
# lidar_.lidar_SpeedupStats.length         = 2000.0
# lidar_.lidar_SpeedupStats.origin         = 643050.58826 4025581.533244 91.0
# lidar_.lidar_SpeedupStats.periodic       = true
# lidar_.lidar_SpeedupStats.time_table     = 0.0 234.0
# lidar_.lidar_SpeedupStats.azimuth_table  = -265.0000000422165 94.99999995778349
# lidar_.lidar_SpeedupStats.elevation_table = 0 0
# lidar_.lidar_InflowTurb.type             = LidarSampler
# lidar_.lidar_InflowTurb.num_points       = 667
# lidar_.lidar_InflowTurb.length           = 2000.0
# lidar_.lidar_InflowTurb.origin           = 643050.58826 4025581.533244 91.0
# lidar_.lidar_InflowTurb.periodic         = true
# lidar_.lidar_InflowTurb.time_table       = 0.0 19.5
# lidar_.lidar_InflowTurb.azimuth_table    = -100.00000004221651 -70.00000004221651
# lidar_.lidar_InflowTurb.elevation_table  = 0 0
# lidar_.lidar_HorizWakeMeand.type         = LidarSampler
# lidar_.lidar_HorizWakeMeand.num_points   = 667
# lidar_.lidar_HorizWakeMeand.length       = 2000.0
# lidar_.lidar_HorizWakeMeand.origin       = 643050.58826 4025581.533244 91.0
# lidar_.lidar_HorizWakeMeand.periodic     = true
# lidar_.lidar_HorizWakeMeand.time_table   = 0.0 19.5
# lidar_.lidar_HorizWakeMeand.azimuth_table = 79.9999999577835 109.9999999577835
# lidar_.lidar_HorizWakeMeand.elevation_table = 0 0
# lidar_.lidar_VerticalWakeMeand.type      = LidarSampler
# lidar_.lidar_VerticalWakeMeand.num_points = 667
# lidar_.lidar_VerticalWakeMeand.length    = 2000.0
# lidar_.lidar_VerticalWakeMeand.origin    = 643050.58826 4025581.533244 91.0
# lidar_.lidar_VerticalWakeMeand.periodic  = true
# lidar_.lidar_VerticalWakeMeand.time_table = 0.0 19.5
# lidar_.lidar_VerticalWakeMeand.azimuth_table = 94.9999999577835 94.9999999577835
# lidar_.lidar_VerticalWakeMeand.elevation_table = -15.0 15.0
#
# #---- extra params ----
# #== END AMR-WIND INPUT ==
