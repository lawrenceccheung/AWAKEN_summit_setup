# %% [markdown]
# # Compare power between various runs for all wind farms

# %%
# Load the libraries                                                                                                                        

import numpy             as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
#import xarray as xr
#import argparse
import os
import pandas as pd
import glob

import yaml as yaml
Loader=yaml.safe_load

# Make all plots inline 
# %matplotlib inline

# %%
def loadyamldef(yamlfile, extradict={}):
    with open(yamlfile) as f:
        returndict = Loader(f)
    # Get the path to yamlfile
    dirpath = os.path.dirname(yamlfile)
    returndict['dirpath'] = dirpath
    # override any entries in the file
    for k,g in extradict.items():
        returndict[k] = g
    return returndict

def getturblist(yamldef, group):
    turbinegroups = yamldef['turbinegroups']
    # First check to make sure that the group exists:
    if group not in turbinegroups:
        return None
    
    dirpath=yamldef['dirpath']
    cwd = os.getcwd()
    os.chdir(dirpath)
    if 'globpattern' in turbinegroups[group]:
        # Load files from the glob pattern:
        outfilelist = glob.glob(turbinegroups[group]['globpattern'])
    else:
        outfilelist = turbinegroups[group]['filelist']
    outfilelist = [os.path.abspath(x) for x in outfilelist]
    os.chdir(cwd)
    return outfilelist

def avgturbpower(yamldef, group, delim=' '):
    """
    Average turbine power from a bunch of turbines
    """
    turblist = getturblist(yamldef, group)
    avgpower = None
    skiprows = yamldef['skiprows'] if 'skiprows' in yamldef else 0
    for ifile, turbfile in enumerate(turblist):
        dat = np.loadtxt(turbfile, skiprows=skiprows, delimiter=delim)
        if ifile == 0:
            avgpower = dat
        else:
            avgpower += dat
    avgpower /= len(turblist)
    return avgpower

def setfigtextsize(ax, fsize):
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label, ax.yaxis.get_offset_text(), ax.xaxis.get_offset_text(), ] + ax.get_xticklabels() + ax.get_yticklabels() ):
        item.set_fontsize(fsize)

# %%
AllFigures = [
    {'title':'King Plains avg. turbine power (all turbines)',
     'turbinegroup':'allturbines',
     'figsize':(10,4),
     'xlim':[0, 3000],
     'datasets':[
        ['DATA_Summit_amrwind_bananasrun1/KingPlainsTurbines.yaml', {'label':'AMR-Wind Summit', 'plotargs':{'color':'r'}}],
        ['DATA_Summit_amrwind_eastkp/KingPlainsTurbines.yaml', {'label':'AMR-Wind Summit (East KP)', 'delim':',', 'plotargs':{'color':'pink'}}],
        ['DATA_SNL_naluwind_unstable/NaluTurbines.yaml', {'label':'Nalu-Wind SNL', 'plotargs':{'color':'g'}}],
        ['DATA_eagle_WRFLESGAD_unstable/no_terrain/WRFTurbines.yaml', {'label':'WRF-LES-GAD Eagle (no terrain)', 'plotargs':{'color':'c'}}],
        ['DATA_eagle_WRFLESGAD_unstable/terrain/WRFTurbines.yaml', {'label':'WRF-LES-GAD Eagle (terrain)', 'plotargs':{'color':'c', 'ls':'--'}}],
        ['DATA_FLORIS_TurbOPark_unstable/KingPlains.yaml', {'label':'FLORIS TurbOPark', 'plotargs':{'color':'b'}}],
        ['DATA_FLORIS_GCH_unstable/KingPlains.yaml', {'label':'FLORIS GCH', 'plotargs':{'color':'b', 'ls':'--'}}],
        ],
    },
    {'title':'King Plains avg. turbine power (frontrow)',
     'turbinegroup':'frontrow',
     'figsize':(10,4),
     'xlim':[0, 3000],
     'datasets':[
        ['DATA_Summit_amrwind_bananasrun1/KingPlainsTurbines.yaml', {'label':'AMR-Wind Summit', 'plotargs':{'color':'r'}}],
        ['DATA_Summit_amrwind_eastkp/KingPlainsTurbines.yaml', {'label':'AMR-Wind Summit (East KP)', 'delim':',', 'plotargs':{'color':'pink'}}],
        ['DATA_SNL_naluwind_unstable/NaluTurbines.yaml', {'label':'Nalu-Wind SNL', 'plotargs':{'color':'g'}}],
        ['DATA_eagle_WRFLESGAD_unstable/no_terrain/WRFTurbines.yaml', {'label':'WRF-LES-GAD Eagle (no terrain)', 'plotargs':{'color':'c'}}],
        ['DATA_eagle_WRFLESGAD_unstable/terrain/WRFTurbines.yaml', {'label':'WRF-LES-GAD Eagle (terrain)', 'plotargs':{'color':'c', 'ls':'--'}}],
        ['DATA_FLORIS_TurbOPark_unstable/KingPlains.yaml', {'label':'FLORIS TurbOPark', 'plotargs':{'color':'b'}}],
        ['DATA_FLORIS_GCH_unstable/KingPlains.yaml', {'label':'FLORIS GCH', 'plotargs':{'color':'b', 'ls':'--'}}],
        ],
    },
    {'title':'Thunder Ranch avg. turbine power (all turbines)',
     'turbinegroup':'allturbines',
     'xlim':[0, 1500],
     'ylim':[0, 2100],     
     'datasets':[
        ['DATA_Summit_amrwind_bananasrun1/ThunderRanchTurbines.yaml', {'label':'AMR-Wind Summit', 'plotargs':{'color':'r'}}],
        ['DATA_SNL_naluwind_unstable_TR/NaluTurbines.yaml', {'label':'Nalu-Wind SNL', 'plotargs':{'color':'g'}}],
        ['DATA_FLORIS_TurbOPark_unstable/ThunderRanch.yaml', {'label':'FLORIS TurbOPark', 'plotargs':{'color':'b'}}],         
     ],
    },
    {'title':'Armadillo Flats avg. turbine power (all turbines)',
     'turbinegroup':'allturbines',
     'xlim':[0, 1200],
     'ylim':[0, 1600],     
     'datasets':[
        ['DATA_Summit_amrwind_bananasrun1/ArmadilloFlatsTurbines.yaml', {'label':'AMR-Wind Summit', 'plotargs':{'color':'r'}}],
        ['DATA_FLORIS_TurbOPark_unstable/ArmadilloFlats.yaml',          {'label':'FLORIS TurbOPark', 'plotargs':{'color':'b'}}],         
     ],
    },
    {'title':'Breckinridge avg. turbine power (all turbines)',
     'turbinegroup':'allturbines',
     'xlim':[0, 1200],
     'ylim':[0, 1600],          
     'datasets':[
        ['DATA_Summit_amrwind_bananasrun1/BreckinridgeTurbines.yaml', {'label':'AMR-Wind Summit', 'plotargs':{'color':'r'}}],
        ['DATA_FLORIS_TurbOPark_unstable/Breckenridge.yaml',          {'label':'FLORIS TurbOPark', 'plotargs':{'color':'b'}}],
     ],
    },
    {'title':'Chisholm View avg. turbine power (all turbines)',
     'turbinegroup':'allturbines',
     'xlim':[0, 1200],
     'ylim':[0, 1600],     
     'datasets':[ 
        ['DATA_Summit_amrwind_bananasrun1/ChisholmViewTurbines.yaml', {'label':'AMR-Wind Summit', 'plotargs':{'color':'r'}}],
        ['DATA_FLORIS_TurbOPark_unstable/ChisholmView.yaml',          {'label':'FLORIS TurbOPark', 'plotargs':{'color':'b'}}],
     ],
    },         
]

# %%
fontsize=9

for datadict in AllFigures:
    datadefs = []
    datasets = datadict['datasets']
    turbinegroup = datadict['turbinegroup']
    figsize      = datadict['figsize'] if 'figsize' in datadict else (6,4)
    title        = datadict['title']
    print('***** '+title+' *****')
    for data in datasets:
        datadefs.append(loadyamldef(data[0], extradict=data[1]))
    fig, ax = plt.subplots(1,1,figsize=figsize, dpi=125)
    for data in datadefs:
        print('Loading '+data['label'])
        plotargs = data['plotargs'] if 'plotargs' in data else {}
        plotargs['label'] = data['label']
        delim = data['delim'] if 'delim' in data else ' '
        farmavg = avgturbpower(data, turbinegroup, delim=delim)
        ax.plot(farmavg[:,0], farmavg[:,1], **plotargs)
        
    # Format and label figure
    ax.legend(prop={'size':fontsize-1})
    ax.grid(ls=':')
    if 'xlim' in datadict: ax.set_xlim(datadict['xlim'])
    if 'ylim' in datadict: ax.set_ylim(datadict['ylim'])
    ax.set_xlabel('Time [s]')
    ax.set_ylabel('Power [kW]')
    ax.set_title(title)
    setfigtextsize(ax, fontsize)
# Out:
# ***** King Plains avg. turbine power (all turbines) *****
# Loading AMR-Wind Summit
# Loading AMR-Wind Summit (East KP)
# Loading Nalu-Wind SNL
# Loading WRF-LES-GAD Eagle (no terrain)
# Loading WRF-LES-GAD Eagle (terrain)
# Loading FLORIS TurbOPark
# Loading FLORIS GCH
# ***** King Plains avg. turbine power (frontrow) *****
# Loading AMR-Wind Summit
# Loading AMR-Wind Summit (East KP)
# Loading Nalu-Wind SNL
# Loading WRF-LES-GAD Eagle (no terrain)
# Loading WRF-LES-GAD Eagle (terrain)
# Loading FLORIS TurbOPark
# Loading FLORIS GCH
# ***** Thunder Ranch avg. turbine power (all turbines) *****
# Loading AMR-Wind Summit
# Loading Nalu-Wind SNL
# Loading FLORIS TurbOPark
# ***** Armadillo Flats avg. turbine power (all turbines) *****
# Loading AMR-Wind Summit
# Loading FLORIS TurbOPark
# ***** Breckinridge avg. turbine power (all turbines) *****
# Loading AMR-Wind Summit
# Loading FLORIS TurbOPark
# ***** Chisholm View avg. turbine power (all turbines) *****
# Loading AMR-Wind Summit
# ...
